# %%
# Most Basic
import matplotlib.pyplot as plt
import matplotlib as mpl
import seaborn as sns
import pandas as pd
import numpy as np
import math
from os import path
import sys
from datetime import datetime
from scipy.stats import norm
import scipy.stats as ss
import copy
import warnings
warnings.simplefilter('error')
import datetime

# Filter Specific Functionalities
from filterpy.kalman import UnscentedKalmanFilter
from filterpy.common import Q_discrete_white_noise
from filterpy.kalman import MerweScaledSigmaPoints

# Gradient Based
import autograd.numpy as a_np
import autograd.scipy.stats as a_ss
from autograd import grad, multigrad_dict, elementwise_grad, jacobian

# Self Defined functions5
from DataMaker_New import dataCleaner_new
from ESN import EchoState
from Loss import loss

# %%
columns = ["date","exdate","strike_price","best_bid","best_offer","volume","impl_volatility"]
start = datetime.datetime(2018, 1, 1)
end = datetime.datetime(2019, 12, 31)
train_valid_split = 0.936
valid_test_split = 0.94
u_dim = 10
topK = 5
cleaner = dataCleaner_new(columns, u_dim, topK, start, end, train_valid_split, valid_test_split)
return_dict, price_dict = cleaner.make_return_price()
risk_dict = cleaner.make_risk()
train_data, valid_data, test_data = cleaner.make_final_data(price_dict, return_dict, risk_dict)
num_train_day, num_train_obs = cleaner.get_train_num()
num_valid_day, num_valid_obs = cleaner.get_valid_num()
num_test_day, num_test_obs = cleaner.get_test_num()

# train_data[np.datetime64('2019-01-02T00:00:00.000000000')]
# Out:
# Attached 351 days of train data
# Attached 1755 train option observations
# Attached 1 days of validation data
# Attached 5 validation option observations
# Attached 23 days of test data
# Attached 115 test option observations

# %%
# Define transition Dynamics
# Positional requirement, no real effect, will be replaced by ESN and BS defined further down
def fx(x, dt):
    return x*dt
def hx(x):
    return x

def sigmoid(x):
    return np.divide(1, 1+np.exp(-x))


def ESNf(theta_now, dt, **fx_args):
    """
    :params theta_now theta_t
    
    **fx_args
    :params G reservoir transition matrix
    :params G_in input translation matrix
    :params b reservoir bias vector
    :params u_quad_now u_t^2
    """
    G = fx_args["G"]
    G_in = fx_args["G_in"]
    b = fx_args["b"]
    u_quad_now = fx_args["u_quad_now"]
    theta_next = sigmoid(np.matmul(G, theta_now) + np.matmul(G_in, u_quad_now) + b)
    return theta_next
    

def BSf(theta_t, **hx_args):
    """
    :params theta_t current state vector
    
    **hx_args
    :params p_t current asset price
    :params r_t current asset price
    :params K_t strike price, 1d vector
    :params T_t maturity time, 1d vector
    """
    p_t = hx_args["p_t"]
    r_t = hx_args["r_t"]
    K_t = hx_args["K_t"]
    T_t = hx_args["T_t"]
    
    volatility_std = np.average(theta_t)
    volatility_var = np.power(volatility_std, 2)
    
    dividor = np.sqrt(volatility_var * T_t)
    d_pls = (np.log(p_t/K_t) + np.multiply(r_t+volatility_var/2, T_t)) / dividor
    d_mns = (np.log(p_t/K_t) + np.multiply(r_t-volatility_var/2, T_t)) / dividor
    y_t = np.multiply(p_t, norm.cdf(d_pls)) - np.multiply(np.multiply(K_t, np.exp(-r_t*T_t)), norm.cdf(d_mns))
    return y_t

def is_pos_def(x):
    return np.all(np.linalg.eigvals(x) > 0)

# %% [markdown]
# # 睡觉专区

# %%
np.random.seed(1234)
gradient = grad(loss)


forward_k = 20

error_for_all_theta_dim = []
best_itr_for_all_theta_dim = []
best_train_itr_for_all_theta_dim = []
params_for_all_theta_dim = []
ms_s_for_all_theta_dim = []
Cs_s_for_all_theta_dim = []

for theta_dim in np.arange(2, 11, 1):

    m_t_1 = [np.array([0]), np.array([0]), np.array([0])]
    v_t_1 = [np.array([0]), np.array([0]), np.array([0])]
    beta_1 = 0.9
    beta_2 = 0.999
    epsillon = 1e-8
    
    print("theta_dim = {}".format(theta_dim))
    alpha = 5
    connectivity = 0.4
    spectral_radius = 0.98
    bday_p_year = 252
    bias = -7

    v_scale = 100.0
    target_var = 1e-6
    chi_mu = math.sqrt(2)* math.gamma((theta_dim+1)/2) / math.gamma(theta_dim/2)
    W_scale = target_var+chi_mu

    # initialize ESN dynamics
    ESN = EchoState(theta_dim, u_dim, connectivity, spectral_radius, bias)
    W = np.eye(theta_dim)*W_scale
    v = v_scale

    last_avg_error = 100
    best_itr = 0
    best_train_error = 100
    best_train_itr = 0
    
    #%%%%%% Error trajectories
    
    test_error_traj = []
    params_traj = []
    ms_s_traj = []
    Cs_s_traj = []
    
    for em_itr in range(200):
        dt=1
        points = MerweScaledSigmaPoints(theta_dim, alpha=.001, beta=2., kappa=0)
        ukf = UnscentedKalmanFilter(dim_x=ESN.theta_dim, dim_z=topK, dt=1, fx=fx, hx=hx, points=points)
        ukf.x = np.ones(ESN.theta_dim)* 0.006 # initial state
        ukf.P *= 0.01 # initial uncertainty
        ukf.R = np.diag([v]*topK) # 1 standard
        ukf.Q = W

        ms = [ukf.x.copy()]
        Cs = [ukf.P.copy()]
        u_quad_s = []
        ps = []
        rs = []
        ys = []
        Ks = []
        us = []
        Ts = []

        all_days = sorted(list(train_data.keys()))
        for day in all_days:
            # get observable data
            ## Stock Wise and market wise data
            r_t = train_data[day][1] / bday_p_year
            u_t = train_data[day][2].reshape([-1])
            p_t = train_data[day][3]

            ## Option wise data
            y_t = train_data[day][0]["spotclose"].values
            K_t = train_data[day][0]["strike_price"].values
            today = [d.date() for d in train_data[day][0]["date"]]
            expireday = [d.date() for d in train_data[day][0]["exdate"]]
            T_t = np.busday_count(today, expireday)


            ukf.predict(fx = ESNf, G=ESN.G, G_in=ESN.G_in, b= ESN.b, u_quad_now=np.power(u_t,2))
            ukf.update(y_t, hx=BSf, p_t=p_t, r_t=r_t, K_t=K_t, T_t=T_t)
            ms.append(ukf.x_post.copy())
            Cs.append(ukf.P_post.copy())
            u_quad_s.append(np.power(u_t,2))
            us.append(u_t)
            ps.append(p_t)
            rs.append(r_t)
            ys.append(y_t)
            Ks.append(K_t)
            Ts.append(T_t)

        ms = np.array(ms)
        Cs = np.array(Cs)
        ms_s, Cs_s, _, cvs_s = ukf.rts_smoother(ms, Cs, fx=ESNf, G=ESN.G, G_in=ESN.G_in, b=ESN.b, u_s=us)


        params = [ESN.G, ESN.G_in, ESN.b, ukf.Q, v]

        step = 0.05
        try:
            curr_loss = loss(params,
                             ms_s, Cs_s, cvs_s,
                             u_quad_s,
                             ps, rs, Ks, Ts, ys,
                             num_train_obs,
                             reg=alpha)
            curr_grad = gradient(params,
                                 ms_s, Cs_s, cvs_s,
                                 u_quad_s,
                                 ps, rs, Ks, Ts, ys,
                                 num_train_obs,
                                 reg=alpha)

######################## Adam Optimizer ###########################
            
            m_t = [None, None, None]
            v_t = [None, None, None]
            m_t_hat = [None, None, None]
            v_t_hat = [None, None, None]

            m_t[0] = beta_1 * m_t_1[0] + (1-beta_1) * curr_grad[0]
            v_t[0] = beta_2 * v_t_1[0] + (1-beta_2) * (curr_grad[0] * curr_grad[0])
            m_t_hat[0] = m_t[0] / (1-beta_1 ** (em_itr+1))
            v_t_hat[0] = v_t[0] / (1-beta_2 ** (em_itr+1))
            params[0] -= step * m_t_hat[0] / (np.sqrt(v_t_hat[0]) + epsillon)

            m_t[1] = beta_1 * m_t_1[1] + (1-beta_1) * curr_grad[1]
            v_t[1] = beta_2 * v_t_1[1] + (1-beta_2) * (curr_grad[1] * curr_grad[1])
            m_t_hat[1] = m_t[1] / (1-beta_1 ** (em_itr+1))
            v_t_hat[1] = v_t[1] / (1-beta_2 ** (em_itr+1))
            params[1] -= step * m_t_hat[1] / (np.sqrt(v_t_hat[1]) + epsillon)

            m_t[2] = beta_1 * m_t_1[2] + (1-beta_1) * curr_grad[2]
            v_t[2] = beta_2 * v_t_1[2] + (1-beta_2) * (curr_grad[2] * curr_grad[2])
            m_t_hat[2] = m_t[2] / (1-beta_1 ** (em_itr+1))
            v_t_hat[2] = v_t[2] / (1-beta_2 ** (em_itr+1))
            params[2] -= step * m_t_hat[2] / (np.sqrt(v_t_hat[2]) + epsillon)

            m_t = m_t_1
            v_t = v_t_1

###################################################################

        except RuntimeWarning or LinAlgError or OverflowError:
            print("Error occured")
            pass

        ESN.G, ESN.G_in, ESN.b, W, v = params

        
################################################################### Training Performance
        
        np.delete(ms_s,0,0)
        np.delete(Cs_s,0,0)
        train_errors = []
        ukf.x = ms_s[1]
        ukf.P = Cs_s[1]
        for i in range(2, len(ms_s)-1):

            ukf.predict(fx = ESNf,  G=ESN.G, G_in=ESN.G_in, b= ESN.b, u_quad_now=u_quad_s[i])
            pred_price = BSf(ukf.x_prior, p_t=ps[i], r_t=rs[i], K_t=Ks[i], T_t=Ts[i])
            error = np.average(np.abs(ys[i]-pred_price) /ys[i])
            train_errors.append(error)
            ukf.update(ys[i], hx=BSf, p_t=ps[i], r_t=rs[i], K_t=Ks[i], T_t=Ts[i])

        avg_train_error = np.average(train_errors)

################################################################### Validation Performance
        ukf.x = ms_s[-1]
        ukf.P = Cs_s[-1]
        valid_errors = []
        
        all_valid_days = sorted(list(valid_data.keys()))
        for day in all_valid_days:
            # get observable data
            ## Stock Wise and market wise data
            r_t = valid_data[day][1] / bday_p_year
            u_t = valid_data[day][2].reshape([-1])
            p_t = valid_data[day][3]

            ## Option wise data
            y_t = valid_data[day][0]["spotclose"].values
            K_t = valid_data[day][0]["strike_price"].values
            today = [d.date() for d in valid_data[day][0]["date"]]
            expireday = [d.date() for d in valid_data[day][0]["exdate"]]
            T_t = np.busday_count(today, expireday)

            ukf.predict(fx = ESNf, G=ESN.G, G_in=ESN.G_in, b= ESN.b, u_quad_now=np.power(u_t,2))
            pred_price = BSf(ukf.x_prior, p_t=p_t, r_t=r_t, K_t=K_t, T_t=T_t)
            error = np.average(np.abs(y_t-pred_price) /y_t)
            valid_errors.append(error)
            
            ukf.update(y_t, hx=BSf, p_t=p_t, r_t=r_t, K_t=K_t, T_t=T_t)
            
        avg_valid_error = np.average(valid_errors) 

################################################################### Testing Performance
        
        # forward K step prediction
        k_step_test_error = []
        
        for k in range(1, min(forward_k+1, num_test_day+1)):
    
            test_errors = []
            
            
            all_test_days = sorted(list(test_data.keys()))
            
            # For loop for base shift, shift of last updated ukf timestep
            for idx in range(len(all_test_days) - k):
                
                ukf_pred = copy.deepcopy(ukf)
                
                # For loop for k predictions forward
                for shift in range(k) :
                    # get observable data
                    ## Stock Wise and market wise data
                    r_t = test_data[all_test_days[idx+shift]][1] / bday_p_year
                    u_t = test_data[all_test_days[idx+shift]][2].reshape([-1])
                    p_t = test_data[all_test_days[idx+shift]][3]

                    ## Option wise data
                    y_t = test_data[all_test_days[idx+shift]][0]["spotclose"].values
                    K_t = test_data[all_test_days[idx+shift]][0]["strike_price"].values
                    today = [d.date() for d in test_data[all_test_days[idx+shift]][0]["date"]]
                    expireday = [d.date() for d in test_data[all_test_days[idx+shift]][0]["exdate"]]
                    T_t = np.busday_count(today, expireday)

                    ukf_pred.predict(fx = ESNf, G=ESN.G, G_in=ESN.G_in, b= ESN.b, u_quad_now=np.power(u_t,2))
                
                
                
                pred_price = BSf(ukf_pred.x_prior, p_t=p_t, r_t=r_t, K_t=K_t, T_t=T_t)
                error = np.average(np.abs(y_t-pred_price) /y_t)
                test_errors.append(error)
                
                
                # shift base one step forward
                r_t = test_data[all_test_days[idx]][1] / bday_p_year
                u_t = test_data[all_test_days[idx]][2].reshape([-1])
                p_t = test_data[all_test_days[idx]][3]

                ## Option wise data
                y_t = test_data[all_test_days[idx]][0]["spotclose"].values
                K_t = test_data[all_test_days[idx]][0]["strike_price"].values
                today = [d.date() for d in test_data[all_test_days[idx]][0]["date"]]
                expireday = [d.date() for d in test_data[all_test_days[idx]][0]["exdate"]]

                ukf.predict(fx = ESNf, G=ESN.G, G_in=ESN.G_in, b= ESN.b, u_quad_now=np.power(u_t,2))
                ukf.update(y_t, hx=BSf, p_t=p_t, r_t=r_t, K_t=K_t, T_t=T_t)
            
            if test_errors != []:
                avg_test_error = np.average(test_errors)
                k_step_test_error.append(avg_test_error)
            else:
                pass
            
            
################################################################### Show details
        

        print("EM Iter {} | Loss: {:.4f} | Train Error: {:.4f} | Val Error : {:.4f} | Test Error: {:.4f} |"  
              " Dyn var {:.2f} | Obs var {:.2f}".format(em_itr, curr_loss,
                                                        avg_train_error, avg_valid_error, avg_test_error, 
                                                        W[0,0], v))
        
        if last_avg_error < avg_valid_error and em_itr-best_itr >= 40:
            break
        elif last_avg_error < avg_valid_error and em_itr-best_itr < 40:
            pass
        elif last_avg_error > avg_valid_error and em_itr-best_itr < 40:
            last_avg_error = avg_valid_error
            model_performance = avg_test_error
            best_itr = em_itr
            
        if best_train_error > avg_train_error and em_itr-best_train_itr < 100:
            best_train_error = avg_traind_error
            best_train_itr = em_itr
            
    
        test_error_traj.append(k_step_test_error)
        params_traj.append(params)
        ms_s_traj.append(ms_s)
        Cs_s_traj.append(Cs_s)
    
    error_for_all_theta_dim.append(test_error_traj)
    best_itr_for_all_theta_dim.append(best_itr)
    best_train_itr_for_all_theta_dim.append(best_itr)
    params_for_all_theta_dim.append(params_traj)
    ms_s_for_all_theta_dim.append(ms_s_traj)
    Cs_s_for_all_theta_dim.append(Cs_s_traj)
    
    print("best val error: {} at {}th iteration, Model Performance: {} | theta_dim = {}".format(last_avg_error,
                                                                                                best_itr,
                                                                                                model_performance,
                                                                                                theta_dim))
    print("++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++")
# Out:
# theta_dim = 2
# EM Iter 0 | Loss: 43.8834 | Train Error: 0.8175 | Val Error : 0.9549 | Test Error: 0.8807 | Dyn var 1.25 | Obs var 100.00
# EM Iter 1 | Loss: 38.4936 | Train Error: 0.8169 | Val Error : 0.9545 | Test Error: 0.8802 | Dyn var 1.25 | Obs var 100.00
# EM Iter 2 | Loss: 34.0715 | Train Error: 0.8162 | Val Error : 0.9541 | Test Error: 0.8797 | Dyn var 1.25 | Obs var 100.00
# EM Iter 3 | Loss: 31.2450 | Train Error: 0.8153 | Val Error : 0.9536 | Test Error: 0.8791 | Dyn var 1.25 | Obs var 100.00
# EM Iter 4 | Loss: 28.9518 | Train Error: 0.8144 | Val Error : 0.9530 | Test Error: 0.8784 | Dyn var 1.25 | Obs var 100.00
# EM Iter 5 | Loss: 26.8117 | Train Error: 0.8133 | Val Error : 0.9524 | Test Error: 0.8777 | Dyn var 1.25 | Obs var 100.00
# EM Iter 6 | Loss: 25.2378 | Train Error: 0.8121 | Val Error : 0.9517 | Test Error: 0.8768 | Dyn var 1.25 | Obs var 100.00
# EM Iter 7 | Loss: 23.8192 | Train Error: 0.8109 | Val Error : 0.9510 | Test Error: 0.8759 | Dyn var 1.25 | Obs var 100.00
# EM Iter 8 | Loss: 22.7999 | Train Error: 0.8095 | Val Error : 0.9501 | Test Error: 0.8749 | Dyn var 1.25 | Obs var 100.00
# EM Iter 9 | Loss: 22.1052 | Train Error: 0.8080 | Val Error : 0.9493 | Test Error: 0.8739 | Dyn var 1.25 | Obs var 100.00
# EM Iter 10 | Loss: 21.5105 | Train Error: 0.8064 | Val Error : 0.9483 | Test Error: 0.8728 | Dyn var 1.25 | Obs var 100.00
# EM Iter 11 | Loss: 21.1609 | Train Error: 0.8047 | Val Error : 0.9473 | Test Error: 0.8716 | Dyn var 1.25 | Obs var 100.00
# EM Iter 12 | Loss: 20.6877 | Train Error: 0.8027 | Val Error : 0.9462 | Test Error: 0.8702 | Dyn var 1.25 | Obs var 100.00
# EM Iter 13 | Loss: 20.3446 | Train Error: 0.8006 | Val Error : 0.9450 | Test Error: 0.8688 | Dyn var 1.25 | Obs var 100.00
# EM Iter 14 | Loss: 19.8753 | Train Error: 0.7983 | Val Error : 0.9436 | Test Error: 0.8672 | Dyn var 1.25 | Obs var 100.00
# EM Iter 15 | Loss: 19.6932 | Train Error: 0.7959 | Val Error : 0.9422 | Test Error: 0.8655 | Dyn var 1.25 | Obs var 100.00
# EM Iter 16 | Loss: 19.3074 | Train Error: 0.7931 | Val Error : 0.9406 | Test Error: 0.8636 | Dyn var 1.25 | Obs var 100.00
# EM Iter 17 | Loss: 19.1244 | Train Error: 0.7903 | Val Error : 0.9390 | Test Error: 0.8616 | Dyn var 1.25 | Obs var 100.00
# EM Iter 18 | Loss: 18.7366 | Train Error: 0.7871 | Val Error : 0.9372 | Test Error: 0.8595 | Dyn var 1.25 | Obs var 100.00
# EM Iter 19 | Loss: 18.5506 | Train Error: 0.7837 | Val Error : 0.9353 | Test Error: 0.8572 | Dyn var 1.25 | Obs var 100.00
# EM Iter 20 | Loss: 18.1590 | Train Error: 0.7800 | Val Error : 0.9331 | Test Error: 0.8546 | Dyn var 1.25 | Obs var 100.00
# EM Iter 21 | Loss: 17.9685 | Train Error: 0.7760 | Val Error : 0.9308 | Test Error: 0.8519 | Dyn var 1.25 | Obs var 100.00
# EM Iter 22 | Loss: 17.5719 | Train Error: 0.7715 | Val Error : 0.9283 | Test Error: 0.8489 | Dyn var 1.25 | Obs var 100.00
# EM Iter 23 | Loss: 17.3758 | Train Error: 0.7667 | Val Error : 0.9256 | Test Error: 0.8456 | Dyn var 1.25 | Obs var 100.00
# EM Iter 24 | Loss: 16.9732 | Train Error: 0.7612 | Val Error : 0.9226 | Test Error: 0.8420 | Dyn var 1.25 | Obs var 100.00
# EM Iter 25 | Loss: 16.7707 | Train Error: 0.7554 | Val Error : 0.9194 | Test Error: 0.8380 | Dyn var 1.25 | Obs var 100.00
# EM Iter 26 | Loss: 16.3614 | Train Error: 0.7488 | Val Error : 0.9157 | Test Error: 0.8336 | Dyn var 1.25 | Obs var 100.00
# EM Iter 27 | Loss: 16.1520 | Train Error: 0.7417 | Val Error : 0.9118 | Test Error: 0.8288 | Dyn var 1.25 | Obs var 100.00
# EM Iter 28 | Loss: 15.7354 | Train Error: 0.7336 | Val Error : 0.9075 | Test Error: 0.8233 | Dyn var 1.25 | Obs var 100.00
# EM Iter 29 | Loss: 15.5186 | Train Error: 0.7247 | Val Error : 0.9027 | Test Error: 0.8174 | Dyn var 1.25 | Obs var 100.00
# EM Iter 30 | Loss: 15.0945 | Train Error: 0.7147 | Val Error : 0.8974 | Test Error: 0.8106 | Dyn var 1.25 | Obs var 100.00
# EM Iter 31 | Loss: 14.8700 | Train Error: 0.7037 | Val Error : 0.8917 | Test Error: 0.8031 | Dyn var 1.25 | Obs var 100.00
# EM Iter 32 | Loss: 14.4381 | Train Error: 0.6911 | Val Error : 0.8852 | Test Error: 0.7945 | Dyn var 1.25 | Obs var 100.00
# EM Iter 33 | Loss: 14.2056 | Train Error: 0.6773 | Val Error : 0.8782 | Test Error: 0.7849 | Dyn var 1.25 | Obs var 100.00
# EM Iter 34 | Loss: 13.7656 | Train Error: 0.6615 | Val Error : 0.8702 | Test Error: 0.7739 | Dyn var 1.25 | Obs var 100.00
# EM Iter 35 | Loss: 13.6784 | Train Error: 0.6444 | Val Error : 0.8617 | Test Error: 0.7618 | Dyn var 1.25 | Obs var 100.00
# EM Iter 36 | Loss: 13.3812 | Train Error: 0.6254 | Val Error : 0.8525 | Test Error: 0.7482 | Dyn var 1.25 | Obs var 100.00
# EM Iter 37 | Loss: 13.2892 | Train Error: 0.6046 | Val Error : 0.8425 | Test Error: 0.7331 | Dyn var 1.25 | Obs var 100.00
# EM Iter 38 | Loss: 13.2963 | Train Error: 0.5827 | Val Error : 0.8320 | Test Error: 0.7166 | Dyn var 1.25 | Obs var 100.00
# EM Iter 39 | Loss: 13.2047 | Train Error: 0.5597 | Val Error : 0.8207 | Test Error: 0.6983 | Dyn var 1.25 | Obs var 100.00
# EM Iter 40 | Loss: 13.2105 | Train Error: 0.5362 | Val Error : 0.8087 | Test Error: 0.6783 | Dyn var 1.25 | Obs var 100.00
# EM Iter 41 | Loss: 13.1174 | Train Error: 0.5124 | Val Error : 0.7959 | Test Error: 0.6561 | Dyn var 1.25 | Obs var 100.00
# EM Iter 42 | Loss: 13.1216 | Train Error: 0.4887 | Val Error : 0.7824 | Test Error: 0.6317 | Dyn var 1.25 | Obs var 100.00
# EM Iter 43 | Loss: 13.0270 | Train Error: 0.4666 | Val Error : 0.7679 | Test Error: 0.6047 | Dyn var 1.25 | Obs var 100.00
# EM Iter 44 | Loss: 13.0297 | Train Error: 0.4493 | Val Error : 0.7526 | Test Error: 0.5751 | Dyn var 1.25 | Obs var 100.00
# EM Iter 45 | Loss: 12.9336 | Train Error: 0.4379 | Val Error : 0.7362 | Test Error: 0.5423 | Dyn var 1.25 | Obs var 100.00
# EM Iter 46 | Loss: 12.9348 | Train Error: 0.4324 | Val Error : 0.7189 | Test Error: 0.5065 | Dyn var 1.25 | Obs var 100.00
# EM Iter 47 | Loss: 12.8372 | Train Error: 0.4310 | Val Error : 0.7003 | Test Error: 0.4668 | Dyn var 1.25 | Obs var 100.00
# EM Iter 48 | Loss: 12.8368 | Train Error: 0.4351 | Val Error : 0.6807 | Test Error: 0.4236 | Dyn var 1.25 | Obs var 100.00
# EM Iter 49 | Loss: 12.7376 | Train Error: 0.4454 | Val Error : 0.6594 | Test Error: 0.3758 | Dyn var 1.25 | Obs var 100.00
# EM Iter 50 | Loss: 12.7357 | Train Error: 0.4619 | Val Error : 0.6367 | Test Error: 0.3240 | Dyn var 1.25 | Obs var 100.00
# EM Iter 51 | Loss: 12.6349 | Train Error: 0.4854 | Val Error : 0.6117 | Test Error: 0.2667 | Dyn var 1.25 | Obs var 100.00
# EM Iter 52 | Loss: 12.6315 | Train Error: 0.5166 | Val Error : 0.5846 | Test Error: 0.2049 | Dyn var 1.25 | Obs var 100.00
# EM Iter 53 | Loss: 12.5292 | Train Error: 0.5576 | Val Error : 0.5539 | Test Error: 0.1472 | Dyn var 1.25 | Obs var 100.00
# EM Iter 54 | Loss: 12.5242 | Train Error: 0.6089 | Val Error : 0.5196 | Test Error: 0.1092 | Dyn var 1.25 | Obs var 100.00
# EM Iter 55 | Loss: 12.4204 | Train Error: 0.6723 | Val Error : 0.4794 | Test Error: 0.1281 | Dyn var 1.25 | Obs var 100.00
# EM Iter 56 | Loss: 12.4139 | Train Error: 0.7458 | Val Error : 0.4406 | Test Error: 0.1711 | Dyn var 1.25 | Obs var 100.00
# EM Iter 57 | Loss: 12.3085 | Train Error: 0.8318 | Val Error : 0.4158 | Test Error: 0.2383 | Dyn var 1.25 | Obs var 100.00
# EM Iter 58 | Loss: 12.3005 | Train Error: 0.9299 | Val Error : 0.3805 | Test Error: 0.3155 | Dyn var 1.25 | Obs var 100.00
# EM Iter 59 | Loss: 12.1937 | Train Error: 1.0430 | Val Error : 0.3296 | Test Error: 0.4098 | Dyn var 1.25 | Obs var 100.00
# EM Iter 60 | Loss: 12.1842 | Train Error: 1.1697 | Val Error : 0.2595 | Test Error: 0.5271 | Dyn var 1.25 | Obs var 100.00
# EM Iter 61 | Loss: 12.0759 | Train Error: 1.3159 | Val Error : 0.1673 | Test Error: 0.6556 | Dyn var 1.25 | Obs var 100.00
# EM Iter 62 | Loss: 12.0649 | Train Error: 1.4780 | Val Error : 0.2021 | Test Error: 0.7912 | Dyn var 1.25 | Obs var 100.00
# EM Iter 63 | Loss: 11.9551 | Train Error: 1.6632 | Val Error : 0.4262 | Test Error: 0.9395 | Dyn var 1.25 | Obs var 100.00
# EM Iter 64 | Loss: 11.9426 | Train Error: 1.8654 | Val Error : 0.7037 | Test Error: 1.0953 | Dyn var 1.25 | Obs var 100.00
# EM Iter 65 | Loss: 11.8315 | Train Error: 2.0937 | Val Error : 1.0595 | Test Error: 1.2656 | Dyn var 1.25 | Obs var 100.00
# EM Iter 66 | Loss: 11.8175 | Train Error: 2.3419 | Val Error : 1.4944 | Test Error: 1.4437 | Dyn var 1.25 | Obs var 100.00
# EM Iter 67 | Loss: 11.7050 | Train Error: 2.6194 | Val Error : 2.0448 | Test Error: 1.6383 | Dyn var 1.25 | Obs var 100.00
# EM Iter 68 | Loss: 11.6896 | Train Error: 2.9148 | Val Error : 2.7059 | Test Error: 1.8410 | Dyn var 1.25 | Obs var 100.00
# EM Iter 69 | Loss: 11.5756 | Train Error: 3.2432 | Val Error : 3.5299 | Test Error: 2.0623 | Dyn var 1.25 | Obs var 100.00
# EM Iter 70 | Loss: 11.5589 | Train Error: 3.5922 | Val Error : 4.5014 | Test Error: 2.2920 | Dyn var 1.25 | Obs var 100.00
# EM Iter 71 | Loss: 11.4436 | Train Error: 3.9817 | Val Error : 5.6938 | Test Error: 2.5428 | Dyn var 1.25 | Obs var 100.00
# EM Iter 72 | Loss: 11.4254 | Train Error: 4.3930 | Val Error : 7.0740 | Test Error: 2.8020 | Dyn var 1.25 | Obs var 100.00
# EM Iter 73 | Loss: 11.3087 | Train Error: 4.8496 | Val Error : 8.7437 | Test Error: 3.0853 | Dyn var 1.25 | Obs var 100.00
# EM Iter 74 | Loss: 11.2892 | Train Error: 5.3296 | Val Error : 10.6426 | Test Error: 3.3770 | Dyn var 1.25 | Obs var 100.00
# EM Iter 75 | Loss: 11.1712 | Train Error: 5.8627 | Val Error : 12.9097 | Test Error: 3.6960 | Dyn var 1.25 | Obs var 100.00
# EM Iter 76 | Loss: 11.1503 | Train Error: 6.4208 | Val Error : 15.4465 | Test Error: 4.0231 | Dyn var 1.25 | Obs var 100.00
# EM Iter 77 | Loss: 11.0311 | Train Error: 7.0410 | Val Error : 18.4401 | Test Error: 4.3814 | Dyn var 1.25 | Obs var 100.00
# EM Iter 78 | Loss: 11.0088 | Train Error: 7.6875 | Val Error : 21.7408 | Test Error: 4.7472 | Dyn var 1.25 | Obs var 100.00
# EM Iter 79 | Loss: 10.8883 | Train Error: 8.4039 | Val Error : 25.5963 | Test Error: 5.1488 | Dyn var 1.25 | Obs var 100.00
# EM Iter 80 | Loss: 10.8647 | Train Error: 9.1480 | Val Error : 29.7913 | Test Error: 5.5571 | Dyn var 1.25 | Obs var 100.00
# EM Iter 81 | Loss: 10.7430 | Train Error: 9.9719 | Val Error : 34.6491 | Test Error: 6.0063 | Dyn var 1.25 | Obs var 100.00
# EM Iter 82 | Loss: 10.7180 | Train Error: 10.8251 | Val Error : 39.8721 | Test Error: 6.4610 | Dyn var 1.25 | Obs var 100.00
# EM Iter 83 | Loss: 10.5952 | Train Error: 11.7695 | Val Error : 45.8759 | Test Error: 6.9627 | Dyn var 1.25 | Obs var 100.00
# EM Iter 84 | Loss: 10.5689 | Train Error: 12.7438 | Val Error : 52.2632 | Test Error: 7.4681 | Dyn var 1.25 | Obs var 100.00
# EM Iter 85 | Loss: 10.4449 | Train Error: 13.8213 | Val Error : 59.5599 | Test Error: 8.0276 | Dyn var 1.25 | Obs var 100.00
# EM Iter 86 | Loss: 10.4173 | Train Error: 14.9298 | Val Error : 67.2508 | Test Error: 8.5884 | Dyn var 1.25 | Obs var 100.00
# EM Iter 87 | Loss: 10.2921 | Train Error: 16.1546 | Val Error : 75.9910 | Test Error: 9.2117 | Dyn var 1.25 | Obs var 100.00
# EM Iter 88 | Loss: 10.2632 | Train Error: 17.4113 | Val Error : 85.1281 | Test Error: 9.8331 | Dyn var 1.25 | Obs var 100.00
# EM Iter 89 | Loss: 10.1369 | Train Error: 18.7985 | Val Error : 95.4669 | Test Error: 10.5268 | Dyn var 1.25 | Obs var 100.00
# EM Iter 90 | Loss: 10.1067 | Train Error: 20.2187 | Val Error : 106.1979 | Test Error: 11.2143 | Dyn var 1.25 | Obs var 100.00
# EM Iter 91 | Loss: 9.9794 | Train Error: 21.7844 | Val Error : 118.2962 | Test Error: 11.9855 | Dyn var 1.25 | Obs var 100.00
# EM Iter 92 | Loss: 9.9479 | Train Error: 23.3845 | Val Error : 130.7753 | Test Error: 12.7452 | Dyn var 1.25 | Obs var 100.00
# EM Iter 93 | Loss: 9.8194 | Train Error: 25.1460 | Val Error : 144.8016 | Test Error: 13.6021 | Dyn var 1.25 | Obs var 100.00
# EM Iter 94 | Loss: 9.7867 | Train Error: 26.9438 | Val Error : 159.1913 | Test Error: 14.4403 | Dyn var 1.25 | Obs var 100.00
# EM Iter 95 | Loss: 9.6572 | Train Error: 28.9197 | Val Error : 175.3231 | Test Error: 15.3916 | Dyn var 1.25 | Obs var 100.00
# EM Iter 96 | Loss: 9.6233 | Train Error: 30.9344 | Val Error : 191.7956 | Test Error: 16.3152 | Dyn var 1.25 | Obs var 100.00
# EM Iter 97 | Loss: 9.4926 | Train Error: 33.1446 | Val Error : 210.2218 | Test Error: 17.3708 | Dyn var 1.25 | Obs var 100.00
# EM Iter 98 | Loss: 9.4575 | Train Error: 35.3970 | Val Error : 228.9606 | Test Error: 18.3870 | Dyn var 1.25 | Obs var 100.00
# EM Iter 99 | Loss: 9.3258 | Train Error: 37.8627 | Val Error : 249.8827 | Test Error: 19.5574 | Dyn var 1.25 | Obs var 100.00
# EM Iter 100 | Loss: 9.2895 | Train Error: 40.3754 | Val Error : 271.0843 | Test Error: 20.6739 | Dyn var 1.25 | Obs var 100.00
# EM Iter 101 | Loss: 9.1567 | Train Error: 43.1194 | Val Error : 294.7177 | Test Error: 21.9705 | Dyn var 1.25 | Obs var 100.00
# best val error: 0.16726525640906714 at 61th iteration, Model Performance: 0.6556169803608449 | theta_dim = 2
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# theta_dim = 3
# EM Iter 0 | Loss: 62.1347 | Train Error: 0.8691 | Val Error : 0.9860 | Test Error: 0.9217 | Dyn var 1.60 | Obs var 100.00
# EM Iter 1 | Loss: 53.9939 | Train Error: 0.8700 | Val Error : 0.9865 | Test Error: 0.9226 | Dyn var 1.60 | Obs var 100.00
# EM Iter 2 | Loss: 47.9010 | Train Error: 0.8707 | Val Error : 0.9869 | Test Error: 0.9233 | Dyn var 1.60 | Obs var 100.00
# EM Iter 3 | Loss: 43.5418 | Train Error: 0.8712 | Val Error : 0.9872 | Test Error: 0.9237 | Dyn var 1.60 | Obs var 100.00
# EM Iter 4 | Loss: 39.6642 | Train Error: 0.8716 | Val Error : 0.9874 | Test Error: 0.9241 | Dyn var 1.60 | Obs var 100.00
# EM Iter 5 | Loss: 37.6792 | Train Error: 0.8718 | Val Error : 0.9876 | Test Error: 0.9243 | Dyn var 1.60 | Obs var 100.00
# EM Iter 6 | Loss: 35.3391 | Train Error: 0.8720 | Val Error : 0.9877 | Test Error: 0.9245 | Dyn var 1.60 | Obs var 100.00
# EM Iter 7 | Loss: 34.0524 | Train Error: 0.8721 | Val Error : 0.9877 | Test Error: 0.9246 | Dyn var 1.60 | Obs var 100.00
# EM Iter 8 | Loss: 32.3840 | Train Error: 0.8721 | Val Error : 0.9877 | Test Error: 0.9246 | Dyn var 1.60 | Obs var 100.00
# EM Iter 9 | Loss: 31.9984 | Train Error: 0.8720 | Val Error : 0.9877 | Test Error: 0.9245 | Dyn var 1.60 | Obs var 100.00
# EM Iter 10 | Loss: 30.7417 | Train Error: 0.8718 | Val Error : 0.9876 | Test Error: 0.9243 | Dyn var 1.60 | Obs var 100.00
# EM Iter 11 | Loss: 30.3827 | Train Error: 0.8716 | Val Error : 0.9874 | Test Error: 0.9241 | Dyn var 1.60 | Obs var 100.00
# EM Iter 12 | Loss: 29.1455 | Train Error: 0.8712 | Val Error : 0.9872 | Test Error: 0.9237 | Dyn var 1.60 | Obs var 100.00
# EM Iter 13 | Loss: 28.7977 | Train Error: 0.8707 | Val Error : 0.9869 | Test Error: 0.9232 | Dyn var 1.60 | Obs var 100.00
# EM Iter 14 | Loss: 27.5776 | Train Error: 0.8700 | Val Error : 0.9865 | Test Error: 0.9226 | Dyn var 1.60 | Obs var 100.00
# EM Iter 15 | Loss: 27.4609 | Train Error: 0.8693 | Val Error : 0.9861 | Test Error: 0.9219 | Dyn var 1.60 | Obs var 100.00
# EM Iter 16 | Loss: 26.2832 | Train Error: 0.8684 | Val Error : 0.9856 | Test Error: 0.9211 | Dyn var 1.60 | Obs var 100.00
# EM Iter 17 | Loss: 26.3642 | Train Error: 0.8674 | Val Error : 0.9850 | Test Error: 0.9202 | Dyn var 1.60 | Obs var 100.00
# EM Iter 18 | Loss: 25.1816 | Train Error: 0.8663 | Val Error : 0.9843 | Test Error: 0.9191 | Dyn var 1.60 | Obs var 100.00
# EM Iter 19 | Loss: 25.2561 | Train Error: 0.8650 | Val Error : 0.9836 | Test Error: 0.9179 | Dyn var 1.60 | Obs var 100.00
# EM Iter 20 | Loss: 24.0656 | Train Error: 0.8635 | Val Error : 0.9826 | Test Error: 0.9166 | Dyn var 1.60 | Obs var 100.00
# EM Iter 21 | Loss: 24.1309 | Train Error: 0.8618 | Val Error : 0.9817 | Test Error: 0.9151 | Dyn var 1.60 | Obs var 100.00
# EM Iter 22 | Loss: 22.9302 | Train Error: 0.8599 | Val Error : 0.9805 | Test Error: 0.9134 | Dyn var 1.60 | Obs var 100.00
# EM Iter 23 | Loss: 22.9845 | Train Error: 0.8577 | Val Error : 0.9792 | Test Error: 0.9115 | Dyn var 1.60 | Obs var 100.00
# EM Iter 24 | Loss: 22.0320 | Train Error: 0.8552 | Val Error : 0.9777 | Test Error: 0.9094 | Dyn var 1.60 | Obs var 100.00
# EM Iter 25 | Loss: 22.3194 | Train Error: 0.8526 | Val Error : 0.9761 | Test Error: 0.9072 | Dyn var 1.60 | Obs var 100.00
# EM Iter 26 | Loss: 21.3898 | Train Error: 0.8496 | Val Error : 0.9743 | Test Error: 0.9048 | Dyn var 1.60 | Obs var 100.00
# EM Iter 27 | Loss: 21.6701 | Train Error: 0.8464 | Val Error : 0.9723 | Test Error: 0.9022 | Dyn var 1.60 | Obs var 100.00
# EM Iter 28 | Loss: 20.7330 | Train Error: 0.8427 | Val Error : 0.9701 | Test Error: 0.8993 | Dyn var 1.60 | Obs var 100.00
# EM Iter 29 | Loss: 21.1783 | Train Error: 0.8389 | Val Error : 0.9678 | Test Error: 0.8963 | Dyn var 1.60 | Obs var 100.00
# EM Iter 30 | Loss: 20.5227 | Train Error: 0.8346 | Val Error : 0.9652 | Test Error: 0.8931 | Dyn var 1.60 | Obs var 100.00
# EM Iter 31 | Loss: 21.0722 | Train Error: 0.8301 | Val Error : 0.9625 | Test Error: 0.8897 | Dyn var 1.60 | Obs var 100.00
# EM Iter 32 | Loss: 20.4150 | Train Error: 0.8251 | Val Error : 0.9594 | Test Error: 0.8860 | Dyn var 1.60 | Obs var 100.00
# EM Iter 33 | Loss: 20.9628 | Train Error: 0.8198 | Val Error : 0.9563 | Test Error: 0.8822 | Dyn var 1.60 | Obs var 100.00
# EM Iter 34 | Loss: 20.3037 | Train Error: 0.8139 | Val Error : 0.9528 | Test Error: 0.8780 | Dyn var 1.60 | Obs var 100.00
# EM Iter 35 | Loss: 20.8496 | Train Error: 0.8077 | Val Error : 0.9492 | Test Error: 0.8737 | Dyn var 1.60 | Obs var 100.00
# EM Iter 36 | Loss: 20.1886 | Train Error: 0.8008 | Val Error : 0.9451 | Test Error: 0.8688 | Dyn var 1.60 | Obs var 100.00
# EM Iter 37 | Loss: 20.7325 | Train Error: 0.7934 | Val Error : 0.9408 | Test Error: 0.8638 | Dyn var 1.60 | Obs var 100.00
# EM Iter 38 | Loss: 20.0693 | Train Error: 0.7852 | Val Error : 0.9361 | Test Error: 0.8582 | Dyn var 1.60 | Obs var 100.00
# EM Iter 39 | Loss: 20.6111 | Train Error: 0.7765 | Val Error : 0.9312 | Test Error: 0.8523 | Dyn var 1.60 | Obs var 100.00
# EM Iter 40 | Loss: 19.9457 | Train Error: 0.7667 | Val Error : 0.9257 | Test Error: 0.8457 | Dyn var 1.60 | Obs var 100.00
# EM Iter 41 | Loss: 20.4852 | Train Error: 0.7564 | Val Error : 0.9199 | Test Error: 0.8387 | Dyn var 1.60 | Obs var 100.00
# EM Iter 42 | Loss: 19.8176 | Train Error: 0.7447 | Val Error : 0.9135 | Test Error: 0.8308 | Dyn var 1.60 | Obs var 100.00
# EM Iter 43 | Loss: 20.3549 | Train Error: 0.7324 | Val Error : 0.9068 | Test Error: 0.8225 | Dyn var 1.60 | Obs var 100.00
# EM Iter 44 | Loss: 19.6850 | Train Error: 0.7184 | Val Error : 0.8994 | Test Error: 0.8131 | Dyn var 1.60 | Obs var 100.00
# EM Iter 45 | Loss: 20.2199 | Train Error: 0.7036 | Val Error : 0.8916 | Test Error: 0.8030 | Dyn var 1.60 | Obs var 100.00
# EM Iter 46 | Loss: 19.5477 | Train Error: 0.6869 | Val Error : 0.8830 | Test Error: 0.7916 | Dyn var 1.60 | Obs var 100.00
# EM Iter 47 | Loss: 20.0803 | Train Error: 0.6691 | Val Error : 0.8741 | Test Error: 0.7793 | Dyn var 1.60 | Obs var 100.00
# EM Iter 48 | Loss: 19.4058 | Train Error: 0.6492 | Val Error : 0.8641 | Test Error: 0.7653 | Dyn var 1.60 | Obs var 100.00
# EM Iter 49 | Loss: 19.9360 | Train Error: 0.6281 | Val Error : 0.8538 | Test Error: 0.7502 | Dyn var 1.60 | Obs var 100.00
# EM Iter 50 | Loss: 19.2591 | Train Error: 0.6043 | Val Error : 0.8423 | Test Error: 0.7329 | Dyn var 1.60 | Obs var 100.00
# EM Iter 51 | Loss: 19.7870 | Train Error: 0.5796 | Val Error : 0.8305 | Test Error: 0.7143 | Dyn var 1.60 | Obs var 100.00
# EM Iter 52 | Loss: 19.1078 | Train Error: 0.5531 | Val Error : 0.8174 | Test Error: 0.6929 | Dyn var 1.60 | Obs var 100.00
# EM Iter 53 | Loss: 19.6334 | Train Error: 0.5269 | Val Error : 0.8038 | Test Error: 0.6698 | Dyn var 1.60 | Obs var 100.00
# EM Iter 54 | Loss: 18.9518 | Train Error: 0.4996 | Val Error : 0.7888 | Test Error: 0.6433 | Dyn var 1.60 | Obs var 100.00
# EM Iter 55 | Loss: 19.4751 | Train Error: 0.4742 | Val Error : 0.7733 | Test Error: 0.6148 | Dyn var 1.60 | Obs var 100.00
# EM Iter 56 | Loss: 18.7912 | Train Error: 0.4528 | Val Error : 0.7561 | Test Error: 0.5820 | Dyn var 1.60 | Obs var 100.00
# EM Iter 57 | Loss: 19.3122 | Train Error: 0.4391 | Val Error : 0.7384 | Test Error: 0.5468 | Dyn var 1.60 | Obs var 100.00
# EM Iter 58 | Loss: 18.6261 | Train Error: 0.4324 | Val Error : 0.7189 | Test Error: 0.5064 | Dyn var 1.60 | Obs var 100.00
# EM Iter 59 | Loss: 19.1448 | Train Error: 0.4312 | Val Error : 0.6987 | Test Error: 0.4631 | Dyn var 1.60 | Obs var 100.00
# EM Iter 60 | Loss: 18.4564 | Train Error: 0.4369 | Val Error : 0.6762 | Test Error: 0.4136 | Dyn var 1.60 | Obs var 100.00
# EM Iter 61 | Loss: 18.9728 | Train Error: 0.4496 | Val Error : 0.6528 | Test Error: 0.3609 | Dyn var 1.60 | Obs var 100.00
# EM Iter 62 | Loss: 18.2822 | Train Error: 0.4710 | Val Error : 0.6265 | Test Error: 0.3006 | Dyn var 1.60 | Obs var 100.00
# EM Iter 63 | Loss: 18.7964 | Train Error: 0.4997 | Val Error : 0.5986 | Test Error: 0.2367 | Dyn var 1.60 | Obs var 100.00
# EM Iter 64 | Loss: 18.1036 | Train Error: 0.5405 | Val Error : 0.5663 | Test Error: 0.1656 | Dyn var 1.60 | Obs var 100.00
# EM Iter 65 | Loss: 18.6156 | Train Error: 0.5914 | Val Error : 0.5309 | Test Error: 0.1181 | Dyn var 1.60 | Obs var 100.00
# EM Iter 66 | Loss: 17.9206 | Train Error: 0.6580 | Val Error : 0.4883 | Test Error: 0.1198 | Dyn var 1.60 | Obs var 100.00
# EM Iter 67 | Loss: 18.4305 | Train Error: 0.7353 | Val Error : 0.4433 | Test Error: 0.1642 | Dyn var 1.60 | Obs var 100.00
# EM Iter 68 | Loss: 17.7334 | Train Error: 0.8286 | Val Error : 0.4168 | Test Error: 0.2357 | Dyn var 1.60 | Obs var 100.00
# EM Iter 69 | Loss: 18.2411 | Train Error: 0.9337 | Val Error : 0.3790 | Test Error: 0.3185 | Dyn var 1.60 | Obs var 100.00
# EM Iter 70 | Loss: 17.5419 | Train Error: 1.0587 | Val Error : 0.3216 | Test Error: 0.4248 | Dyn var 1.60 | Obs var 100.00
# EM Iter 71 | Loss: 18.0475 | Train Error: 1.1972 | Val Error : 0.2426 | Test Error: 0.5516 | Dyn var 1.60 | Obs var 100.00
# EM Iter 72 | Loss: 17.3462 | Train Error: 1.3611 | Val Error : 0.1440 | Test Error: 0.6941 | Dyn var 1.60 | Obs var 100.00
# EM Iter 73 | Loss: 17.8498 | Train Error: 1.5402 | Val Error : 0.2744 | Test Error: 0.8417 | Dyn var 1.60 | Obs var 100.00
# EM Iter 74 | Loss: 17.1465 | Train Error: 1.7503 | Val Error : 0.5413 | Test Error: 1.0072 | Dyn var 1.60 | Obs var 100.00
# EM Iter 75 | Loss: 17.6480 | Train Error: 1.9753 | Val Error : 0.8696 | Test Error: 1.1780 | Dyn var 1.60 | Obs var 100.00
# EM Iter 76 | Loss: 16.9427 | Train Error: 2.2369 | Val Error : 1.3040 | Test Error: 1.3690 | Dyn var 1.60 | Obs var 100.00
# EM Iter 77 | Loss: 17.4422 | Train Error: 2.5148 | Val Error : 1.8294 | Test Error: 1.5653 | Dyn var 1.60 | Obs var 100.00
# EM Iter 78 | Loss: 16.7349 | Train Error: 2.8318 | Val Error : 2.5125 | Test Error: 1.7845 | Dyn var 1.60 | Obs var 100.00
# EM Iter 79 | Loss: 17.2324 | Train Error: 3.1637 | Val Error : 3.3222 | Test Error: 2.0090 | Dyn var 1.60 | Obs var 100.00
# EM Iter 80 | Loss: 16.5232 | Train Error: 3.5417 | Val Error : 4.3553 | Test Error: 2.2592 | Dyn var 1.60 | Obs var 100.00
# EM Iter 81 | Loss: 17.0187 | Train Error: 3.9381 | Val Error : 5.5548 | Test Error: 2.5147 | Dyn var 1.60 | Obs var 100.00
# EM Iter 82 | Loss: 16.3076 | Train Error: 4.3879 | Val Error : 7.0569 | Test Error: 2.7991 | Dyn var 1.60 | Obs var 100.00
# EM Iter 83 | Loss: 16.8012 | Train Error: 4.8556 | Val Error : 8.7667 | Test Error: 3.0886 | Dyn var 1.60 | Obs var 100.00
# EM Iter 84 | Loss: 16.0883 | Train Error: 5.3849 | Val Error : 10.8717 | Test Error: 3.4106 | Dyn var 1.60 | Obs var 100.00
# EM Iter 85 | Loss: 16.5799 | Train Error: 5.9339 | Val Error : 13.2245 | Test Error: 3.7375 | Dyn var 1.60 | Obs var 100.00
# EM Iter 86 | Loss: 15.8652 | Train Error: 6.5540 | Val Error : 16.0771 | Test Error: 4.1009 | Dyn var 1.60 | Obs var 100.00
# EM Iter 87 | Loss: 16.3549 | Train Error: 7.1957 | Val Error : 19.2137 | Test Error: 4.4687 | Dyn var 1.60 | Obs var 100.00
# EM Iter 88 | Loss: 15.6384 | Train Error: 7.9184 | Val Error : 22.9660 | Test Error: 4.8777 | Dyn var 1.60 | Obs var 100.00
# EM Iter 89 | Loss: 16.1262 | Train Error: 8.6625 | Val Error : 27.0325 | Test Error: 5.2904 | Dyn var 1.60 | Obs var 100.00
# EM Iter 90 | Loss: 15.4080 | Train Error: 9.4988 | Val Error : 31.8416 | Test Error: 5.7495 | Dyn var 1.60 | Obs var 100.00
# EM Iter 91 | Loss: 15.8940 | Train Error: 10.3576 | Val Error : 36.9869 | Test Error: 6.2115 | Dyn var 1.60 | Obs var 100.00
# EM Iter 92 | Loss: 15.1741 | Train Error: 11.3215 | Val Error : 43.0124 | Test Error: 6.7257 | Dyn var 1.60 | Obs var 100.00
# EM Iter 93 | Loss: 15.6581 | Train Error: 12.3087 | Val Error : 49.3876 | Test Error: 7.2418 | Dyn var 1.60 | Obs var 100.00
# EM Iter 94 | Loss: 14.9366 | Train Error: 13.4140 | Val Error : 56.7918 | Test Error: 7.8168 | Dyn var 1.60 | Obs var 100.00
# EM Iter 95 | Loss: 15.4188 | Train Error: 14.5432 | Val Error : 64.5495 | Test Error: 8.3921 | Dyn var 1.60 | Obs var 100.00
# EM Iter 96 | Loss: 14.6956 | Train Error: 15.8051 | Val Error : 73.4972 | Test Error: 9.0339 | Dyn var 1.60 | Obs var 100.00
# EM Iter 97 | Loss: 15.1760 | Train Error: 17.0917 | Val Error : 82.7930 | Test Error: 9.6742 | Dyn var 1.60 | Obs var 100.00
# EM Iter 98 | Loss: 14.4513 | Train Error: 18.5265 | Val Error : 93.4525 | Test Error: 10.3897 | Dyn var 1.60 | Obs var 100.00
# EM Iter 99 | Loss: 14.9298 | Train Error: 19.9868 | Val Error : 104.4462 | Test Error: 11.1012 | Dyn var 1.60 | Obs var 100.00
# EM Iter 100 | Loss: 14.2035 | Train Error: 21.6118 | Val Error : 116.9909 | Test Error: 11.8978 | Dyn var 1.60 | Obs var 100.00
# EM Iter 101 | Loss: 14.6803 | Train Error: 23.2633 | Val Error : 129.8483 | Test Error: 12.6872 | Dyn var 1.60 | Obs var 100.00
# EM Iter 102 | Loss: 13.9524 | Train Error: 25.0972 | Val Error : 144.4589 | Test Error: 13.5732 | Dyn var 1.60 | Obs var 100.00
# EM Iter 103 | Loss: 14.4274 | Train Error: 26.9589 | Val Error : 159.3539 | Test Error: 14.4478 | Dyn var 1.60 | Obs var 100.00
# EM Iter 104 | Loss: 13.6980 | Train Error: 29.0216 | Val Error : 176.2199 | Test Error: 15.4320 | Dyn var 1.60 | Obs var 100.00
# EM Iter 105 | Loss: 14.1713 | Train Error: 31.1139 | Val Error : 193.3367 | Test Error: 16.3997 | Dyn var 1.60 | Obs var 100.00
# EM Iter 106 | Loss: 13.4403 | Train Error: 33.4267 | Val Error : 212.6583 | Test Error: 17.4918 | Dyn var 1.60 | Obs var 100.00
# EM Iter 107 | Loss: 13.9119 | Train Error: 35.7717 | Val Error : 232.1932 | Test Error: 18.5609 | Dyn var 1.60 | Obs var 100.00
# EM Iter 108 | Loss: 13.1794 | Train Error: 38.3572 | Val Error : 254.1825 | Test Error: 19.7715 | Dyn var 1.60 | Obs var 100.00
# EM Iter 109 | Loss: 13.6492 | Train Error: 40.9787 | Val Error : 276.3459 | Test Error: 20.9508 | Dyn var 1.60 | Obs var 100.00
# EM Iter 110 | Loss: 12.9152 | Train Error: 43.8610 | Val Error : 301.2279 | Test Error: 22.2912 | Dyn var 1.60 | Obs var 100.00
# EM Iter 111 | Loss: 13.3834 | Train Error: 46.7846 | Val Error : 326.2455 | Test Error: 23.5899 | Dyn var 1.60 | Obs var 100.00
# EM Iter 112 | Loss: 12.6479 | Train Error: 49.9892 | Val Error : 354.2587 | Test Error: 25.0721 | Dyn var 1.60 | Obs var 100.00
# best val error: 0.14400034879973667 at 72th iteration, Model Performance: 0.6940637501126333 | theta_dim = 3
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# theta_dim = 4
# EM Iter 0 | Loss: 82.1738 | Train Error: 0.8802 | Val Error : 0.9923 | Test Error: 0.9328 | Dyn var 1.88 | Obs var 100.00
# EM Iter 1 | Loss: 69.5930 | Train Error: 0.8811 | Val Error : 0.9928 | Test Error: 0.9338 | Dyn var 1.88 | Obs var 100.00
# EM Iter 2 | Loss: 61.8169 | Train Error: 0.8818 | Val Error : 0.9931 | Test Error: 0.9345 | Dyn var 1.88 | Obs var 100.00
# EM Iter 3 | Loss: 55.2299 | Train Error: 0.8822 | Val Error : 0.9933 | Test Error: 0.9349 | Dyn var 1.88 | Obs var 100.00
# EM Iter 4 | Loss: 51.3578 | Train Error: 0.8825 | Val Error : 0.9935 | Test Error: 0.9353 | Dyn var 1.88 | Obs var 100.00
# EM Iter 5 | Loss: 47.5901 | Train Error: 0.8827 | Val Error : 0.9936 | Test Error: 0.9355 | Dyn var 1.88 | Obs var 100.00
# EM Iter 6 | Loss: 45.6748 | Train Error: 0.8828 | Val Error : 0.9937 | Test Error: 0.9356 | Dyn var 1.88 | Obs var 100.00
# EM Iter 7 | Loss: 43.7950 | Train Error: 0.8829 | Val Error : 0.9937 | Test Error: 0.9357 | Dyn var 1.88 | Obs var 100.00
# EM Iter 8 | Loss: 43.0883 | Train Error: 0.8829 | Val Error : 0.9937 | Test Error: 0.9357 | Dyn var 1.88 | Obs var 100.00
# EM Iter 9 | Loss: 41.3002 | Train Error: 0.8828 | Val Error : 0.9936 | Test Error: 0.9356 | Dyn var 1.88 | Obs var 100.00
# EM Iter 10 | Loss: 40.6544 | Train Error: 0.8826 | Val Error : 0.9935 | Test Error: 0.9354 | Dyn var 1.88 | Obs var 100.00
# EM Iter 11 | Loss: 38.9055 | Train Error: 0.8823 | Val Error : 0.9934 | Test Error: 0.9351 | Dyn var 1.88 | Obs var 100.00
# EM Iter 12 | Loss: 38.3400 | Train Error: 0.8820 | Val Error : 0.9932 | Test Error: 0.9347 | Dyn var 1.88 | Obs var 100.00
# EM Iter 13 | Loss: 36.9758 | Train Error: 0.8816 | Val Error : 0.9930 | Test Error: 0.9342 | Dyn var 1.88 | Obs var 100.00
# EM Iter 14 | Loss: 36.4766 | Train Error: 0.8811 | Val Error : 0.9927 | Test Error: 0.9337 | Dyn var 1.88 | Obs var 100.00
# EM Iter 15 | Loss: 35.1149 | Train Error: 0.8805 | Val Error : 0.9924 | Test Error: 0.9331 | Dyn var 1.88 | Obs var 100.00
# EM Iter 16 | Loss: 34.8367 | Train Error: 0.8798 | Val Error : 0.9921 | Test Error: 0.9324 | Dyn var 1.88 | Obs var 100.00
# EM Iter 17 | Loss: 33.5365 | Train Error: 0.8790 | Val Error : 0.9917 | Test Error: 0.9316 | Dyn var 1.88 | Obs var 100.00
# EM Iter 18 | Loss: 33.4550 | Train Error: 0.8782 | Val Error : 0.9912 | Test Error: 0.9307 | Dyn var 1.88 | Obs var 100.00
# EM Iter 19 | Loss: 32.1474 | Train Error: 0.8772 | Val Error : 0.9907 | Test Error: 0.9297 | Dyn var 1.88 | Obs var 100.00
# EM Iter 20 | Loss: 32.0564 | Train Error: 0.8761 | Val Error : 0.9900 | Test Error: 0.9286 | Dyn var 1.88 | Obs var 100.00
# EM Iter 21 | Loss: 30.7378 | Train Error: 0.8749 | Val Error : 0.9893 | Test Error: 0.9273 | Dyn var 1.88 | Obs var 100.00
# EM Iter 22 | Loss: 30.6344 | Train Error: 0.8735 | Val Error : 0.9885 | Test Error: 0.9259 | Dyn var 1.88 | Obs var 100.00
# EM Iter 23 | Loss: 29.5105 | Train Error: 0.8720 | Val Error : 0.9877 | Test Error: 0.9244 | Dyn var 1.88 | Obs var 100.00
# EM Iter 24 | Loss: 29.4489 | Train Error: 0.8702 | Val Error : 0.9866 | Test Error: 0.9228 | Dyn var 1.88 | Obs var 100.00
# EM Iter 25 | Loss: 28.3186 | Train Error: 0.8683 | Val Error : 0.9855 | Test Error: 0.9210 | Dyn var 1.88 | Obs var 100.00
# EM Iter 26 | Loss: 28.6637 | Train Error: 0.8662 | Val Error : 0.9843 | Test Error: 0.9190 | Dyn var 1.88 | Obs var 100.00
# EM Iter 27 | Loss: 27.7575 | Train Error: 0.8639 | Val Error : 0.9829 | Test Error: 0.9169 | Dyn var 1.88 | Obs var 100.00
# EM Iter 28 | Loss: 28.2567 | Train Error: 0.8615 | Val Error : 0.9814 | Test Error: 0.9148 | Dyn var 1.88 | Obs var 100.00
# EM Iter 29 | Loss: 27.3457 | Train Error: 0.8588 | Val Error : 0.9798 | Test Error: 0.9124 | Dyn var 1.88 | Obs var 100.00
# EM Iter 30 | Loss: 27.8399 | Train Error: 0.8559 | Val Error : 0.9781 | Test Error: 0.9100 | Dyn var 1.88 | Obs var 100.00
# EM Iter 31 | Loss: 26.9237 | Train Error: 0.8527 | Val Error : 0.9761 | Test Error: 0.9073 | Dyn var 1.88 | Obs var 100.00
# EM Iter 32 | Loss: 27.6474 | Train Error: 0.8494 | Val Error : 0.9741 | Test Error: 0.9046 | Dyn var 1.88 | Obs var 100.00
# EM Iter 33 | Loss: 26.7846 | Train Error: 0.8457 | Val Error : 0.9719 | Test Error: 0.9016 | Dyn var 1.88 | Obs var 100.00
# EM Iter 34 | Loss: 27.5059 | Train Error: 0.8418 | Val Error : 0.9695 | Test Error: 0.8985 | Dyn var 1.88 | Obs var 100.00
# EM Iter 35 | Loss: 26.6406 | Train Error: 0.8375 | Val Error : 0.9669 | Test Error: 0.8952 | Dyn var 1.88 | Obs var 100.00
# EM Iter 36 | Loss: 27.3593 | Train Error: 0.8328 | Val Error : 0.9641 | Test Error: 0.8918 | Dyn var 1.88 | Obs var 100.00
# EM Iter 37 | Loss: 26.4912 | Train Error: 0.8278 | Val Error : 0.9611 | Test Error: 0.8880 | Dyn var 1.88 | Obs var 100.00
# EM Iter 38 | Loss: 27.2071 | Train Error: 0.8223 | Val Error : 0.9578 | Test Error: 0.8840 | Dyn var 1.88 | Obs var 100.00
# EM Iter 39 | Loss: 26.3362 | Train Error: 0.8164 | Val Error : 0.9543 | Test Error: 0.8798 | Dyn var 1.88 | Obs var 100.00
# EM Iter 40 | Loss: 27.0492 | Train Error: 0.8099 | Val Error : 0.9505 | Test Error: 0.8752 | Dyn var 1.88 | Obs var 100.00
# EM Iter 41 | Loss: 26.1752 | Train Error: 0.8028 | Val Error : 0.9463 | Test Error: 0.8703 | Dyn var 1.88 | Obs var 100.00
# EM Iter 42 | Loss: 26.8852 | Train Error: 0.7952 | Val Error : 0.9418 | Test Error: 0.8650 | Dyn var 1.88 | Obs var 100.00
# EM Iter 43 | Loss: 26.0082 | Train Error: 0.7867 | Val Error : 0.9370 | Test Error: 0.8592 | Dyn var 1.88 | Obs var 100.00
# EM Iter 44 | Loss: 26.7151 | Train Error: 0.7776 | Val Error : 0.9318 | Test Error: 0.8530 | Dyn var 1.88 | Obs var 100.00
# EM Iter 45 | Loss: 25.8350 | Train Error: 0.7675 | Val Error : 0.9261 | Test Error: 0.8461 | Dyn var 1.88 | Obs var 100.00
# EM Iter 46 | Loss: 26.5387 | Train Error: 0.7565 | Val Error : 0.9199 | Test Error: 0.8388 | Dyn var 1.88 | Obs var 100.00
# EM Iter 47 | Loss: 25.6555 | Train Error: 0.7443 | Val Error : 0.9133 | Test Error: 0.8306 | Dyn var 1.88 | Obs var 100.00
# EM Iter 48 | Loss: 26.3561 | Train Error: 0.7311 | Val Error : 0.9062 | Test Error: 0.8217 | Dyn var 1.88 | Obs var 100.00
# EM Iter 49 | Loss: 25.4697 | Train Error: 0.7166 | Val Error : 0.8984 | Test Error: 0.8118 | Dyn var 1.88 | Obs var 100.00
# EM Iter 50 | Loss: 26.1671 | Train Error: 0.7006 | Val Error : 0.8901 | Test Error: 0.8010 | Dyn var 1.88 | Obs var 100.00
# EM Iter 51 | Loss: 25.2776 | Train Error: 0.6830 | Val Error : 0.8811 | Test Error: 0.7889 | Dyn var 1.88 | Obs var 100.00
# EM Iter 52 | Loss: 25.9718 | Train Error: 0.6638 | Val Error : 0.8714 | Test Error: 0.7756 | Dyn var 1.88 | Obs var 100.00
# EM Iter 53 | Loss: 25.0792 | Train Error: 0.6428 | Val Error : 0.8610 | Test Error: 0.7607 | Dyn var 1.88 | Obs var 100.00
# EM Iter 54 | Loss: 25.7703 | Train Error: 0.6198 | Val Error : 0.8498 | Test Error: 0.7442 | Dyn var 1.88 | Obs var 100.00
# EM Iter 55 | Loss: 24.8745 | Train Error: 0.5947 | Val Error : 0.8377 | Test Error: 0.7257 | Dyn var 1.88 | Obs var 100.00
# EM Iter 56 | Loss: 25.5625 | Train Error: 0.5681 | Val Error : 0.8248 | Test Error: 0.7052 | Dyn var 1.88 | Obs var 100.00
# EM Iter 57 | Loss: 24.6636 | Train Error: 0.5405 | Val Error : 0.8109 | Test Error: 0.6821 | Dyn var 1.88 | Obs var 100.00
# EM Iter 58 | Loss: 25.3485 | Train Error: 0.5128 | Val Error : 0.7962 | Test Error: 0.6565 | Dyn var 1.88 | Obs var 100.00
# EM Iter 59 | Loss: 24.4465 | Train Error: 0.4852 | Val Error : 0.7802 | Test Error: 0.6278 | Dyn var 1.88 | Obs var 100.00
# EM Iter 60 | Loss: 25.1284 | Train Error: 0.4608 | Val Error : 0.7633 | Test Error: 0.5959 | Dyn var 1.88 | Obs var 100.00
# EM Iter 61 | Loss: 24.2234 | Train Error: 0.4432 | Val Error : 0.7451 | Test Error: 0.5602 | Dyn var 1.88 | Obs var 100.00
# EM Iter 62 | Loss: 24.9022 | Train Error: 0.4340 | Val Error : 0.7257 | Test Error: 0.5207 | Dyn var 1.88 | Obs var 100.00
# EM Iter 63 | Loss: 23.9942 | Train Error: 0.4309 | Val Error : 0.7049 | Test Error: 0.4765 | Dyn var 1.88 | Obs var 100.00
# EM Iter 64 | Loss: 24.6701 | Train Error: 0.4345 | Val Error : 0.6826 | Test Error: 0.4278 | Dyn var 1.88 | Obs var 100.00
# EM Iter 65 | Loss: 23.7591 | Train Error: 0.4460 | Val Error : 0.6584 | Test Error: 0.3736 | Dyn var 1.88 | Obs var 100.00
# EM Iter 66 | Loss: 24.4321 | Train Error: 0.4658 | Val Error : 0.6323 | Test Error: 0.3139 | Dyn var 1.88 | Obs var 100.00
# EM Iter 67 | Loss: 23.5182 | Train Error: 0.4942 | Val Error : 0.6035 | Test Error: 0.2479 | Dyn var 1.88 | Obs var 100.00
# EM Iter 68 | Loss: 24.1883 | Train Error: 0.5335 | Val Error : 0.5714 | Test Error: 0.1754 | Dyn var 1.88 | Obs var 100.00
# EM Iter 69 | Loss: 23.2716 | Train Error: 0.5854 | Val Error : 0.5349 | Test Error: 0.1216 | Dyn var 1.88 | Obs var 100.00
# EM Iter 70 | Loss: 23.9388 | Train Error: 0.6511 | Val Error : 0.4926 | Test Error: 0.1158 | Dyn var 1.88 | Obs var 100.00
# EM Iter 71 | Loss: 23.0192 | Train Error: 0.7313 | Val Error : 0.4442 | Test Error: 0.1620 | Dyn var 1.88 | Obs var 100.00
# EM Iter 72 | Loss: 23.6836 | Train Error: 0.8248 | Val Error : 0.4180 | Test Error: 0.2327 | Dyn var 1.88 | Obs var 100.00
# EM Iter 73 | Loss: 22.7613 | Train Error: 0.9347 | Val Error : 0.3786 | Test Error: 0.3192 | Dyn var 1.88 | Obs var 100.00
# EM Iter 74 | Loss: 23.4230 | Train Error: 1.0608 | Val Error : 0.3205 | Test Error: 0.4268 | Dyn var 1.88 | Obs var 100.00
# EM Iter 75 | Loss: 22.4979 | Train Error: 1.2065 | Val Error : 0.2367 | Test Error: 0.5599 | Dyn var 1.88 | Obs var 100.00
# EM Iter 76 | Loss: 23.1568 | Train Error: 1.3729 | Val Error : 0.1377 | Test Error: 0.7040 | Dyn var 1.88 | Obs var 100.00
# EM Iter 77 | Loss: 22.2291 | Train Error: 1.5622 | Val Error : 0.3007 | Test Error: 0.8594 | Dyn var 1.88 | Obs var 100.00
# EM Iter 78 | Loss: 22.8853 | Train Error: 1.7763 | Val Error : 0.5770 | Test Error: 1.0273 | Dyn var 1.88 | Obs var 100.00
# EM Iter 79 | Loss: 21.9549 | Train Error: 2.0148 | Val Error : 0.9319 | Test Error: 1.2074 | Dyn var 1.88 | Obs var 100.00
# EM Iter 80 | Loss: 22.6085 | Train Error: 2.2825 | Val Error : 1.3856 | Test Error: 1.4016 | Dyn var 1.88 | Obs var 100.00
# EM Iter 81 | Loss: 21.6755 | Train Error: 2.5775 | Val Error : 1.9576 | Test Error: 1.6090 | Dyn var 1.88 | Obs var 100.00
# EM Iter 82 | Loss: 22.3265 | Train Error: 2.9018 | Val Error : 2.6757 | Test Error: 1.8323 | Dyn var 1.88 | Obs var 100.00
# EM Iter 83 | Loss: 21.3910 | Train Error: 3.2548 | Val Error : 3.5615 | Test Error: 2.0699 | Dyn var 1.88 | Obs var 100.00
# EM Iter 84 | Loss: 22.0394 | Train Error: 3.6431 | Val Error : 4.6519 | Test Error: 2.3254 | Dyn var 1.88 | Obs var 100.00
# EM Iter 85 | Loss: 21.1014 | Train Error: 4.0658 | Val Error : 5.9676 | Test Error: 2.5960 | Dyn var 1.88 | Obs var 100.00
# EM Iter 86 | Loss: 21.7472 | Train Error: 4.5283 | Val Error : 7.5565 | Test Error: 2.8869 | Dyn var 1.88 | Obs var 100.00
# EM Iter 87 | Loss: 20.8068 | Train Error: 5.0277 | Val Error : 9.4345 | Test Error: 3.1940 | Dyn var 1.88 | Obs var 100.00
# EM Iter 88 | Loss: 21.4501 | Train Error: 5.5731 | Val Error : 11.6628 | Test Error: 3.5239 | Dyn var 1.88 | Obs var 100.00
# EM Iter 89 | Loss: 20.5073 | Train Error: 6.1601 | Val Error : 14.2474 | Test Error: 3.8708 | Dyn var 1.88 | Obs var 100.00
# EM Iter 90 | Loss: 21.1481 | Train Error: 6.8007 | Val Error : 17.2668 | Test Error: 4.2439 | Dyn var 1.88 | Obs var 100.00
# EM Iter 91 | Loss: 20.2029 | Train Error: 7.4876 | Val Error : 20.7106 | Test Error: 4.6346 | Dyn var 1.88 | Obs var 100.00
# EM Iter 92 | Loss: 20.8413 | Train Error: 8.2345 | Val Error : 24.6794 | Test Error: 5.0550 | Dyn var 1.88 | Obs var 100.00
# EM Iter 93 | Loss: 19.8938 | Train Error: 9.0317 | Val Error : 29.1398 | Test Error: 5.4937 | Dyn var 1.88 | Obs var 100.00
# EM Iter 94 | Loss: 20.5297 | Train Error: 9.8973 | Val Error : 34.2203 | Test Error: 5.9665 | Dyn var 1.88 | Obs var 100.00
# EM Iter 95 | Loss: 19.5799 | Train Error: 10.8184 | Val Error : 39.8575 | Test Error: 6.4578 | Dyn var 1.88 | Obs var 100.00
# EM Iter 96 | Loss: 20.2135 | Train Error: 11.8172 | Val Error : 46.2146 | Test Error: 6.9882 | Dyn var 1.88 | Obs var 100.00
# EM Iter 97 | Loss: 19.2615 | Train Error: 12.8763 | Val Error : 53.1906 | Test Error: 7.5374 | Dyn var 1.88 | Obs var 100.00
# EM Iter 98 | Loss: 19.8927 | Train Error: 14.0228 | Val Error : 60.9910 | Test Error: 8.1314 | Dyn var 1.88 | Obs var 100.00
# EM Iter 99 | Loss: 18.9384 | Train Error: 15.2350 | Val Error : 69.4697 | Test Error: 8.7438 | Dyn var 1.88 | Obs var 100.00
# EM Iter 100 | Loss: 19.5673 | Train Error: 16.5451 | Val Error : 78.8830 | Test Error: 9.4081 | Dyn var 1.88 | Obs var 100.00
# EM Iter 101 | Loss: 18.6108 | Train Error: 17.9266 | Val Error : 89.0313 | Test Error: 10.0899 | Dyn var 1.88 | Obs var 100.00
# EM Iter 102 | Loss: 19.2374 | Train Error: 19.4175 | Val Error : 100.2314 | Test Error: 10.8317 | Dyn var 1.88 | Obs var 100.00
# EM Iter 103 | Loss: 18.2788 | Train Error: 20.9857 | Val Error : 112.2207 | Test Error: 11.5895 | Dyn var 1.88 | Obs var 100.00
# EM Iter 104 | Loss: 18.9031 | Train Error: 22.6758 | Val Error : 125.3877 | Test Error: 12.4169 | Dyn var 1.88 | Obs var 100.00
# EM Iter 105 | Loss: 17.9423 | Train Error: 24.4493 | Val Error : 139.3963 | Test Error: 13.2578 | Dyn var 1.88 | Obs var 100.00
# EM Iter 106 | Loss: 18.5644 | Train Error: 26.3585 | Val Error : 154.7189 | Test Error: 14.1796 | Dyn var 1.88 | Obs var 100.00
# EM Iter 107 | Loss: 17.6014 | Train Error: 28.3574 | Val Error : 170.9331 | Test Error: 15.1114 | Dyn var 1.88 | Obs var 100.00
# EM Iter 108 | Loss: 18.2214 | Train Error: 30.5070 | Val Error : 188.6115 | Test Error: 16.1372 | Dyn var 1.88 | Obs var 100.00
# EM Iter 109 | Loss: 17.2562 | Train Error: 32.7526 | Val Error : 207.2281 | Test Error: 17.1681 | Dyn var 1.88 | Obs var 100.00
# EM Iter 110 | Loss: 17.8741 | Train Error: 35.1658 | Val Error : 227.4758 | Test Error: 18.3086 | Dyn var 1.88 | Obs var 100.00
# EM Iter 111 | Loss: 16.9067 | Train Error: 37.6810 | Val Error : 248.7031 | Test Error: 19.4472 | Dyn var 1.88 | Obs var 100.00
# EM Iter 112 | Loss: 17.5224 | Train Error: 40.3825 | Val Error : 271.7497 | Test Error: 20.7137 | Dyn var 1.88 | Obs var 100.00
# EM Iter 113 | Loss: 16.5530 | Train Error: 43.1916 | Val Error : 295.8086 | Test Error: 21.9692 | Dyn var 1.88 | Obs var 100.00
# EM Iter 114 | Loss: 17.1666 | Train Error: 46.2083 | Val Error : 321.9012 | Test Error: 23.3741 | Dyn var 1.88 | Obs var 100.00
# EM Iter 115 | Loss: 16.1950 | Train Error: 49.3371 | Val Error : 349.0252 | Test Error: 24.7559 | Dyn var 1.88 | Obs var 100.00
# EM Iter 116 | Loss: 16.8065 | Train Error: 52.6975 | Val Error : 378.4301 | Test Error: 26.3122 | Dyn var 1.88 | Obs var 100.00
# best val error: 0.13771480378258993 at 76th iteration, Model Performance: 0.7040231480722415 | theta_dim = 4
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# theta_dim = 5
# EM Iter 0 | Loss: 104.2525 | Train Error: 0.8941 | Val Error : 0.9984 | Test Error: 0.9490 | Dyn var 2.13 | Obs var 100.00
# EM Iter 1 | Loss: 86.9304 | Train Error: 0.8950 | Val Error : 0.9987 | Test Error: 0.9502 | Dyn var 2.13 | Obs var 100.00
# EM Iter 2 | Loss: 75.6449 | Train Error: 0.8957 | Val Error : 0.9989 | Test Error: 0.9511 | Dyn var 2.13 | Obs var 100.00
# EM Iter 3 | Loss: 67.5373 | Train Error: 0.8961 | Val Error : 0.9990 | Test Error: 0.9517 | Dyn var 2.13 | Obs var 100.00
# EM Iter 4 | Loss: 62.0567 | Train Error: 0.8965 | Val Error : 0.9991 | Test Error: 0.9522 | Dyn var 2.13 | Obs var 100.00
# EM Iter 5 | Loss: 58.1866 | Train Error: 0.8968 | Val Error : 0.9991 | Test Error: 0.9526 | Dyn var 2.13 | Obs var 100.00
# EM Iter 6 | Loss: 55.7012 | Train Error: 0.8970 | Val Error : 0.9992 | Test Error: 0.9529 | Dyn var 2.13 | Obs var 100.00
# EM Iter 7 | Loss: 52.9458 | Train Error: 0.8971 | Val Error : 0.9992 | Test Error: 0.9530 | Dyn var 2.13 | Obs var 100.00
# EM Iter 8 | Loss: 50.8111 | Train Error: 0.8971 | Val Error : 0.9992 | Test Error: 0.9531 | Dyn var 2.13 | Obs var 100.00
# EM Iter 9 | Loss: 48.5814 | Train Error: 0.8971 | Val Error : 0.9992 | Test Error: 0.9531 | Dyn var 2.13 | Obs var 100.00
# EM Iter 10 | Loss: 46.9877 | Train Error: 0.8971 | Val Error : 0.9992 | Test Error: 0.9530 | Dyn var 2.13 | Obs var 100.00
# EM Iter 11 | Loss: 44.9241 | Train Error: 0.8969 | Val Error : 0.9992 | Test Error: 0.9528 | Dyn var 2.13 | Obs var 100.00
# EM Iter 12 | Loss: 43.7725 | Train Error: 0.8967 | Val Error : 0.9991 | Test Error: 0.9525 | Dyn var 2.13 | Obs var 100.00
# EM Iter 13 | Loss: 41.8017 | Train Error: 0.8964 | Val Error : 0.9991 | Test Error: 0.9521 | Dyn var 2.13 | Obs var 100.00
# EM Iter 14 | Loss: 40.9945 | Train Error: 0.8961 | Val Error : 0.9990 | Test Error: 0.9516 | Dyn var 2.13 | Obs var 100.00
# EM Iter 15 | Loss: 39.2443 | Train Error: 0.8956 | Val Error : 0.9989 | Test Error: 0.9511 | Dyn var 2.13 | Obs var 100.00
# EM Iter 16 | Loss: 39.0118 | Train Error: 0.8952 | Val Error : 0.9987 | Test Error: 0.9504 | Dyn var 2.13 | Obs var 100.00
# EM Iter 17 | Loss: 37.4470 | Train Error: 0.8946 | Val Error : 0.9986 | Test Error: 0.9497 | Dyn var 2.13 | Obs var 100.00
# EM Iter 18 | Loss: 37.6747 | Train Error: 0.8940 | Val Error : 0.9984 | Test Error: 0.9489 | Dyn var 2.13 | Obs var 100.00
# EM Iter 19 | Loss: 36.2807 | Train Error: 0.8933 | Val Error : 0.9982 | Test Error: 0.9480 | Dyn var 2.13 | Obs var 100.00
# EM Iter 20 | Loss: 36.5028 | Train Error: 0.8926 | Val Error : 0.9979 | Test Error: 0.9471 | Dyn var 2.13 | Obs var 100.00
# EM Iter 21 | Loss: 35.3494 | Train Error: 0.8917 | Val Error : 0.9976 | Test Error: 0.9460 | Dyn var 2.13 | Obs var 100.00
# EM Iter 22 | Loss: 36.2035 | Train Error: 0.8909 | Val Error : 0.9973 | Test Error: 0.9449 | Dyn var 2.13 | Obs var 100.00
# EM Iter 23 | Loss: 35.1975 | Train Error: 0.8899 | Val Error : 0.9969 | Test Error: 0.9438 | Dyn var 2.13 | Obs var 100.00
# EM Iter 24 | Loss: 36.0523 | Train Error: 0.8889 | Val Error : 0.9965 | Test Error: 0.9426 | Dyn var 2.13 | Obs var 100.00
# EM Iter 25 | Loss: 35.0464 | Train Error: 0.8879 | Val Error : 0.9961 | Test Error: 0.9413 | Dyn var 2.13 | Obs var 100.00
# EM Iter 26 | Loss: 35.9007 | Train Error: 0.8868 | Val Error : 0.9956 | Test Error: 0.9400 | Dyn var 2.13 | Obs var 100.00
# EM Iter 27 | Loss: 34.8938 | Train Error: 0.8855 | Val Error : 0.9950 | Test Error: 0.9386 | Dyn var 2.13 | Obs var 100.00
# EM Iter 28 | Loss: 35.7467 | Train Error: 0.8843 | Val Error : 0.9944 | Test Error: 0.9372 | Dyn var 2.13 | Obs var 100.00
# EM Iter 29 | Loss: 34.7381 | Train Error: 0.8829 | Val Error : 0.9937 | Test Error: 0.9357 | Dyn var 2.13 | Obs var 100.00
# EM Iter 30 | Loss: 35.5890 | Train Error: 0.8815 | Val Error : 0.9930 | Test Error: 0.9341 | Dyn var 2.13 | Obs var 100.00
# EM Iter 31 | Loss: 34.5781 | Train Error: 0.8799 | Val Error : 0.9921 | Test Error: 0.9325 | Dyn var 2.13 | Obs var 100.00
# EM Iter 32 | Loss: 35.4264 | Train Error: 0.8783 | Val Error : 0.9912 | Test Error: 0.9307 | Dyn var 2.13 | Obs var 100.00
# EM Iter 33 | Loss: 34.4127 | Train Error: 0.8764 | Val Error : 0.9902 | Test Error: 0.9289 | Dyn var 2.13 | Obs var 100.00
# EM Iter 34 | Loss: 35.2580 | Train Error: 0.8746 | Val Error : 0.9892 | Test Error: 0.9270 | Dyn var 2.13 | Obs var 100.00
# EM Iter 35 | Loss: 34.2412 | Train Error: 0.8725 | Val Error : 0.9879 | Test Error: 0.9249 | Dyn var 2.13 | Obs var 100.00
# EM Iter 36 | Loss: 35.0833 | Train Error: 0.8703 | Val Error : 0.9867 | Test Error: 0.9228 | Dyn var 2.13 | Obs var 100.00
# EM Iter 37 | Loss: 34.0631 | Train Error: 0.8678 | Val Error : 0.9852 | Test Error: 0.9205 | Dyn var 2.13 | Obs var 100.00
# EM Iter 38 | Loss: 34.9017 | Train Error: 0.8653 | Val Error : 0.9837 | Test Error: 0.9182 | Dyn var 2.13 | Obs var 100.00
# EM Iter 39 | Loss: 33.8779 | Train Error: 0.8625 | Val Error : 0.9820 | Test Error: 0.9157 | Dyn var 2.13 | Obs var 100.00
# EM Iter 40 | Loss: 34.7128 | Train Error: 0.8595 | Val Error : 0.9803 | Test Error: 0.9131 | Dyn var 2.13 | Obs var 100.00
# EM Iter 41 | Loss: 33.6852 | Train Error: 0.8562 | Val Error : 0.9783 | Test Error: 0.9102 | Dyn var 2.13 | Obs var 100.00
# EM Iter 42 | Loss: 34.5163 | Train Error: 0.8528 | Val Error : 0.9762 | Test Error: 0.9074 | Dyn var 2.13 | Obs var 100.00
# EM Iter 43 | Loss: 33.4849 | Train Error: 0.8489 | Val Error : 0.9738 | Test Error: 0.9042 | Dyn var 2.13 | Obs var 100.00
# EM Iter 44 | Loss: 34.3121 | Train Error: 0.8448 | Val Error : 0.9713 | Test Error: 0.9009 | Dyn var 2.13 | Obs var 100.00
# EM Iter 45 | Loss: 33.2768 | Train Error: 0.8401 | Val Error : 0.9685 | Test Error: 0.8973 | Dyn var 2.13 | Obs var 100.00
# EM Iter 46 | Loss: 34.1000 | Train Error: 0.8353 | Val Error : 0.9656 | Test Error: 0.8936 | Dyn var 2.13 | Obs var 100.00
# EM Iter 47 | Loss: 33.0608 | Train Error: 0.8298 | Val Error : 0.9623 | Test Error: 0.8895 | Dyn var 2.13 | Obs var 100.00
# EM Iter 48 | Loss: 33.8800 | Train Error: 0.8240 | Val Error : 0.9588 | Test Error: 0.8852 | Dyn var 2.13 | Obs var 100.00
# EM Iter 49 | Loss: 32.8367 | Train Error: 0.8174 | Val Error : 0.9549 | Test Error: 0.8805 | Dyn var 2.13 | Obs var 100.00
# EM Iter 50 | Loss: 33.6520 | Train Error: 0.8105 | Val Error : 0.9508 | Test Error: 0.8756 | Dyn var 2.13 | Obs var 100.00
# ...
# EM Iter 88 | Loss: 39.0741 | Train Error: 18.3654 | Val Error : 92.2175 | Test Error: 10.3291 | Dyn var 2.92 | Obs var 100.00
# EM Iter 89 | Loss: 38.8821 | Train Error: 19.7705 | Val Error : 102.7802 | Test Error: 10.9913 | Dyn var 2.92 | Obs var 100.00
# EM Iter 90 | Loss: 38.4505 | Train Error: 21.1995 | Val Error : 113.7441 | Test Error: 11.7219 | Dyn var 2.92 | Obs var 100.00
# EM Iter 91 | Loss: 38.2527 | Train Error: 22.7787 | Val Error : 126.0142 | Test Error: 12.4492 | Dyn var 2.92 | Obs var 100.00
# EM Iter 92 | Loss: 37.8154 | Train Error: 24.3732 | Val Error : 138.6019 | Test Error: 13.2576 | Dyn var 2.92 | Obs var 100.00
# EM Iter 93 | Loss: 37.6119 | Train Error: 26.1426 | Val Error : 152.7350 | Test Error: 14.0551 | Dyn var 2.92 | Obs var 100.00
# EM Iter 94 | Loss: 37.1689 | Train Error: 27.9161 | Val Error : 167.0664 | Test Error: 14.9486 | Dyn var 2.92 | Obs var 100.00
# EM Iter 95 | Loss: 36.9598 | Train Error: 29.8925 | Val Error : 183.2244 | Test Error: 15.8215 | Dyn var 2.92 | Obs var 100.00
# EM Iter 96 | Loss: 36.5113 | Train Error: 31.8593 | Val Error : 199.4242 | Test Error: 16.8081 | Dyn var 2.92 | Obs var 100.00
# EM Iter 97 | Loss: 36.2966 | Train Error: 34.0602 | Val Error : 217.7748 | Test Error: 17.7618 | Dyn var 2.92 | Obs var 100.00
# EM Iter 98 | Loss: 35.8426 | Train Error: 36.2359 | Val Error : 235.9746 | Test Error: 18.8500 | Dyn var 2.92 | Obs var 100.00
# EM Iter 99 | Loss: 35.6224 | Train Error: 38.6792 | Val Error : 256.6905 | Test Error: 19.8900 | Dyn var 2.92 | Obs var 100.00
# EM Iter 100 | Loss: 35.1631 | Train Error: 41.0804 | Val Error : 277.0313 | Test Error: 21.0890 | Dyn var 2.92 | Obs var 100.00
# best val error: 0.14361858947189735 at 60th iteration, Model Performance: 0.6947413153509873 | theta_dim = 9
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# theta_dim = 10
# EM Iter 0 | Loss: 203.6199 | Train Error: 0.8588 | Val Error : 0.9797 | Test Error: 0.9125 | Dyn var 3.08 | Obs var 100.00
# EM Iter 1 | Loss: 161.8471 | Train Error: 0.8661 | Val Error : 0.9841 | Test Error: 0.9189 | Dyn var 3.08 | Obs var 100.00
# EM Iter 2 | Loss: 135.6398 | Train Error: 0.8708 | Val Error : 0.9870 | Test Error: 0.9234 | Dyn var 3.08 | Obs var 100.00
# EM Iter 3 | Loss: 119.5177 | Train Error: 0.8742 | Val Error : 0.9889 | Test Error: 0.9266 | Dyn var 3.08 | Obs var 100.00
# EM Iter 4 | Loss: 108.2586 | Train Error: 0.8766 | Val Error : 0.9903 | Test Error: 0.9290 | Dyn var 3.08 | Obs var 100.00
# EM Iter 5 | Loss: 99.9108 | Train Error: 0.8783 | Val Error : 0.9912 | Test Error: 0.9307 | Dyn var 3.08 | Obs var 100.00
# EM Iter 6 | Loss: 90.9196 | Train Error: 0.8793 | Val Error : 0.9918 | Test Error: 0.9319 | Dyn var 3.08 | Obs var 100.00
# EM Iter 7 | Loss: 85.0456 | Train Error: 0.8799 | Val Error : 0.9921 | Test Error: 0.9325 | Dyn var 3.08 | Obs var 100.00
# EM Iter 8 | Loss: 78.3800 | Train Error: 0.8801 | Val Error : 0.9922 | Test Error: 0.9327 | Dyn var 3.08 | Obs var 100.00
# EM Iter 9 | Loss: 73.9842 | Train Error: 0.8798 | Val Error : 0.9921 | Test Error: 0.9324 | Dyn var 3.08 | Obs var 100.00
# EM Iter 10 | Loss: 69.0443 | Train Error: 0.8792 | Val Error : 0.9918 | Test Error: 0.9318 | Dyn var 3.08 | Obs var 100.00
# EM Iter 11 | Loss: 66.1206 | Train Error: 0.8783 | Val Error : 0.9913 | Test Error: 0.9308 | Dyn var 3.08 | Obs var 100.00
# EM Iter 12 | Loss: 63.5320 | Train Error: 0.8772 | Val Error : 0.9906 | Test Error: 0.9296 | Dyn var 3.08 | Obs var 100.00
# EM Iter 13 | Loss: 62.5725 | Train Error: 0.8758 | Val Error : 0.9899 | Test Error: 0.9283 | Dyn var 3.08 | Obs var 100.00
# EM Iter 14 | Loss: 60.8397 | Train Error: 0.8744 | Val Error : 0.9890 | Test Error: 0.9268 | Dyn var 3.08 | Obs var 100.00
# EM Iter 15 | Loss: 60.5522 | Train Error: 0.8727 | Val Error : 0.9881 | Test Error: 0.9252 | Dyn var 3.08 | Obs var 100.00
# EM Iter 16 | Loss: 59.8639 | Train Error: 0.8709 | Val Error : 0.9871 | Test Error: 0.9235 | Dyn var 3.08 | Obs var 100.00
# EM Iter 17 | Loss: 60.2470 | Train Error: 0.8691 | Val Error : 0.9860 | Test Error: 0.9217 | Dyn var 3.08 | Obs var 100.00
# EM Iter 18 | Loss: 59.5795 | Train Error: 0.8671 | Val Error : 0.9848 | Test Error: 0.9199 | Dyn var 3.08 | Obs var 100.00
# EM Iter 19 | Loss: 59.9792 | Train Error: 0.8650 | Val Error : 0.9836 | Test Error: 0.9179 | Dyn var 3.08 | Obs var 100.00
# EM Iter 20 | Loss: 59.3248 | Train Error: 0.8628 | Val Error : 0.9822 | Test Error: 0.9159 | Dyn var 3.08 | Obs var 100.00
# EM Iter 21 | Loss: 59.7346 | Train Error: 0.8604 | Val Error : 0.9808 | Test Error: 0.9138 | Dyn var 3.08 | Obs var 100.00
# EM Iter 22 | Loss: 59.0879 | Train Error: 0.8578 | Val Error : 0.9792 | Test Error: 0.9116 | Dyn var 3.08 | Obs var 100.00
# EM Iter 23 | Loss: 59.5032 | Train Error: 0.8551 | Val Error : 0.9776 | Test Error: 0.9093 | Dyn var 3.08 | Obs var 100.00
# EM Iter 24 | Loss: 58.8602 | Train Error: 0.8521 | Val Error : 0.9758 | Test Error: 0.9068 | Dyn var 3.08 | Obs var 100.00
# EM Iter 25 | Loss: 59.2777 | Train Error: 0.8490 | Val Error : 0.9739 | Test Error: 0.9043 | Dyn var 3.08 | Obs var 100.00
# EM Iter 26 | Loss: 58.6354 | Train Error: 0.8456 | Val Error : 0.9718 | Test Error: 0.9016 | Dyn var 3.08 | Obs var 100.00
# EM Iter 27 | Loss: 59.0524 | Train Error: 0.8420 | Val Error : 0.9696 | Test Error: 0.8987 | Dyn var 3.08 | Obs var 100.00
# EM Iter 28 | Loss: 58.4086 | Train Error: 0.8380 | Val Error : 0.9672 | Test Error: 0.8957 | Dyn var 3.08 | Obs var 100.00
# EM Iter 29 | Loss: 58.8232 | Train Error: 0.8338 | Val Error : 0.9647 | Test Error: 0.8925 | Dyn var 3.08 | Obs var 100.00
# EM Iter 30 | Loss: 58.1762 | Train Error: 0.8292 | Val Error : 0.9619 | Test Error: 0.8891 | Dyn var 3.08 | Obs var 100.00
# EM Iter 31 | Loss: 58.5868 | Train Error: 0.8243 | Val Error : 0.9590 | Test Error: 0.8854 | Dyn var 3.08 | Obs var 100.00
# EM Iter 32 | Loss: 57.9352 | Train Error: 0.8189 | Val Error : 0.9558 | Test Error: 0.8816 | Dyn var 3.08 | Obs var 100.00
# EM Iter 33 | Loss: 58.3407 | Train Error: 0.8131 | Val Error : 0.9523 | Test Error: 0.8774 | Dyn var 3.08 | Obs var 100.00
# EM Iter 34 | Loss: 57.6835 | Train Error: 0.8068 | Val Error : 0.9486 | Test Error: 0.8730 | Dyn var 3.08 | Obs var 100.00
# EM Iter 35 | Loss: 58.0830 | Train Error: 0.8000 | Val Error : 0.9446 | Test Error: 0.8683 | Dyn var 3.08 | Obs var 100.00
# EM Iter 36 | Loss: 57.4193 | Train Error: 0.7926 | Val Error : 0.9403 | Test Error: 0.8632 | Dyn var 3.08 | Obs var 100.00
# EM Iter 37 | Loss: 57.8120 | Train Error: 0.7845 | Val Error : 0.9357 | Test Error: 0.8577 | Dyn var 3.08 | Obs var 100.00
# EM Iter 38 | Loss: 57.1412 | Train Error: 0.7757 | Val Error : 0.9307 | Test Error: 0.8517 | Dyn var 3.08 | Obs var 100.00
# EM Iter 39 | Loss: 57.5266 | Train Error: 0.7661 | Val Error : 0.9253 | Test Error: 0.8452 | Dyn var 3.08 | Obs var 100.00
# EM Iter 40 | Loss: 56.8483 | Train Error: 0.7556 | Val Error : 0.9195 | Test Error: 0.8382 | Dyn var 3.08 | Obs var 100.00
# EM Iter 41 | Loss: 57.2259 | Train Error: 0.7441 | Val Error : 0.9132 | Test Error: 0.8305 | Dyn var 3.08 | Obs var 100.00
# EM Iter 42 | Loss: 56.5397 | Train Error: 0.7317 | Val Error : 0.9064 | Test Error: 0.8221 | Dyn var 3.08 | Obs var 100.00
# EM Iter 43 | Loss: 56.9093 | Train Error: 0.7180 | Val Error : 0.8992 | Test Error: 0.8128 | Dyn var 3.08 | Obs var 100.00
# EM Iter 44 | Loss: 56.2150 | Train Error: 0.7031 | Val Error : 0.8913 | Test Error: 0.8027 | Dyn var 3.08 | Obs var 100.00
# EM Iter 45 | Loss: 56.5764 | Train Error: 0.6867 | Val Error : 0.8829 | Test Error: 0.7914 | Dyn var 3.08 | Obs var 100.00
# EM Iter 46 | Loss: 55.8737 | Train Error: 0.6688 | Val Error : 0.8739 | Test Error: 0.7791 | Dyn var 3.08 | Obs var 100.00
# EM Iter 47 | Loss: 56.2267 | Train Error: 0.6493 | Val Error : 0.8642 | Test Error: 0.7654 | Dyn var 3.08 | Obs var 100.00
# EM Iter 48 | Loss: 55.5156 | Train Error: 0.6281 | Val Error : 0.8538 | Test Error: 0.7502 | Dyn var 3.08 | Obs var 100.00
# EM Iter 49 | Loss: 55.8601 | Train Error: 0.6049 | Val Error : 0.8426 | Test Error: 0.7333 | Dyn var 3.08 | Obs var 100.00
# EM Iter 50 | Loss: 55.1406 | Train Error: 0.5800 | Val Error : 0.8307 | Test Error: 0.7146 | Dyn var 3.08 | Obs var 100.00
# EM Iter 51 | Loss: 55.4766 | Train Error: 0.5542 | Val Error : 0.8179 | Test Error: 0.6938 | Dyn var 3.08 | Obs var 100.00
# EM Iter 52 | Loss: 54.7486 | Train Error: 0.5277 | Val Error : 0.8042 | Test Error: 0.6706 | Dyn var 3.08 | Obs var 100.00
# EM Iter 53 | Loss: 55.0761 | Train Error: 0.5011 | Val Error : 0.7896 | Test Error: 0.6449 | Dyn var 3.08 | Obs var 100.00
# EM Iter 54 | Loss: 54.3396 | Train Error: 0.4753 | Val Error : 0.7740 | Test Error: 0.6162 | Dyn var 3.08 | Obs var 100.00
# EM Iter 55 | Loss: 54.6586 | Train Error: 0.4541 | Val Error : 0.7574 | Test Error: 0.5844 | Dyn var 3.08 | Obs var 100.00
# EM Iter 56 | Loss: 53.9137 | Train Error: 0.4397 | Val Error : 0.7396 | Test Error: 0.5491 | Dyn var 3.08 | Obs var 100.00
# EM Iter 57 | Loss: 54.2244 | Train Error: 0.4327 | Val Error : 0.7206 | Test Error: 0.5100 | Dyn var 3.08 | Obs var 100.00
# EM Iter 58 | Loss: 53.4711 | Train Error: 0.4310 | Val Error : 0.7003 | Test Error: 0.4667 | Dyn var 3.08 | Obs var 100.00
# EM Iter 59 | Loss: 53.7735 | Train Error: 0.4359 | Val Error : 0.6785 | Test Error: 0.4188 | Dyn var 3.08 | Obs var 100.00
# EM Iter 60 | Loss: 53.0119 | Train Error: 0.4482 | Val Error : 0.6551 | Test Error: 0.3659 | Dyn var 3.08 | Obs var 100.00
# EM Iter 61 | Loss: 53.3061 | Train Error: 0.4682 | Val Error : 0.6296 | Test Error: 0.3078 | Dyn var 3.08 | Obs var 100.00
# EM Iter 62 | Loss: 52.5364 | Train Error: 0.4961 | Val Error : 0.6017 | Test Error: 0.2438 | Dyn var 3.08 | Obs var 100.00
# EM Iter 63 | Loss: 52.8224 | Train Error: 0.5346 | Val Error : 0.5706 | Test Error: 0.1737 | Dyn var 3.08 | Obs var 100.00
# EM Iter 64 | Loss: 52.0446 | Train Error: 0.5846 | Val Error : 0.5354 | Test Error: 0.1221 | Dyn var 3.08 | Obs var 100.00
# EM Iter 65 | Loss: 52.3226 | Train Error: 0.6477 | Val Error : 0.4948 | Test Error: 0.1138 | Dyn var 3.08 | Obs var 100.00
# EM Iter 66 | Loss: 51.5369 | Train Error: 0.7242 | Val Error : 0.4465 | Test Error: 0.1580 | Dyn var 3.08 | Obs var 100.00
# EM Iter 67 | Loss: 51.8071 | Train Error: 0.8132 | Val Error : 0.4217 | Test Error: 0.2236 | Dyn var 3.08 | Obs var 100.00
# EM Iter 68 | Loss: 51.0135 | Train Error: 0.9172 | Val Error : 0.3855 | Test Error: 0.3057 | Dyn var 3.08 | Obs var 100.00
# EM Iter 69 | Loss: 51.2759 | Train Error: 1.0364 | Val Error : 0.3329 | Test Error: 0.4035 | Dyn var 3.08 | Obs var 100.00
# EM Iter 70 | Loss: 50.4746 | Train Error: 1.1733 | Val Error : 0.2573 | Test Error: 0.5304 | Dyn var 3.08 | Obs var 100.00
# EM Iter 71 | Loss: 50.7294 | Train Error: 1.3294 | Val Error : 0.1602 | Test Error: 0.6672 | Dyn var 3.08 | Obs var 100.00
# EM Iter 72 | Loss: 49.9205 | Train Error: 1.5071 | Val Error : 0.2356 | Test Error: 0.8150 | Dyn var 3.08 | Obs var 100.00
# EM Iter 73 | Loss: 50.1678 | Train Error: 1.7071 | Val Error : 0.4834 | Test Error: 0.9737 | Dyn var 3.08 | Obs var 100.00
# EM Iter 74 | Loss: 49.3514 | Train Error: 1.9305 | Val Error : 0.8010 | Test Error: 1.1447 | Dyn var 3.08 | Obs var 100.00
# EM Iter 75 | Loss: 49.5914 | Train Error: 2.1795 | Val Error : 1.2038 | Test Error: 1.3276 | Dyn var 3.08 | Obs var 100.00
# EM Iter 76 | Loss: 48.7675 | Train Error: 2.4556 | Val Error : 1.7121 | Test Error: 1.5242 | Dyn var 3.08 | Obs var 100.00
# EM Iter 77 | Loss: 49.0004 | Train Error: 2.7581 | Val Error : 2.3458 | Test Error: 1.7338 | Dyn var 3.08 | Obs var 100.00
# EM Iter 78 | Loss: 48.1692 | Train Error: 3.0881 | Val Error : 3.1302 | Test Error: 1.9587 | Dyn var 3.08 | Obs var 100.00
# EM Iter 79 | Loss: 48.3951 | Train Error: 3.4482 | Val Error : 4.0895 | Test Error: 2.1977 | Dyn var 3.08 | Obs var 100.00
# EM Iter 80 | Loss: 47.5567 | Train Error: 3.8415 | Val Error : 5.2530 | Test Error: 2.4536 | Dyn var 3.08 | Obs var 100.00
# EM Iter 81 | Loss: 47.7756 | Train Error: 4.2703 | Val Error : 6.6501 | Test Error: 2.7248 | Dyn var 3.08 | Obs var 100.00
# EM Iter 82 | Loss: 46.9301 | Train Error: 4.7342 | Val Error : 8.3111 | Test Error: 3.0149 | Dyn var 3.08 | Obs var 100.00
# EM Iter 83 | Loss: 47.1423 | Train Error: 5.2386 | Val Error : 10.2725 | Test Error: 3.3215 | Dyn var 3.08 | Obs var 100.00
# EM Iter 84 | Loss: 46.2898 | Train Error: 5.7821 | Val Error : 12.5607 | Test Error: 3.6491 | Dyn var 3.08 | Obs var 100.00
# EM Iter 85 | Loss: 46.4954 | Train Error: 6.3728 | Val Error : 15.2241 | Test Error: 3.9945 | Dyn var 3.08 | Obs var 100.00
# EM Iter 86 | Loss: 45.6359 | Train Error: 7.0070 | Val Error : 18.2765 | Test Error: 4.3631 | Dyn var 3.08 | Obs var 100.00
# EM Iter 87 | Loss: 45.8350 | Train Error: 7.6960 | Val Error : 21.7878 | Test Error: 4.7510 | Dyn var 3.08 | Obs var 100.00
# EM Iter 88 | Loss: 44.9687 | Train Error: 8.4297 | Val Error : 25.7454 | Test Error: 5.1647 | Dyn var 3.08 | Obs var 100.00
# EM Iter 89 | Loss: 45.1614 | Train Error: 9.2276 | Val Error : 30.2561 | Test Error: 5.5992 | Dyn var 3.08 | Obs var 100.00
# EM Iter 90 | Loss: 44.2884 | Train Error: 10.0719 | Val Error : 35.2602 | Test Error: 6.0624 | Dyn var 3.08 | Obs var 100.00
# EM Iter 91 | Loss: 44.4749 | Train Error: 10.9925 | Val Error : 40.9267 | Test Error: 6.5478 | Dyn var 3.08 | Obs var 100.00
# EM Iter 92 | Loss: 43.5952 | Train Error: 11.9596 | Val Error : 47.1174 | Test Error: 7.0653 | Dyn var 3.08 | Obs var 100.00
# EM Iter 93 | Loss: 43.7755 | Train Error: 13.0169 | Val Error : 54.1004 | Test Error: 7.6066 | Dyn var 3.08 | Obs var 100.00
# EM Iter 94 | Loss: 42.8893 | Train Error: 14.1187 | Val Error : 61.6149 | Test Error: 8.1836 | Dyn var 3.08 | Obs var 100.00
# EM Iter 95 | Loss: 43.0635 | Train Error: 15.3283 | Val Error : 70.0805 | Test Error: 8.7862 | Dyn var 3.08 | Obs var 100.00
# EM Iter 96 | Loss: 42.1709 | Train Error: 16.5773 | Val Error : 79.0532 | Test Error: 9.4284 | Dyn var 3.08 | Obs var 100.00
# EM Iter 97 | Loss: 42.3391 | Train Error: 17.9564 | Val Error : 89.1746 | Test Error: 10.0980 | Dyn var 3.08 | Obs var 100.00
# EM Iter 98 | Loss: 41.4401 | Train Error: 19.3656 | Val Error : 99.7365 | Test Error: 10.8117 | Dyn var 3.08 | Obs var 100.00
# EM Iter 99 | Loss: 41.6024 | Train Error: 20.9327 | Val Error : 111.6968 | Test Error: 11.5547 | Dyn var 3.08 | Obs var 100.00
# EM Iter 100 | Loss: 40.6973 | Train Error: 22.5157 | Val Error : 123.9762 | Test Error: 12.3467 | Dyn var 3.08 | Obs var 100.00
# EM Iter 101 | Loss: 40.8537 | Train Error: 24.2910 | Val Error : 137.9707 | Test Error: 13.1700 | Dyn var 3.08 | Obs var 100.00
# EM Iter 102 | Loss: 39.9424 | Train Error: 26.0616 | Val Error : 152.0933 | Test Error: 14.0476 | Dyn var 3.08 | Obs var 100.00
# EM Iter 103 | Loss: 40.0929 | Train Error: 28.0675 | Val Error : 168.3329 | Test Error: 14.9587 | Dyn var 3.08 | Obs var 100.00
# EM Iter 104 | Loss: 39.1757 | Train Error: 30.0397 | Val Error : 184.4218 | Test Error: 15.9297 | Dyn var 3.08 | Obs var 100.00
# EM Iter 105 | Loss: 39.3204 | Train Error: 32.3006 | Val Error : 203.1362 | Test Error: 16.9367 | Dyn var 3.08 | Obs var 100.00
# EM Iter 106 | Loss: 38.3973 | Train Error: 34.4887 | Val Error : 221.3115 | Test Error: 18.0095 | Dyn var 3.08 | Obs var 100.00
# EM Iter 107 | Loss: 38.5363 | Train Error: 37.0314 | Val Error : 242.7528 | Test Error: 19.1209 | Dyn var 3.08 | Obs var 100.00
# EM Iter 108 | Loss: 37.6074 | Train Error: 39.4497 | Val Error : 263.1300 | Test Error: 20.3043 | Dyn var 3.08 | Obs var 100.00
# EM Iter 109 | Loss: 37.7406 | Train Error: 42.3038 | Val Error : 287.5758 | Test Error: 21.5294 | Dyn var 3.08 | Obs var 100.00
# EM Iter 110 | Loss: 36.8061 | Train Error: 44.9661 | Val Error : 310.2643 | Test Error: 22.8327 | Dyn var 3.08 | Obs var 100.00
# EM Iter 111 | Loss: 36.9335 | Train Error: 48.1640 | Val Error : 338.0212 | Test Error: 24.1810 | Dyn var 3.08 | Obs var 100.00
# best val error: 0.1601786127974321 at 71th iteration, Model Performance: 0.6671829394973282 | theta_dim = 10
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++

# %% [markdown]
# # Plot Prediction error vs forward step & Volatility trajectory

# %%
for k in range(len(error_for_all_theta_dim)):

    sns.set()
    fig = plt.figure(figsize=(15, 4))
    fig.suptitle("Theta = {}".format(k+2))
    
    iteratons = range(best_itr_for_all_theta_dim[k]-9, best_itr_for_all_theta_dim[k]-5)
    
    # forward steps
    a = fig.add_subplot(121)
    
    
    xlabel = list(range(len(k_step_test_error)+1))
    plt.xticks(xlabel)
    a.set_ylim(0.0, 0.5)
    a.set_title('Prediction Error vs Forward Steps, theta_dim = {}'.format(k+2), color='C0')
    for i in iteratons:
        show = error_for_all_theta_dim[k][i]
        a.plot([i+1 for i in range(len(k_step_test_error))], show, marker='^', markersize= 5, linewidth=1)
    a.legend(["em itr={}".format(i) for i in iteratons])
    
    b = fig.add_subplot(122)
    b.xaxis_date()
    # volatility trajectory
    b.set_title('Volatility Trajectory vs theta dimension, theta_dim = {}'.format(k+2), color='C0')
    b.set_ylim(0.005, 0.008)
    for i in iteratons:
        volatility_mean = np.average(ms_s_for_all_theta_dim[k][i], axis=1)
        b.plot(all_days, volatility_mean[1:], linewidth=1)
    b.legend(["em itr={}".format(i) for i in iteratons])
    plt.xticks(rotation=60)
    fig.show()

# %% [markdown]
# # Test Implied Volatility

# %%
base_date = list(valid_data.keys())[-1]
base_date_vol = np.average(valid_data[list(valid_data.keys())[-1]][0]["impl_volatility"].values) / bday_p_year

test_days = list(test_data.keys())
test_error_traj_imp_vol = []
for k in range(1, min(forward_k+1, num_test_day+1)):
    k_step_test_error_imp_vol = []
    for idx in range(k-1, num_test_day):
        pred_date = test_days[idx]
        pred_date_p = test_data[pred_date][3]
        pred_date_r = test_data[pred_date][1] / bday_p_year
        pred_date_K = test_data[pred_date][0]["strike_price"].values
        today = [d.date() for d in test_data[pred_date][0]["date"]]
        expireday = [d.date() for d in test_data[pred_date][0]["exdate"]]
        pred_date_T = np.busday_count(today, expireday)
        pred_date_y = test_data[pred_date][0]["spotclose"].values

        pred_price_imp_vol = BSf(base_date_vol, 
                                 p_t=pred_date_p, 
                                 r_t=pred_date_r, 
                                 K_t=pred_date_K, 
                                 T_t=pred_date_T)
        pred_error_imp_vol = np.average(np.abs(pred_price_imp_vol-pred_date_y) / pred_date_y)
        k_step_test_error_imp_vol.append(pred_error_imp_vol)

        base_date = test_days[idx-k+1]
        base_date_vol = np.average(valid_data[list(valid_data.keys())[-1]][0]["impl_volatility"].values) / bday_p_year

    test_error_traj_imp_vol.append(np.average(k_step_test_error_imp_vol))

fig = plt.figure(figsize=(8,4))
fig.suptitle("Implied Volatility Prediction k steps forward")
plt.xticks(xlabel)
plt.plot([_+1 for _ in range(forward_k)], test_error_traj_imp_vol, marker ='^', markersize=5, linewidth=1)
fig.show()

# %%
train_data[np.datetime64('2019-01-02T00:00:00.000000000')]
# Out:
# [              date     exdate  strike_price  best_bid  best_offer  volume  \
#  7824298 2019-01-02 2019-06-21        3050.0      3.40         3.7   30005
#  7824308 2019-01-02 2019-06-21        3300.0      0.75         1.0   30005
#  7823256 2019-01-02 2019-01-18        2570.0     14.50        15.3   22363
#  7823260 2019-01-02 2019-01-18        2590.0      9.20         9.8   19735
#  7825956 2019-01-02 2019-01-11        2525.0     23.40        24.0   19555
#
#           impl_volatility  spotclose
#  7824298         0.149985      3.550
#  7824308         0.163895      0.875
#  7823256         0.180783     14.900
#  7823260         0.174487      9.500
#  7825956         0.192232     23.700  ,
#  0.0279388,
#  array([ 8.64007027e-05, -1.53957145e-02, -1.57721063e-02, -2.05882284e-02,
#         -2.71122542e-02,  4.95937426e-02,  8.56268080e-03, -1.24158255e-03,
#          8.49248436e-03,  1.26849667e-03]),
#  2510.030029]
