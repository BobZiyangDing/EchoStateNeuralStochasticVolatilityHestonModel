# %%
# Most Basic
import matplotlib.pyplot as plt
import matplotlib as mpl
import seaborn as sns
import pandas as pd
import numpy as np
import math
from os import path
import sys
from datetime import datetime
from scipy.stats import norm
import scipy.stats as ss
import copy
import warnings
warnings.simplefilter('error')
import datetime

# Filter Specific Functionalities
from filterpy.kalman import UnscentedKalmanFilter
from filterpy.common import Q_discrete_white_noise
from filterpy.kalman import MerweScaledSigmaPoints

# Gradient Based
import autograd.numpy as a_np
import autograd.scipy.stats as a_ss
from autograd import grad, multigrad_dict, elementwise_grad, jacobian

# Self Defined functions5
from DataMaker_New import dataCleaner_new
from ESN import EchoState
from Loss import loss

# %%
columns = ["date","exdate","strike_price","best_bid","best_offer","volume","impl_volatility"]
start = datetime.datetime(2018, 1, 1)
end = datetime.datetime(2019, 12, 31)
train_valid_split = 0.936
valid_test_split = 0.94
u_dim = 10
topK = 5
cleaner = dataCleaner_new(columns, u_dim, topK, start, end, train_valid_split, valid_test_split)
return_dict, price_dict = cleaner.make_return_price()
risk_dict = cleaner.make_risk()
train_data, valid_data, test_data = cleaner.make_final_data(price_dict, return_dict, risk_dict)
num_train_day, num_train_obs = cleaner.get_train_num()
num_valid_day, num_valid_obs = cleaner.get_valid_num()
num_test_day, num_test_obs = cleaner.get_test_num()

# train_data[np.datetime64('2019-01-02T00:00:00.000000000')]
# Out:
# Attached 351 days of train data
# Attached 1755 train option observations
# Attached 1 days of validation data
# Attached 5 validation option observations
# Attached 23 days of test data
# Attached 115 test option observations

# %%
# Define transition Dynamics
# Positional requirement, no real effect, will be replaced by ESN and BS defined further down
def fx(x, dt):
    return x*dt
def hx(x):
    return x

def sigmoid(x):
    return np.divide(1, 1+np.exp(-x))


def ESNf(theta_now, dt, **fx_args):
    """
    :params theta_now theta_t
    
    **fx_args
    :params G reservoir transition matrix
    :params G_in input translation matrix
    :params b reservoir bias vector
    :params u_quad_now u_t^2
    """
    G = fx_args["G"]
    G_in = fx_args["G_in"]
    b = fx_args["b"]
    u_quad_now = fx_args["u_quad_now"]
    theta_next = sigmoid(np.matmul(G, theta_now) + np.matmul(G_in, u_quad_now) + b)
    return theta_next
    

def BSf(theta_t, **hx_args):
    """
    :params theta_t current state vector
    
    **hx_args
    :params p_t current asset price
    :params r_t current asset price
    :params K_t strike price, 1d vector
    :params T_t maturity time, 1d vector
    """
    p_t = hx_args["p_t"]
    r_t = hx_args["r_t"]
    K_t = hx_args["K_t"]
    T_t = hx_args["T_t"]
    
    volatility_std = np.average(theta_t)
    volatility_var = np.power(volatility_std, 2)
    
    dividor = np.sqrt(volatility_var * T_t)
    d_pls = (np.log(p_t/K_t) + np.multiply(r_t+volatility_var/2, T_t)) / dividor
    d_mns = (np.log(p_t/K_t) + np.multiply(r_t-volatility_var/2, T_t)) / dividor
    y_t = np.multiply(p_t, norm.cdf(d_pls)) - np.multiply(np.multiply(K_t, np.exp(-r_t*T_t)), norm.cdf(d_mns))
    return y_t

def is_pos_def(x):
    return np.all(np.linalg.eigvals(x) > 0)

# %% [markdown]
# # 睡觉专区

# %%
np.random.seed(1234)
gradient = grad(loss)


forward_k = 20

error_for_all_theta_dim = []
best_itr_for_all_theta_dim = []
best_train_itr_for_all_theta_dim = []
params_for_all_theta_dim = []
ms_s_for_all_theta_dim = []
Cs_s_for_all_theta_dim = []

for theta_dim in np.arange(8, 10, 1):

    m_t_1 = [np.array([0]), np.array([0]), np.array([0])]
    v_t_1 = [np.array([0]), np.array([0]), np.array([0])]
    beta_1 = 0.9
    beta_2 = 0.999
    epsillon = 1e-8
    
    print("theta_dim = {}".format(theta_dim))
    alpha = 5
    connectivity = 0.4
    spectral_radius = 0.98
    bday_p_year = 252
    bias = -7

    v_scale = 100.0
    target_var = 1e-6
    chi_mu = math.sqrt(2)* math.gamma((theta_dim+1)/2) / math.gamma(theta_dim/2)
    W_scale = target_var+chi_mu

    # initialize ESN dynamics
    ESN = EchoState(theta_dim, u_dim, connectivity, spectral_radius, bias)
    W = np.eye(theta_dim)*W_scale
    v = v_scale

    last_avg_error = 100
    best_itr = 0
    best_train_error = 100
    best_train_itr = 0
    
    #%%%%%% Error trajectories
    
    test_error_traj = []
    params_traj = []
    ms_s_traj = []
    Cs_s_traj = []
    
    for em_itr in range(200):
        dt=1
        points = MerweScaledSigmaPoints(theta_dim, alpha=.001, beta=2., kappa=0)
        ukf = UnscentedKalmanFilter(dim_x=ESN.theta_dim, dim_z=topK, dt=1, fx=fx, hx=hx, points=points)
        ukf.x = np.ones(ESN.theta_dim)* 0.006 # initial state
        ukf.P *= 0.01 # initial uncertainty
        ukf.R = np.diag([v]*topK) # 1 standard
        ukf.Q = W

        ms = [ukf.x.copy()]
        Cs = [ukf.P.copy()]
        u_quad_s = []
        ps = []
        rs = []
        ys = []
        Ks = []
        us = []
        Ts = []

        all_days = sorted(list(train_data.keys()))
        for day in all_days:
            # get observable data
            ## Stock Wise and market wise data
            r_t = train_data[day][1] / bday_p_year
            u_t = train_data[day][2].reshape([-1])
            p_t = train_data[day][3]

            ## Option wise data
            y_t = train_data[day][0]["spotclose"].values
            K_t = train_data[day][0]["strike_price"].values
            today = [d.date() for d in train_data[day][0]["date"]]
            expireday = [d.date() for d in train_data[day][0]["exdate"]]
            T_t = np.busday_count(today, expireday)


            ukf.predict(fx = ESNf, G=ESN.G, G_in=ESN.G_in, b= ESN.b, u_quad_now=np.power(u_t,2))
            ukf.update(y_t, hx=BSf, p_t=p_t, r_t=r_t, K_t=K_t, T_t=T_t)
            ms.append(ukf.x_post.copy())
            Cs.append(ukf.P_post.copy())
            u_quad_s.append(np.power(u_t,2))
            us.append(u_t)
            ps.append(p_t)
            rs.append(r_t)
            ys.append(y_t)
            Ks.append(K_t)
            Ts.append(T_t)

        ms = np.array(ms)
        Cs = np.array(Cs)
        ms_s, Cs_s, _, cvs_s = ukf.rts_smoother(ms, Cs, fx=ESNf, G=ESN.G, G_in=ESN.G_in, b=ESN.b, u_s=us)


        params = [ESN.G, ESN.G_in, ESN.b, ukf.Q, v]

        step = 0.02
        try:
            curr_loss = loss(params,
                             ms_s, Cs_s, cvs_s,
                             u_quad_s,
                             ps, rs, Ks, Ts, ys,
                             num_train_obs,
                             reg=alpha)
            curr_grad = gradient(params,
                                 ms_s, Cs_s, cvs_s,
                                 u_quad_s,
                                 ps, rs, Ks, Ts, ys,
                                 num_train_obs,
                                 reg=alpha)

######################## Adam Optimizer ###########################
            
            m_t = [None, None, None]
            v_t = [None, None, None]
            m_t_hat = [None, None, None]
            v_t_hat = [None, None, None]

            m_t[0] = beta_1 * m_t_1[0] + (1-beta_1) * curr_grad[0]
            v_t[0] = beta_2 * v_t_1[0] + (1-beta_2) * (curr_grad[0] * curr_grad[0])
            m_t_hat[0] = m_t[0] / (1-beta_1 ** (em_itr+1))
            v_t_hat[0] = v_t[0] / (1-beta_2 ** (em_itr+1))
            params[0] -= step * m_t_hat[0] / (np.sqrt(v_t_hat[0]) + epsillon)

            m_t[1] = beta_1 * m_t_1[1] + (1-beta_1) * curr_grad[1]
            v_t[1] = beta_2 * v_t_1[1] + (1-beta_2) * (curr_grad[1] * curr_grad[1])
            m_t_hat[1] = m_t[1] / (1-beta_1 ** (em_itr+1))
            v_t_hat[1] = v_t[1] / (1-beta_2 ** (em_itr+1))
            params[1] -= step * m_t_hat[1] / (np.sqrt(v_t_hat[1]) + epsillon)

            m_t[2] = beta_1 * m_t_1[2] + (1-beta_1) * curr_grad[2]
            v_t[2] = beta_2 * v_t_1[2] + (1-beta_2) * (curr_grad[2] * curr_grad[2])
            m_t_hat[2] = m_t[2] / (1-beta_1 ** (em_itr+1))
            v_t_hat[2] = v_t[2] / (1-beta_2 ** (em_itr+1))
            params[2] -= step * m_t_hat[2] / (np.sqrt(v_t_hat[2]) + epsillon)

            m_t = m_t_1
            v_t = v_t_1

###################################################################

        except RuntimeWarning or LinAlgError or OverflowError:
            print("Error occured")
            pass

        ESN.G, ESN.G_in, ESN.b, W, v = params

        
################################################################### Training Performance
        
        np.delete(ms_s,0,0)
        np.delete(Cs_s,0,0)
        train_errors = []
        ukf.x = ms_s[1]
        ukf.P = Cs_s[1]
        for i in range(2, len(ms_s)-1):

            ukf.predict(fx = ESNf,  G=ESN.G, G_in=ESN.G_in, b= ESN.b, u_quad_now=u_quad_s[i])
            pred_price = BSf(ukf.x_prior, p_t=ps[i], r_t=rs[i], K_t=Ks[i], T_t=Ts[i])
            error = np.average(np.abs(ys[i]-pred_price) /ys[i])
            train_errors.append(error)
            ukf.update(ys[i], hx=BSf, p_t=ps[i], r_t=rs[i], K_t=Ks[i], T_t=Ts[i])

        avg_train_error = np.average(train_errors)

################################################################### Validation Performance
        ukf.x = ms_s[-1]
        ukf.P = Cs_s[-1]
        valid_errors = []
        
        all_valid_days = sorted(list(valid_data.keys()))
        for day in all_valid_days:
            # get observable data
            ## Stock Wise and market wise data
            r_t = valid_data[day][1] / bday_p_year
            u_t = valid_data[day][2].reshape([-1])
            p_t = valid_data[day][3]

            ## Option wise data
            y_t = valid_data[day][0]["spotclose"].values
            K_t = valid_data[day][0]["strike_price"].values
            today = [d.date() for d in valid_data[day][0]["date"]]
            expireday = [d.date() for d in valid_data[day][0]["exdate"]]
            T_t = np.busday_count(today, expireday)

            ukf.predict(fx = ESNf, G=ESN.G, G_in=ESN.G_in, b= ESN.b, u_quad_now=np.power(u_t,2))
            pred_price = BSf(ukf.x_prior, p_t=p_t, r_t=r_t, K_t=K_t, T_t=T_t)
            error = np.average(np.abs(y_t-pred_price) /y_t)
            valid_errors.append(error)
            
            ukf.update(y_t, hx=BSf, p_t=p_t, r_t=r_t, K_t=K_t, T_t=T_t)
            
        avg_valid_error = np.average(valid_errors) 

################################################################### Testing Performance
        
        # forward K step prediction
        k_step_test_error = []
        
        for k in range(1, min(forward_k+1, num_test_day+1)):
    
            test_errors = []
            
            
            all_test_days = sorted(list(test_data.keys()))
            
            # For loop for base shift, shift of last updated ukf timestep
            for idx in range(len(all_test_days) - k):
                
                ukf_pred = copy.deepcopy(ukf)
                
                # For loop for k predictions forward
                for shift in range(k) :
                    # get observable data
                    ## Stock Wise and market wise data
                    r_t = test_data[all_test_days[idx+shift]][1] / bday_p_year
                    u_t = test_data[all_test_days[idx+shift]][2].reshape([-1])
                    p_t = test_data[all_test_days[idx+shift]][3]

                    ## Option wise data
                    y_t = test_data[all_test_days[idx+shift]][0]["spotclose"].values
                    K_t = test_data[all_test_days[idx+shift]][0]["strike_price"].values
                    today = [d.date() for d in test_data[all_test_days[idx+shift]][0]["date"]]
                    expireday = [d.date() for d in test_data[all_test_days[idx+shift]][0]["exdate"]]
                    T_t = np.busday_count(today, expireday)

                    ukf_pred.predict(fx = ESNf, G=ESN.G, G_in=ESN.G_in, b= ESN.b, u_quad_now=np.power(u_t,2))
                
                
                
                pred_price = BSf(ukf_pred.x_prior, p_t=p_t, r_t=r_t, K_t=K_t, T_t=T_t)
                error = np.average(np.abs(y_t-pred_price) /y_t)
                test_errors.append(error)
                
                
                # shift base one step forward
                r_t = test_data[all_test_days[idx]][1] / bday_p_year
                u_t = test_data[all_test_days[idx]][2].reshape([-1])
                p_t = test_data[all_test_days[idx]][3]

                ## Option wise data
                y_t = test_data[all_test_days[idx]][0]["spotclose"].values
                K_t = test_data[all_test_days[idx]][0]["strike_price"].values
                today = [d.date() for d in test_data[all_test_days[idx]][0]["date"]]
                expireday = [d.date() for d in test_data[all_test_days[idx]][0]["exdate"]]

                ukf.predict(fx = ESNf, G=ESN.G, G_in=ESN.G_in, b= ESN.b, u_quad_now=np.power(u_t,2))
                ukf.update(y_t, hx=BSf, p_t=p_t, r_t=r_t, K_t=K_t, T_t=T_t)
            
            if test_errors != []:
                avg_test_error = np.average(test_errors)
                k_step_test_error.append(avg_test_error)
            else:
                pass
            
            
################################################################### Show details
        

        print("EM Iter {} | Loss: {:.4f} | Train Error: {:.4f} | Val Error : {:.4f} | Test Error: {:.4f} |"  
              " Dyn var {:.2f} | Obs var {:.2f}".format(em_itr, curr_loss,
                                                        avg_train_error, avg_valid_error, avg_test_error, 
                                                        W[0,0], v))
        
        if last_avg_error < avg_valid_error and em_itr-best_itr >= 50:
            break
        elif last_avg_error < avg_valid_error and em_itr-best_itr < 50:
            pass
        elif last_avg_error > avg_valid_error and em_itr-best_itr < 50:
            last_avg_error = avg_valid_error
            model_performance = avg_test_error
            best_itr = em_itr
            
        if best_train_error > avg_train_error and em_itr-best_train_itr < 50:
            best_train_error = avg_train_error
            best_train_itr = em_itr
            
    
        test_error_traj.append(k_step_test_error)
        params_traj.append(params)
        ms_s_traj.append(ms_s)
        Cs_s_traj.append(Cs_s)
        
    
    error_for_all_theta_dim.append(test_error_traj)
    best_itr_for_all_theta_dim.append(best_itr)
    best_train_itr_for_all_theta_dim.append(best_train_itr)
    params_for_all_theta_dim.append(params_traj)
    ms_s_for_all_theta_dim.append(ms_s_traj)
    Cs_s_for_all_theta_dim.append(Cs_s_traj)
    
    print("best val error: {} at {}th iteration, Model Performance: {} | theta_dim = {}".format(last_avg_error,
                                                                                                best_itr,
                                                                                                model_performance,
                                                                                                theta_dim))
    print("++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++")
# Out:
# theta_dim = 8
# EM Iter 0 | Loss: 149.8082 | Train Error: 0.8834 | Val Error : 0.9940 | Test Error: 0.9363 | Dyn var 2.74 | Obs var 100.00
# EM Iter 1 | Loss: 136.6944 | Train Error: 0.8845 | Val Error : 0.9945 | Test Error: 0.9375 | Dyn var 2.74 | Obs var 100.00
# EM Iter 2 | Loss: 127.3631 | Train Error: 0.8854 | Val Error : 0.9949 | Test Error: 0.9385 | Dyn var 2.74 | Obs var 100.00
# EM Iter 3 | Loss: 119.7368 | Train Error: 0.8861 | Val Error : 0.9952 | Test Error: 0.9393 | Dyn var 2.74 | Obs var 100.00
# EM Iter 4 | Loss: 113.2272 | Train Error: 0.8867 | Val Error : 0.9955 | Test Error: 0.9399 | Dyn var 2.74 | Obs var 100.00
# EM Iter 5 | Loss: 107.8847 | Train Error: 0.8872 | Val Error : 0.9958 | Test Error: 0.9405 | Dyn var 2.74 | Obs var 100.00
# EM Iter 6 | Loss: 102.2891 | Train Error: 0.8877 | Val Error : 0.9960 | Test Error: 0.9411 | Dyn var 2.74 | Obs var 100.00
# EM Iter 7 | Loss: 97.9654 | Train Error: 0.8881 | Val Error : 0.9962 | Test Error: 0.9416 | Dyn var 2.74 | Obs var 100.00
# EM Iter 8 | Loss: 93.2046 | Train Error: 0.8884 | Val Error : 0.9963 | Test Error: 0.9420 | Dyn var 2.74 | Obs var 100.00
# EM Iter 9 | Loss: 89.9611 | Train Error: 0.8888 | Val Error : 0.9965 | Test Error: 0.9424 | Dyn var 2.74 | Obs var 100.00
# EM Iter 10 | Loss: 86.1080 | Train Error: 0.8891 | Val Error : 0.9966 | Test Error: 0.9428 | Dyn var 2.74 | Obs var 100.00
# EM Iter 11 | Loss: 83.4723 | Train Error: 0.8893 | Val Error : 0.9967 | Test Error: 0.9431 | Dyn var 2.74 | Obs var 100.00
# EM Iter 12 | Loss: 80.2065 | Train Error: 0.8896 | Val Error : 0.9968 | Test Error: 0.9434 | Dyn var 2.74 | Obs var 100.00
# EM Iter 13 | Loss: 77.9473 | Train Error: 0.8898 | Val Error : 0.9969 | Test Error: 0.9436 | Dyn var 2.74 | Obs var 100.00
# EM Iter 14 | Loss: 75.0547 | Train Error: 0.8899 | Val Error : 0.9969 | Test Error: 0.9438 | Dyn var 2.74 | Obs var 100.00
# EM Iter 15 | Loss: 73.5056 | Train Error: 0.8901 | Val Error : 0.9970 | Test Error: 0.9440 | Dyn var 2.74 | Obs var 100.00
# EM Iter 16 | Loss: 71.1653 | Train Error: 0.8902 | Val Error : 0.9971 | Test Error: 0.9441 | Dyn var 2.74 | Obs var 100.00
# EM Iter 17 | Loss: 69.9891 | Train Error: 0.8903 | Val Error : 0.9971 | Test Error: 0.9443 | Dyn var 2.74 | Obs var 100.00
# EM Iter 18 | Loss: 67.8569 | Train Error: 0.8904 | Val Error : 0.9971 | Test Error: 0.9443 | Dyn var 2.74 | Obs var 100.00
# EM Iter 19 | Loss: 66.8468 | Train Error: 0.8904 | Val Error : 0.9971 | Test Error: 0.9444 | Dyn var 2.74 | Obs var 100.00
# EM Iter 20 | Loss: 64.7272 | Train Error: 0.8904 | Val Error : 0.9971 | Test Error: 0.9444 | Dyn var 2.74 | Obs var 100.00
# EM Iter 21 | Loss: 63.6881 | Train Error: 0.8904 | Val Error : 0.9971 | Test Error: 0.9444 | Dyn var 2.74 | Obs var 100.00
# EM Iter 22 | Loss: 61.5372 | Train Error: 0.8904 | Val Error : 0.9971 | Test Error: 0.9443 | Dyn var 2.74 | Obs var 100.00
# EM Iter 23 | Loss: 60.5470 | Train Error: 0.8903 | Val Error : 0.9971 | Test Error: 0.9442 | Dyn var 2.74 | Obs var 100.00
# EM Iter 24 | Loss: 58.7307 | Train Error: 0.8902 | Val Error : 0.9970 | Test Error: 0.9441 | Dyn var 2.74 | Obs var 100.00
# EM Iter 25 | Loss: 58.0622 | Train Error: 0.8900 | Val Error : 0.9970 | Test Error: 0.9439 | Dyn var 2.74 | Obs var 100.00
# EM Iter 26 | Loss: 56.5735 | Train Error: 0.8898 | Val Error : 0.9969 | Test Error: 0.9437 | Dyn var 2.74 | Obs var 100.00
# EM Iter 27 | Loss: 56.0066 | Train Error: 0.8896 | Val Error : 0.9968 | Test Error: 0.9434 | Dyn var 2.74 | Obs var 100.00
# EM Iter 28 | Loss: 54.4939 | Train Error: 0.8894 | Val Error : 0.9967 | Test Error: 0.9432 | Dyn var 2.74 | Obs var 100.00
# EM Iter 29 | Loss: 53.9025 | Train Error: 0.8891 | Val Error : 0.9966 | Test Error: 0.9428 | Dyn var 2.74 | Obs var 100.00
# EM Iter 30 | Loss: 52.4654 | Train Error: 0.8888 | Val Error : 0.9965 | Test Error: 0.9425 | Dyn var 2.74 | Obs var 100.00
# EM Iter 31 | Loss: 52.0049 | Train Error: 0.8885 | Val Error : 0.9963 | Test Error: 0.9421 | Dyn var 2.74 | Obs var 100.00
# EM Iter 32 | Loss: 50.7806 | Train Error: 0.8881 | Val Error : 0.9962 | Test Error: 0.9416 | Dyn var 2.74 | Obs var 100.00
# EM Iter 33 | Loss: 50.3864 | Train Error: 0.8877 | Val Error : 0.9960 | Test Error: 0.9412 | Dyn var 2.74 | Obs var 100.00
# EM Iter 34 | Loss: 49.3130 | Train Error: 0.8873 | Val Error : 0.9958 | Test Error: 0.9407 | Dyn var 2.74 | Obs var 100.00
# EM Iter 35 | Loss: 49.1384 | Train Error: 0.8868 | Val Error : 0.9956 | Test Error: 0.9401 | Dyn var 2.74 | Obs var 100.00
# EM Iter 36 | Loss: 48.3098 | Train Error: 0.8863 | Val Error : 0.9954 | Test Error: 0.9395 | Dyn var 2.74 | Obs var 100.00
# EM Iter 37 | Loss: 48.3542 | Train Error: 0.8858 | Val Error : 0.9951 | Test Error: 0.9389 | Dyn var 2.74 | Obs var 100.00
# EM Iter 38 | Loss: 47.8367 | Train Error: 0.8852 | Val Error : 0.9948 | Test Error: 0.9383 | Dyn var 2.74 | Obs var 100.00
# EM Iter 39 | Loss: 47.9055 | Train Error: 0.8846 | Val Error : 0.9946 | Test Error: 0.9376 | Dyn var 2.74 | Obs var 100.00
# EM Iter 40 | Loss: 47.6797 | Train Error: 0.8840 | Val Error : 0.9943 | Test Error: 0.9370 | Dyn var 2.74 | Obs var 100.00
# EM Iter 41 | Loss: 47.7985 | Train Error: 0.8834 | Val Error : 0.9940 | Test Error: 0.9363 | Dyn var 2.74 | Obs var 100.00
# EM Iter 42 | Loss: 47.5703 | Train Error: 0.8828 | Val Error : 0.9936 | Test Error: 0.9356 | Dyn var 2.74 | Obs var 100.00
# EM Iter 43 | Loss: 47.6864 | Train Error: 0.8821 | Val Error : 0.9933 | Test Error: 0.9349 | Dyn var 2.74 | Obs var 100.00
# EM Iter 44 | Loss: 47.4557 | Train Error: 0.8814 | Val Error : 0.9929 | Test Error: 0.9341 | Dyn var 2.74 | Obs var 100.00
# EM Iter 45 | Loss: 47.5693 | Train Error: 0.8807 | Val Error : 0.9926 | Test Error: 0.9333 | Dyn var 2.74 | Obs var 100.00
# EM Iter 46 | Loss: 47.3359 | Train Error: 0.8800 | Val Error : 0.9922 | Test Error: 0.9326 | Dyn var 2.74 | Obs var 100.00
# EM Iter 47 | Loss: 47.4469 | Train Error: 0.8792 | Val Error : 0.9918 | Test Error: 0.9317 | Dyn var 2.74 | Obs var 100.00
# EM Iter 48 | Loss: 47.2109 | Train Error: 0.8784 | Val Error : 0.9913 | Test Error: 0.9309 | Dyn var 2.74 | Obs var 100.00
# EM Iter 49 | Loss: 47.3192 | Train Error: 0.8776 | Val Error : 0.9909 | Test Error: 0.9301 | Dyn var 2.74 | Obs var 100.00
# EM Iter 50 | Loss: 47.0805 | Train Error: 0.8767 | Val Error : 0.9904 | Test Error: 0.9292 | Dyn var 2.74 | Obs var 100.00
# EM Iter 51 | Loss: 47.1862 | Train Error: 0.8759 | Val Error : 0.9899 | Test Error: 0.9283 | Dyn var 2.74 | Obs var 100.00
# EM Iter 52 | Loss: 46.9449 | Train Error: 0.8749 | Val Error : 0.9894 | Test Error: 0.9274 | Dyn var 2.74 | Obs var 100.00
# EM Iter 53 | Loss: 47.0480 | Train Error: 0.8740 | Val Error : 0.9888 | Test Error: 0.9264 | Dyn var 2.74 | Obs var 100.00
# EM Iter 54 | Loss: 46.8040 | Train Error: 0.8730 | Val Error : 0.9883 | Test Error: 0.9254 | Dyn var 2.74 | Obs var 100.00
# EM Iter 55 | Loss: 46.9044 | Train Error: 0.8719 | Val Error : 0.9877 | Test Error: 0.9244 | Dyn var 2.74 | Obs var 100.00
# EM Iter 56 | Loss: 46.6579 | Train Error: 0.8709 | Val Error : 0.9870 | Test Error: 0.9234 | Dyn var 2.74 | Obs var 100.00
# EM Iter 57 | Loss: 46.7557 | Train Error: 0.8698 | Val Error : 0.9864 | Test Error: 0.9223 | Dyn var 2.74 | Obs var 100.00
# EM Iter 58 | Loss: 46.5065 | Train Error: 0.8686 | Val Error : 0.9857 | Test Error: 0.9212 | Dyn var 2.74 | Obs var 100.00
# EM Iter 59 | Loss: 46.6017 | Train Error: 0.8674 | Val Error : 0.9850 | Test Error: 0.9201 | Dyn var 2.74 | Obs var 100.00
# EM Iter 60 | Loss: 46.3500 | Train Error: 0.8661 | Val Error : 0.9842 | Test Error: 0.9190 | Dyn var 2.74 | Obs var 100.00
# EM Iter 61 | Loss: 46.4426 | Train Error: 0.8648 | Val Error : 0.9835 | Test Error: 0.9178 | Dyn var 2.74 | Obs var 100.00
# EM Iter 62 | Loss: 46.1884 | Train Error: 0.8635 | Val Error : 0.9826 | Test Error: 0.9165 | Dyn var 2.74 | Obs var 100.00
# EM Iter 63 | Loss: 46.2785 | Train Error: 0.8621 | Val Error : 0.9818 | Test Error: 0.9153 | Dyn var 2.74 | Obs var 100.00
# EM Iter 64 | Loss: 46.0217 | Train Error: 0.8606 | Val Error : 0.9809 | Test Error: 0.9140 | Dyn var 2.74 | Obs var 100.00
# EM Iter 65 | Loss: 46.1094 | Train Error: 0.8590 | Val Error : 0.9800 | Test Error: 0.9127 | Dyn var 2.74 | Obs var 100.00
# EM Iter 66 | Loss: 45.8501 | Train Error: 0.8574 | Val Error : 0.9790 | Test Error: 0.9113 | Dyn var 2.74 | Obs var 100.00
# EM Iter 67 | Loss: 45.9353 | Train Error: 0.8558 | Val Error : 0.9780 | Test Error: 0.9099 | Dyn var 2.74 | Obs var 100.00
# EM Iter 68 | Loss: 45.6736 | Train Error: 0.8540 | Val Error : 0.9769 | Test Error: 0.9084 | Dyn var 2.74 | Obs var 100.00
# EM Iter 69 | Loss: 45.7564 | Train Error: 0.8522 | Val Error : 0.9758 | Test Error: 0.9069 | Dyn var 2.74 | Obs var 100.00
# EM Iter 70 | Loss: 45.4923 | Train Error: 0.8503 | Val Error : 0.9747 | Test Error: 0.9053 | Dyn var 2.74 | Obs var 100.00
# EM Iter 71 | Loss: 45.5728 | Train Error: 0.8483 | Val Error : 0.9735 | Test Error: 0.9037 | Dyn var 2.74 | Obs var 100.00
# EM Iter 72 | Loss: 45.3063 | Train Error: 0.8462 | Val Error : 0.9722 | Test Error: 0.9021 | Dyn var 2.74 | Obs var 100.00
# EM Iter 73 | Loss: 45.3844 | Train Error: 0.8441 | Val Error : 0.9709 | Test Error: 0.9004 | Dyn var 2.74 | Obs var 100.00
# EM Iter 74 | Loss: 45.1157 | Train Error: 0.8418 | Val Error : 0.9695 | Test Error: 0.8986 | Dyn var 2.74 | Obs var 100.00
# EM Iter 75 | Loss: 45.1915 | Train Error: 0.8394 | Val Error : 0.9681 | Test Error: 0.8968 | Dyn var 2.74 | Obs var 100.00
# EM Iter 76 | Loss: 44.9204 | Train Error: 0.8370 | Val Error : 0.9666 | Test Error: 0.8948 | Dyn var 2.74 | Obs var 100.00
# EM Iter 77 | Loss: 44.9940 | Train Error: 0.8344 | Val Error : 0.9650 | Test Error: 0.8929 | Dyn var 2.74 | Obs var 100.00
# EM Iter 78 | Loss: 44.7207 | Train Error: 0.8316 | Val Error : 0.9634 | Test Error: 0.8909 | Dyn var 2.74 | Obs var 100.00
# EM Iter 79 | Loss: 44.7920 | Train Error: 0.8288 | Val Error : 0.9617 | Test Error: 0.8888 | Dyn var 2.74 | Obs var 100.00
# EM Iter 80 | Loss: 44.5165 | Train Error: 0.8258 | Val Error : 0.9599 | Test Error: 0.8866 | Dyn var 2.74 | Obs var 100.00
# EM Iter 81 | Loss: 44.5857 | Train Error: 0.8227 | Val Error : 0.9580 | Test Error: 0.8843 | Dyn var 2.74 | Obs var 100.00
# EM Iter 82 | Loss: 44.3080 | Train Error: 0.8194 | Val Error : 0.9561 | Test Error: 0.8819 | Dyn var 2.74 | Obs var 100.00
# EM Iter 83 | Loss: 44.3750 | Train Error: 0.8160 | Val Error : 0.9541 | Test Error: 0.8795 | Dyn var 2.74 | Obs var 100.00
# EM Iter 84 | Loss: 44.0952 | Train Error: 0.8124 | Val Error : 0.9519 | Test Error: 0.8770 | Dyn var 2.74 | Obs var 100.00
# EM Iter 85 | Loss: 44.1601 | Train Error: 0.8087 | Val Error : 0.9497 | Test Error: 0.8743 | Dyn var 2.74 | Obs var 100.00
# EM Iter 86 | Loss: 43.8782 | Train Error: 0.8047 | Val Error : 0.9474 | Test Error: 0.8715 | Dyn var 2.74 | Obs var 100.00
# EM Iter 87 | Loss: 43.9410 | Train Error: 0.8006 | Val Error : 0.9450 | Test Error: 0.8687 | Dyn var 2.74 | Obs var 100.00
# EM Iter 88 | Loss: 43.6571 | Train Error: 0.7962 | Val Error : 0.9424 | Test Error: 0.8657 | Dyn var 2.74 | Obs var 100.00
# EM Iter 89 | Loss: 43.7178 | Train Error: 0.7916 | Val Error : 0.9398 | Test Error: 0.8625 | Dyn var 2.74 | Obs var 100.00
# EM Iter 90 | Loss: 43.4319 | Train Error: 0.7868 | Val Error : 0.9370 | Test Error: 0.8592 | Dyn var 2.74 | Obs var 100.00
# EM Iter 91 | Loss: 43.4906 | Train Error: 0.7817 | Val Error : 0.9341 | Test Error: 0.8558 | Dyn var 2.74 | Obs var 100.00
# EM Iter 92 | Loss: 43.2026 | Train Error: 0.7764 | Val Error : 0.9311 | Test Error: 0.8522 | Dyn var 2.74 | Obs var 100.00
# EM Iter 93 | Loss: 43.2594 | Train Error: 0.7708 | Val Error : 0.9280 | Test Error: 0.8484 | Dyn var 2.74 | Obs var 100.00
# EM Iter 94 | Loss: 42.9694 | Train Error: 0.7649 | Val Error : 0.9246 | Test Error: 0.8444 | Dyn var 2.74 | Obs var 100.00
# EM Iter 95 | Loss: 43.0242 | Train Error: 0.7588 | Val Error : 0.9212 | Test Error: 0.8403 | Dyn var 2.74 | Obs var 100.00
# EM Iter 96 | Loss: 42.7324 | Train Error: 0.7522 | Val Error : 0.9176 | Test Error: 0.8359 | Dyn var 2.74 | Obs var 100.00
# EM Iter 97 | Loss: 42.7852 | Train Error: 0.7454 | Val Error : 0.9139 | Test Error: 0.8313 | Dyn var 2.74 | Obs var 100.00
# EM Iter 98 | Loss: 42.4915 | Train Error: 0.7382 | Val Error : 0.9099 | Test Error: 0.8264 | Dyn var 2.74 | Obs var 100.00
# EM Iter 99 | Loss: 42.5424 | Train Error: 0.7306 | Val Error : 0.9059 | Test Error: 0.8213 | Dyn var 2.74 | Obs var 100.00
# EM Iter 100 | Loss: 42.2468 | Train Error: 0.7226 | Val Error : 0.9016 | Test Error: 0.8159 | Dyn var 2.74 | Obs var 100.00
# EM Iter 101 | Loss: 42.2959 | Train Error: 0.7142 | Val Error : 0.8972 | Test Error: 0.8102 | Dyn var 2.74 | Obs var 100.00
# EM Iter 102 | Loss: 41.9984 | Train Error: 0.7053 | Val Error : 0.8925 | Test Error: 0.8042 | Dyn var 2.74 | Obs var 100.00
# EM Iter 103 | Loss: 42.0456 | Train Error: 0.6960 | Val Error : 0.8877 | Test Error: 0.7978 | Dyn var 2.74 | Obs var 100.00
# EM Iter 104 | Loss: 41.7463 | Train Error: 0.6861 | Val Error : 0.8826 | Test Error: 0.7910 | Dyn var 2.74 | Obs var 100.00
# EM Iter 105 | Loss: 41.7917 | Train Error: 0.6758 | Val Error : 0.8774 | Test Error: 0.7839 | Dyn var 2.74 | Obs var 100.00
# EM Iter 106 | Loss: 41.4906 | Train Error: 0.6649 | Val Error : 0.8719 | Test Error: 0.7763 | Dyn var 2.74 | Obs var 100.00
# EM Iter 107 | Loss: 41.5342 | Train Error: 0.6535 | Val Error : 0.8663 | Test Error: 0.7683 | Dyn var 2.74 | Obs var 100.00
# EM Iter 108 | Loss: 41.2313 | Train Error: 0.6415 | Val Error : 0.8603 | Test Error: 0.7598 | Dyn var 2.74 | Obs var 100.00
# EM Iter 109 | Loss: 41.2732 | Train Error: 0.6289 | Val Error : 0.8542 | Test Error: 0.7508 | Dyn var 2.74 | Obs var 100.00
# EM Iter 110 | Loss: 40.9685 | Train Error: 0.6155 | Val Error : 0.8477 | Test Error: 0.7411 | Dyn var 2.74 | Obs var 100.00
# EM Iter 111 | Loss: 41.0087 | Train Error: 0.6017 | Val Error : 0.8411 | Test Error: 0.7310 | Dyn var 2.74 | Obs var 100.00
# EM Iter 112 | Loss: 40.7023 | Train Error: 0.5872 | Val Error : 0.8341 | Test Error: 0.7201 | Dyn var 2.74 | Obs var 100.00
# EM Iter 113 | Loss: 40.7407 | Train Error: 0.5724 | Val Error : 0.8270 | Test Error: 0.7086 | Dyn var 2.74 | Obs var 100.00
# EM Iter 114 | Loss: 40.4326 | Train Error: 0.5572 | Val Error : 0.8194 | Test Error: 0.6963 | Dyn var 2.74 | Obs var 100.00
# EM Iter 115 | Loss: 40.4693 | Train Error: 0.5420 | Val Error : 0.8117 | Test Error: 0.6834 | Dyn var 2.74 | Obs var 100.00
# EM Iter 116 | Loss: 40.1595 | Train Error: 0.5265 | Val Error : 0.8036 | Test Error: 0.6695 | Dyn var 2.74 | Obs var 100.00
# EM Iter 117 | Loss: 40.1946 | Train Error: 0.5112 | Val Error : 0.7952 | Test Error: 0.6549 | Dyn var 2.74 | Obs var 100.00
# EM Iter 118 | Loss: 39.8831 | Train Error: 0.4956 | Val Error : 0.7865 | Test Error: 0.6392 | Dyn var 2.74 | Obs var 100.00
# EM Iter 119 | Loss: 39.9165 | Train Error: 0.4808 | Val Error : 0.7775 | Test Error: 0.6227 | Dyn var 2.74 | Obs var 100.00
# EM Iter 120 | Loss: 39.6034 | Train Error: 0.4668 | Val Error : 0.7681 | Test Error: 0.6050 | Dyn var 2.74 | Obs var 100.00
# EM Iter 121 | Loss: 39.6352 | Train Error: 0.4552 | Val Error : 0.7584 | Test Error: 0.5865 | Dyn var 2.74 | Obs var 100.00
# EM Iter 122 | Loss: 39.3205 | Train Error: 0.4456 | Val Error : 0.7483 | Test Error: 0.5665 | Dyn var 2.74 | Obs var 100.00
# EM Iter 123 | Loss: 39.3506 | Train Error: 0.4388 | Val Error : 0.7379 | Test Error: 0.5456 | Dyn var 2.74 | Obs var 100.00
# EM Iter 124 | Loss: 39.0343 | Train Error: 0.4343 | Val Error : 0.7269 | Test Error: 0.5232 | Dyn var 2.74 | Obs var 100.00
# EM Iter 125 | Loss: 39.0628 | Train Error: 0.4319 | Val Error : 0.7157 | Test Error: 0.4997 | Dyn var 2.74 | Obs var 100.00
# EM Iter 126 | Loss: 38.7449 | Train Error: 0.4309 | Val Error : 0.7039 | Test Error: 0.4745 | Dyn var 2.74 | Obs var 100.00
# EM Iter 127 | Loss: 38.7719 | Train Error: 0.4322 | Val Error : 0.6919 | Test Error: 0.4483 | Dyn var 2.74 | Obs var 100.00
# EM Iter 128 | Loss: 38.4524 | Train Error: 0.4357 | Val Error : 0.6791 | Test Error: 0.4200 | Dyn var 2.74 | Obs var 100.00
# EM Iter 129 | Loss: 38.4778 | Train Error: 0.4417 | Val Error : 0.6660 | Test Error: 0.3907 | Dyn var 2.74 | Obs var 100.00
# EM Iter 130 | Loss: 38.1567 | Train Error: 0.4502 | Val Error : 0.6521 | Test Error: 0.3591 | Dyn var 2.74 | Obs var 100.00
# EM Iter 131 | Loss: 38.1806 | Train Error: 0.4611 | Val Error : 0.6377 | Test Error: 0.3264 | Dyn var 2.74 | Obs var 100.00
# EM Iter 132 | Loss: 37.8580 | Train Error: 0.4748 | Val Error : 0.6224 | Test Error: 0.2912 | Dyn var 2.74 | Obs var 100.00
# EM Iter 133 | Loss: 37.8804 | Train Error: 0.4909 | Val Error : 0.6065 | Test Error: 0.2548 | Dyn var 2.74 | Obs var 100.00
# EM Iter 134 | Loss: 37.5563 | Train Error: 0.5106 | Val Error : 0.5893 | Test Error: 0.2157 | Dyn var 2.74 | Obs var 100.00
# EM Iter 135 | Loss: 37.5771 | Train Error: 0.5336 | Val Error : 0.5714 | Test Error: 0.1753 | Dyn var 2.74 | Obs var 100.00
# EM Iter 136 | Loss: 37.2515 | Train Error: 0.5607 | Val Error : 0.5518 | Test Error: 0.1441 | Dyn var 2.74 | Obs var 100.00
# EM Iter 137 | Loss: 37.2708 | Train Error: 0.5914 | Val Error : 0.5310 | Test Error: 0.1181 | Dyn var 2.74 | Obs var 100.00
# EM Iter 138 | Loss: 36.9438 | Train Error: 0.6271 | Val Error : 0.5079 | Test Error: 0.1082 | Dyn var 2.74 | Obs var 100.00
# EM Iter 139 | Loss: 36.9616 | Train Error: 0.6662 | Val Error : 0.4832 | Test Error: 0.1246 | Dyn var 2.74 | Obs var 100.00
# EM Iter 140 | Loss: 36.6331 | Train Error: 0.7106 | Val Error : 0.4553 | Test Error: 0.1501 | Dyn var 2.74 | Obs var 100.00
# EM Iter 141 | Loss: 36.6495 | Train Error: 0.7578 | Val Error : 0.4375 | Test Error: 0.1804 | Dyn var 2.74 | Obs var 100.00
# EM Iter 142 | Loss: 36.3195 | Train Error: 0.8102 | Val Error : 0.4226 | Test Error: 0.2213 | Dyn var 2.74 | Obs var 100.00
# EM Iter 143 | Loss: 36.3344 | Train Error: 0.8665 | Val Error : 0.4042 | Test Error: 0.2660 | Dyn var 2.74 | Obs var 100.00
# EM Iter 144 | Loss: 36.0030 | Train Error: 0.9288 | Val Error : 0.3809 | Test Error: 0.3147 | Dyn var 2.74 | Obs var 100.00
# EM Iter 145 | Loss: 36.0165 | Train Error: 0.9948 | Val Error : 0.3527 | Test Error: 0.3669 | Dyn var 2.74 | Obs var 100.00
# EM Iter 146 | Loss: 35.6836 | Train Error: 1.0672 | Val Error : 0.3172 | Test Error: 0.4328 | Dyn var 2.74 | Obs var 100.00
# EM Iter 147 | Loss: 35.6957 | Train Error: 1.1439 | Val Error : 0.2748 | Test Error: 0.5039 | Dyn var 2.74 | Obs var 100.00
# EM Iter 148 | Loss: 35.3614 | Train Error: 1.2290 | Val Error : 0.2221 | Test Error: 0.5798 | Dyn var 2.74 | Obs var 100.00
# EM Iter 149 | Loss: 35.3721 | Train Error: 1.3178 | Val Error : 0.1661 | Test Error: 0.6573 | Dyn var 2.74 | Obs var 100.00
# EM Iter 150 | Loss: 35.0364 | Train Error: 1.4159 | Val Error : 0.1458 | Test Error: 0.7399 | Dyn var 2.74 | Obs var 100.00
# EM Iter 151 | Loss: 35.0457 | Train Error: 1.5183 | Val Error : 0.2486 | Test Error: 0.8241 | Dyn var 2.74 | Obs var 100.00
# EM Iter 152 | Loss: 34.7087 | Train Error: 1.6306 | Val Error : 0.3847 | Test Error: 0.9138 | Dyn var 2.74 | Obs var 100.00
# EM Iter 153 | Loss: 34.7165 | Train Error: 1.7476 | Val Error : 0.5376 | Test Error: 1.0051 | Dyn var 2.74 | Obs var 100.00
# EM Iter 154 | Loss: 34.3782 | Train Error: 1.8747 | Val Error : 0.7173 | Test Error: 1.1024 | Dyn var 2.74 | Obs var 100.00
# EM Iter 155 | Loss: 34.3847 | Train Error: 2.0062 | Val Error : 0.9182 | Test Error: 1.2011 | Dyn var 2.74 | Obs var 100.00
# EM Iter 156 | Loss: 34.0449 | Train Error: 2.1498 | Val Error : 1.1534 | Test Error: 1.3064 | Dyn var 2.74 | Obs var 100.00
# EM Iter 157 | Loss: 34.0500 | Train Error: 2.2986 | Val Error : 1.4146 | Test Error: 1.4129 | Dyn var 2.74 | Obs var 100.00
# EM Iter 158 | Loss: 33.7090 | Train Error: 2.4593 | Val Error : 1.7190 | Test Error: 1.5266 | Dyn var 2.74 | Obs var 100.00
# EM Iter 159 | Loss: 33.7127 | Train Error: 2.6241 | Val Error : 2.0548 | Test Error: 1.6414 | Dyn var 2.74 | Obs var 100.00
# EM Iter 160 | Loss: 33.3704 | Train Error: 2.8019 | Val Error : 2.4442 | Test Error: 1.7640 | Dyn var 2.74 | Obs var 100.00
# EM Iter 161 | Loss: 33.3728 | Train Error: 2.9834 | Val Error : 2.8706 | Test Error: 1.8876 | Dyn var 2.74 | Obs var 100.00
# EM Iter 162 | Loss: 33.0291 | Train Error: 3.1791 | Val Error : 3.3623 | Test Error: 2.0195 | Dyn var 2.74 | Obs var 100.00
# EM Iter 163 | Loss: 33.0302 | Train Error: 3.3788 | Val Error : 3.8968 | Test Error: 2.1522 | Dyn var 2.74 | Obs var 100.00
# EM Iter 164 | Loss: 32.6852 | Train Error: 3.5951 | Val Error : 4.5101 | Test Error: 2.2941 | Dyn var 2.74 | Obs var 100.00
# EM Iter 165 | Loss: 32.6850 | Train Error: 3.8156 | Val Error : 5.1719 | Test Error: 2.4364 | Dyn var 2.74 | Obs var 100.00
# EM Iter 166 | Loss: 32.3387 | Train Error: 4.0538 | Val Error : 5.9273 | Test Error: 2.5886 | Dyn var 2.74 | Obs var 100.00
# EM Iter 167 | Loss: 32.3371 | Train Error: 4.2955 | Val Error : 6.7367 | Test Error: 2.7411 | Dyn var 2.74 | Obs var 100.00
# EM Iter 168 | Loss: 31.9896 | Train Error: 4.5563 | Val Error : 7.6562 | Test Error: 2.9042 | Dyn var 2.74 | Obs var 100.00
# EM Iter 169 | Loss: 31.9868 | Train Error: 4.8206 | Val Error : 8.6348 | Test Error: 3.0673 | Dyn var 2.74 | Obs var 100.00
# EM Iter 170 | Loss: 31.6380 | Train Error: 5.1060 | Val Error : 9.7414 | Test Error: 3.2420 | Dyn var 2.74 | Obs var 100.00
# EM Iter 171 | Loss: 31.6338 | Train Error: 5.3945 | Val Error : 10.9116 | Test Error: 3.4162 | Dyn var 2.74 | Obs var 100.00
# EM Iter 172 | Loss: 31.2838 | Train Error: 5.7062 | Val Error : 12.2292 | Test Error: 3.6031 | Dyn var 2.74 | Obs var 100.00
# EM Iter 173 | Loss: 31.2784 | Train Error: 6.0207 | Val Error : 13.6140 | Test Error: 3.7890 | Dyn var 2.74 | Obs var 100.00
# EM Iter 174 | Loss: 30.9271 | Train Error: 6.3604 | Val Error : 15.1673 | Test Error: 3.9886 | Dyn var 2.74 | Obs var 100.00
# EM Iter 175 | Loss: 30.9204 | Train Error: 6.7032 | Val Error : 16.7903 | Test Error: 4.1868 | Dyn var 2.74 | Obs var 100.00
# EM Iter 176 | Loss: 30.5680 | Train Error: 7.0735 | Val Error : 18.6045 | Test Error: 4.3999 | Dyn var 2.74 | Obs var 100.00
# EM Iter 177 | Loss: 30.5599 | Train Error: 7.4457 | Val Error : 20.4896 | Test Error: 4.6111 | Dyn var 2.74 | Obs var 100.00
# EM Iter 178 | Loss: 30.2063 | Train Error: 7.8477 | Val Error : 22.5900 | Test Error: 4.8383 | Dyn var 2.74 | Obs var 100.00
# EM Iter 179 | Loss: 30.1970 | Train Error: 8.2510 | Val Error : 24.7615 | Test Error: 5.0630 | Dyn var 2.74 | Obs var 100.00
# EM Iter 180 | Loss: 29.8422 | Train Error: 8.6867 | Val Error : 27.1739 | Test Error: 5.3052 | Dyn var 2.74 | Obs var 100.00
# EM Iter 181 | Loss: 29.8316 | Train Error: 9.1231 | Val Error : 29.6561 | Test Error: 5.5441 | Dyn var 2.74 | Obs var 100.00
# EM Iter 182 | Loss: 29.4757 | Train Error: 9.5947 | Val Error : 32.4063 | Test Error: 5.8020 | Dyn var 2.74 | Obs var 100.00
# EM Iter 183 | Loss: 29.4639 | Train Error: 10.0661 | Val Error : 35.2236 | Test Error: 6.0557 | Dyn var 2.74 | Obs var 100.00
# EM Iter 184 | Loss: 29.1068 | Train Error: 10.5759 | Val Error : 38.3374 | Test Error: 6.3303 | Dyn var 2.74 | Obs var 100.00
# EM Iter 185 | Loss: 29.0937 | Train Error: 11.0848 | Val Error : 41.5144 | Test Error: 6.5997 | Dyn var 2.74 | Obs var 100.00
# EM Iter 186 | Loss: 28.7355 | Train Error: 11.6349 | Val Error : 45.0178 | Test Error: 6.8917 | Dyn var 2.74 | Obs var 100.00
# EM Iter 187 | Loss: 28.7211 | Train Error: 12.1833 | Val Error : 48.5789 | Test Error: 7.1774 | Dyn var 2.74 | Obs var 100.00
# EM Iter 188 | Loss: 28.3618 | Train Error: 12.7760 | Val Error : 52.4979 | Test Error: 7.4879 | Dyn var 2.74 | Obs var 100.00
# EM Iter 189 | Loss: 28.3461 | Train Error: 13.3660 | Val Error : 56.4678 | Test Error: 7.7908 | Dyn var 2.74 | Obs var 100.00
# EM Iter 190 | Loss: 27.9857 | Train Error: 14.0037 | Val Error : 60.8283 | Test Error: 8.1206 | Dyn var 2.74 | Obs var 100.00
# EM Iter 191 | Loss: 27.9689 | Train Error: 14.6376 | Val Error : 65.2317 | Test Error: 8.4416 | Dyn var 2.74 | Obs var 100.00
# EM Iter 192 | Loss: 27.6074 | Train Error: 15.3229 | Val Error : 70.0598 | Test Error: 8.7919 | Dyn var 2.74 | Obs var 100.00
# EM Iter 193 | Loss: 27.5892 | Train Error: 16.0031 | Val Error : 74.9218 | Test Error: 9.1317 | Dyn var 2.74 | Obs var 100.00
# EM Iter 194 | Loss: 27.2267 | Train Error: 16.7385 | Val Error : 80.2438 | Test Error: 9.5036 | Dyn var 2.74 | Obs var 100.00
# EM Iter 195 | Loss: 27.2073 | Train Error: 17.4676 | Val Error : 85.5897 | Test Error: 9.8632 | Dyn var 2.74 | Obs var 100.00
# EM Iter 196 | Loss: 26.8437 | Train Error: 18.2557 | Val Error : 91.4320 | Test Error: 10.2578 | Dyn var 2.74 | Obs var 100.00
# EM Iter 197 | Loss: 26.8231 | Train Error: 19.0362 | Val Error : 97.2873 | Test Error: 10.6382 | Dyn var 2.74 | Obs var 100.00
# EM Iter 198 | Loss: 26.4584 | Train Error: 19.8798 | Val Error : 103.6767 | Test Error: 11.0567 | Dyn var 2.74 | Obs var 100.00
# EM Iter 199 | Loss: 26.4366 | Train Error: 20.7144 | Val Error : 110.0677 | Test Error: 11.4588 | Dyn var 2.74 | Obs var 100.00
# best val error: 0.14583165563893957 at 150th iteration, Model Performance: 0.7399188144516743 | theta_dim = 8
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# theta_dim = 9
# EM Iter 0 | Loss: 173.1940 | Train Error: 0.8453 | Val Error : 0.9716 | Test Error: 0.9014 | Dyn var 2.92 | Obs var 100.00
# EM Iter 1 | Loss: 157.3982 | Train Error: 0.8490 | Val Error : 0.9738 | Test Error: 0.9043 | Dyn var 2.92 | Obs var 100.00
# EM Iter 2 | Loss: 145.9367 | Train Error: 0.8518 | Val Error : 0.9755 | Test Error: 0.9066 | Dyn var 2.92 | Obs var 100.00
# EM Iter 3 | Loss: 136.8240 | Train Error: 0.8541 | Val Error : 0.9770 | Test Error: 0.9085 | Dyn var 2.92 | Obs var 100.00
# EM Iter 4 | Loss: 129.1052 | Train Error: 0.8561 | Val Error : 0.9782 | Test Error: 0.9102 | Dyn var 2.92 | Obs var 100.00
# EM Iter 5 | Loss: 121.9089 | Train Error: 0.8578 | Val Error : 0.9792 | Test Error: 0.9116 | Dyn var 2.92 | Obs var 100.00
# EM Iter 6 | Loss: 115.6228 | Train Error: 0.8593 | Val Error : 0.9801 | Test Error: 0.9129 | Dyn var 2.92 | Obs var 100.00
# EM Iter 7 | Loss: 109.4388 | Train Error: 0.8607 | Val Error : 0.9809 | Test Error: 0.9141 | Dyn var 2.92 | Obs var 100.00
# EM Iter 8 | Loss: 104.4420 | Train Error: 0.8618 | Val Error : 0.9816 | Test Error: 0.9151 | Dyn var 2.92 | Obs var 100.00
# EM Iter 9 | Loss: 99.4184 | Train Error: 0.8629 | Val Error : 0.9823 | Test Error: 0.9160 | Dyn var 2.92 | Obs var 100.00
# EM Iter 10 | Loss: 95.8646 | Train Error: 0.8638 | Val Error : 0.9828 | Test Error: 0.9169 | Dyn var 2.92 | Obs var 100.00
# EM Iter 11 | Loss: 91.9427 | Train Error: 0.8647 | Val Error : 0.9834 | Test Error: 0.9176 | Dyn var 2.92 | Obs var 100.00
# EM Iter 12 | Loss: 89.0620 | Train Error: 0.8654 | Val Error : 0.9838 | Test Error: 0.9183 | Dyn var 2.92 | Obs var 100.00
# EM Iter 13 | Loss: 86.1030 | Train Error: 0.8661 | Val Error : 0.9842 | Test Error: 0.9190 | Dyn var 2.92 | Obs var 100.00
# EM Iter 14 | Loss: 83.9165 | Train Error: 0.8667 | Val Error : 0.9846 | Test Error: 0.9195 | Dyn var 2.92 | Obs var 100.00
# EM Iter 15 | Loss: 81.2543 | Train Error: 0.8672 | Val Error : 0.9849 | Test Error: 0.9200 | Dyn var 2.92 | Obs var 100.00
# EM Iter 16 | Loss: 79.2577 | Train Error: 0.8677 | Val Error : 0.9851 | Test Error: 0.9204 | Dyn var 2.92 | Obs var 100.00
# EM Iter 17 | Loss: 76.7270 | Train Error: 0.8680 | Val Error : 0.9853 | Test Error: 0.9207 | Dyn var 2.92 | Obs var 100.00
# EM Iter 18 | Loss: 74.9375 | Train Error: 0.8683 | Val Error : 0.9855 | Test Error: 0.9210 | Dyn var 2.92 | Obs var 100.00
# EM Iter 19 | Loss: 72.5936 | Train Error: 0.8685 | Val Error : 0.9856 | Test Error: 0.9211 | Dyn var 2.92 | Obs var 100.00
# EM Iter 20 | Loss: 70.9905 | Train Error: 0.8686 | Val Error : 0.9857 | Test Error: 0.9213 | Dyn var 2.92 | Obs var 100.00
# EM Iter 21 | Loss: 68.6526 | Train Error: 0.8686 | Val Error : 0.9857 | Test Error: 0.9213 | Dyn var 2.92 | Obs var 100.00
# EM Iter 22 | Loss: 67.2660 | Train Error: 0.8686 | Val Error : 0.9857 | Test Error: 0.9213 | Dyn var 2.92 | Obs var 100.00
# EM Iter 23 | Loss: 65.0693 | Train Error: 0.8685 | Val Error : 0.9856 | Test Error: 0.9212 | Dyn var 2.92 | Obs var 100.00
# EM Iter 24 | Loss: 64.0833 | Train Error: 0.8683 | Val Error : 0.9855 | Test Error: 0.9210 | Dyn var 2.92 | Obs var 100.00
# EM Iter 25 | Loss: 62.0841 | Train Error: 0.8680 | Val Error : 0.9854 | Test Error: 0.9207 | Dyn var 2.92 | Obs var 100.00
# EM Iter 26 | Loss: 61.1997 | Train Error: 0.8677 | Val Error : 0.9852 | Test Error: 0.9204 | Dyn var 2.92 | Obs var 100.00
# EM Iter 27 | Loss: 59.3001 | Train Error: 0.8673 | Val Error : 0.9849 | Test Error: 0.9200 | Dyn var 2.92 | Obs var 100.00
# EM Iter 28 | Loss: 58.4991 | Train Error: 0.8668 | Val Error : 0.9846 | Test Error: 0.9196 | Dyn var 2.92 | Obs var 100.00
# EM Iter 29 | Loss: 56.6302 | Train Error: 0.8662 | Val Error : 0.9843 | Test Error: 0.9190 | Dyn var 2.92 | Obs var 100.00
# EM Iter 30 | Loss: 55.8015 | Train Error: 0.8655 | Val Error : 0.9839 | Test Error: 0.9184 | Dyn var 2.92 | Obs var 100.00
# EM Iter 31 | Loss: 54.3506 | Train Error: 0.8648 | Val Error : 0.9834 | Test Error: 0.9177 | Dyn var 2.92 | Obs var 100.00
# EM Iter 32 | Loss: 53.7684 | Train Error: 0.8639 | Val Error : 0.9829 | Test Error: 0.9170 | Dyn var 2.92 | Obs var 100.00
# EM Iter 33 | Loss: 52.4917 | Train Error: 0.8630 | Val Error : 0.9824 | Test Error: 0.9162 | Dyn var 2.92 | Obs var 100.00
# EM Iter 34 | Loss: 52.0885 | Train Error: 0.8621 | Val Error : 0.9818 | Test Error: 0.9153 | Dyn var 2.92 | Obs var 100.00
# EM Iter 35 | Loss: 51.1877 | Train Error: 0.8610 | Val Error : 0.9812 | Test Error: 0.9144 | Dyn var 2.92 | Obs var 100.00
# EM Iter 36 | Loss: 50.9618 | Train Error: 0.8599 | Val Error : 0.9805 | Test Error: 0.9134 | Dyn var 2.92 | Obs var 100.00
# EM Iter 37 | Loss: 50.2925 | Train Error: 0.8587 | Val Error : 0.9798 | Test Error: 0.9124 | Dyn var 2.92 | Obs var 100.00
# EM Iter 38 | Loss: 50.3019 | Train Error: 0.8574 | Val Error : 0.9790 | Test Error: 0.9113 | Dyn var 2.92 | Obs var 100.00
# EM Iter 39 | Loss: 49.9977 | Train Error: 0.8561 | Val Error : 0.9782 | Test Error: 0.9102 | Dyn var 2.92 | Obs var 100.00
# EM Iter 40 | Loss: 50.1904 | Train Error: 0.8548 | Val Error : 0.9774 | Test Error: 0.9090 | Dyn var 2.92 | Obs var 100.00
# EM Iter 41 | Loss: 49.8834 | Train Error: 0.8534 | Val Error : 0.9765 | Test Error: 0.9079 | Dyn var 2.92 | Obs var 100.00
# EM Iter 42 | Loss: 50.0732 | Train Error: 0.8519 | Val Error : 0.9756 | Test Error: 0.9066 | Dyn var 2.92 | Obs var 100.00
# EM Iter 43 | Loss: 49.7634 | Train Error: 0.8504 | Val Error : 0.9747 | Test Error: 0.9054 | Dyn var 2.92 | Obs var 100.00
# EM Iter 44 | Loss: 49.9503 | Train Error: 0.8488 | Val Error : 0.9738 | Test Error: 0.9041 | Dyn var 2.92 | Obs var 100.00
# EM Iter 45 | Loss: 49.6375 | Train Error: 0.8471 | Val Error : 0.9728 | Test Error: 0.9028 | Dyn var 2.92 | Obs var 100.00
# EM Iter 46 | Loss: 49.8215 | Train Error: 0.8454 | Val Error : 0.9717 | Test Error: 0.9014 | Dyn var 2.92 | Obs var 100.00
# EM Iter 47 | Loss: 49.5058 | Train Error: 0.8436 | Val Error : 0.9706 | Test Error: 0.9000 | Dyn var 2.92 | Obs var 100.00
# EM Iter 48 | Loss: 49.6868 | Train Error: 0.8418 | Val Error : 0.9695 | Test Error: 0.8986 | Dyn var 2.92 | Obs var 100.00
# EM Iter 49 | Loss: 49.3680 | Train Error: 0.8398 | Val Error : 0.9683 | Test Error: 0.8971 | Dyn var 2.92 | Obs var 100.00
# EM Iter 50 | Loss: 49.5460 | Train Error: 0.8378 | Val Error : 0.9671 | Test Error: 0.8955 | Dyn var 2.92 | Obs var 100.00
# EM Iter 51 | Loss: 49.2242 | Train Error: 0.8357 | Val Error : 0.9658 | Test Error: 0.8939 | Dyn var 2.92 | Obs var 100.00
# EM Iter 52 | Loss: 49.3991 | Train Error: 0.8335 | Val Error : 0.9645 | Test Error: 0.8923 | Dyn var 2.92 | Obs var 100.00
# EM Iter 53 | Loss: 49.0743 | Train Error: 0.8312 | Val Error : 0.9631 | Test Error: 0.8906 | Dyn var 2.92 | Obs var 100.00
# EM Iter 54 | Loss: 49.2463 | Train Error: 0.8289 | Val Error : 0.9617 | Test Error: 0.8888 | Dyn var 2.92 | Obs var 100.00
# EM Iter 55 | Loss: 48.9185 | Train Error: 0.8264 | Val Error : 0.9602 | Test Error: 0.8870 | Dyn var 2.92 | Obs var 100.00
# EM Iter 56 | Loss: 49.0875 | Train Error: 0.8238 | Val Error : 0.9587 | Test Error: 0.8851 | Dyn var 2.92 | Obs var 100.00
# EM Iter 57 | Loss: 48.7567 | Train Error: 0.8211 | Val Error : 0.9571 | Test Error: 0.8831 | Dyn var 2.92 | Obs var 100.00
# EM Iter 58 | Loss: 48.9227 | Train Error: 0.8183 | Val Error : 0.9554 | Test Error: 0.8811 | Dyn var 2.92 | Obs var 100.00
# EM Iter 59 | Loss: 48.5889 | Train Error: 0.8153 | Val Error : 0.9536 | Test Error: 0.8790 | Dyn var 2.92 | Obs var 100.00
# EM Iter 60 | Loss: 48.7520 | Train Error: 0.8122 | Val Error : 0.9518 | Test Error: 0.8768 | Dyn var 2.92 | Obs var 100.00
# EM Iter 61 | Loss: 48.4154 | Train Error: 0.8090 | Val Error : 0.9499 | Test Error: 0.8745 | Dyn var 2.92 | Obs var 100.00
# EM Iter 62 | Loss: 48.5755 | Train Error: 0.8056 | Val Error : 0.9479 | Test Error: 0.8722 | Dyn var 2.92 | Obs var 100.00
# EM Iter 63 | Loss: 48.2360 | Train Error: 0.8021 | Val Error : 0.9459 | Test Error: 0.8697 | Dyn var 2.92 | Obs var 100.00
# EM Iter 64 | Loss: 48.3933 | Train Error: 0.7984 | Val Error : 0.9437 | Test Error: 0.8672 | Dyn var 2.92 | Obs var 100.00
# EM Iter 65 | Loss: 48.0510 | Train Error: 0.7946 | Val Error : 0.9415 | Test Error: 0.8645 | Dyn var 2.92 | Obs var 100.00
# EM Iter 66 | Loss: 48.2055 | Train Error: 0.7905 | Val Error : 0.9392 | Test Error: 0.8618 | Dyn var 2.92 | Obs var 100.00
# EM Iter 67 | Loss: 47.8603 | Train Error: 0.7863 | Val Error : 0.9367 | Test Error: 0.8589 | Dyn var 2.92 | Obs var 100.00
# EM Iter 68 | Loss: 48.0121 | Train Error: 0.7819 | Val Error : 0.9342 | Test Error: 0.8559 | Dyn var 2.92 | Obs var 100.00
# EM Iter 69 | Loss: 47.6642 | Train Error: 0.7773 | Val Error : 0.9316 | Test Error: 0.8528 | Dyn var 2.92 | Obs var 100.00
# EM Iter 70 | Loss: 47.8132 | Train Error: 0.7724 | Val Error : 0.9289 | Test Error: 0.8495 | Dyn var 2.92 | Obs var 100.00
# EM Iter 71 | Loss: 47.4626 | Train Error: 0.7673 | Val Error : 0.9260 | Test Error: 0.8461 | Dyn var 2.92 | Obs var 100.00
# EM Iter 72 | Loss: 47.6089 | Train Error: 0.7621 | Val Error : 0.9231 | Test Error: 0.8425 | Dyn var 2.92 | Obs var 100.00
# EM Iter 73 | Loss: 47.2556 | Train Error: 0.7565 | Val Error : 0.9199 | Test Error: 0.8388 | Dyn var 2.92 | Obs var 100.00
# EM Iter 74 | Loss: 47.3993 | Train Error: 0.7507 | Val Error : 0.9167 | Test Error: 0.8348 | Dyn var 2.92 | Obs var 100.00
# EM Iter 75 | Loss: 47.0434 | Train Error: 0.7445 | Val Error : 0.9134 | Test Error: 0.8307 | Dyn var 2.92 | Obs var 100.00
# EM Iter 76 | Loss: 47.1845 | Train Error: 0.7381 | Val Error : 0.9099 | Test Error: 0.8264 | Dyn var 2.92 | Obs var 100.00
# EM Iter 77 | Loss: 46.8260 | Train Error: 0.7314 | Val Error : 0.9063 | Test Error: 0.8219 | Dyn var 2.92 | Obs var 100.00
# EM Iter 78 | Loss: 46.9645 | Train Error: 0.7244 | Val Error : 0.9025 | Test Error: 0.8171 | Dyn var 2.92 | Obs var 100.00
# EM Iter 79 | Loss: 46.6035 | Train Error: 0.7169 | Val Error : 0.8986 | Test Error: 0.8121 | Dyn var 2.92 | Obs var 100.00
# EM Iter 80 | Loss: 46.7396 | Train Error: 0.7092 | Val Error : 0.8945 | Test Error: 0.8068 | Dyn var 2.92 | Obs var 100.00
# EM Iter 81 | Loss: 46.3761 | Train Error: 0.7010 | Val Error : 0.8903 | Test Error: 0.8012 | Dyn var 2.92 | Obs var 100.00
# EM Iter 82 | Loss: 46.5096 | Train Error: 0.6925 | Val Error : 0.8859 | Test Error: 0.7954 | Dyn var 2.92 | Obs var 100.00
# EM Iter 83 | Loss: 46.1437 | Train Error: 0.6835 | Val Error : 0.8813 | Test Error: 0.7892 | Dyn var 2.92 | Obs var 100.00
# EM Iter 84 | Loss: 46.2748 | Train Error: 0.6741 | Val Error : 0.8766 | Test Error: 0.7827 | Dyn var 2.92 | Obs var 100.00
# EM Iter 85 | Loss: 45.9065 | Train Error: 0.6642 | Val Error : 0.8716 | Test Error: 0.7758 | Dyn var 2.92 | Obs var 100.00
# EM Iter 86 | Loss: 46.0352 | Train Error: 0.6539 | Val Error : 0.8665 | Test Error: 0.7686 | Dyn var 2.92 | Obs var 100.00
# EM Iter 87 | Loss: 45.6645 | Train Error: 0.6431 | Val Error : 0.8611 | Test Error: 0.7609 | Dyn var 2.92 | Obs var 100.00
# EM Iter 88 | Loss: 45.7908 | Train Error: 0.6318 | Val Error : 0.8556 | Test Error: 0.7529 | Dyn var 2.92 | Obs var 100.00
# EM Iter 89 | Loss: 45.4178 | Train Error: 0.6199 | Val Error : 0.8498 | Test Error: 0.7443 | Dyn var 2.92 | Obs var 100.00
# EM Iter 90 | Loss: 45.5419 | Train Error: 0.6075 | Val Error : 0.8439 | Test Error: 0.7353 | Dyn var 2.92 | Obs var 100.00
# EM Iter 91 | Loss: 45.1665 | Train Error: 0.5946 | Val Error : 0.8377 | Test Error: 0.7256 | Dyn var 2.92 | Obs var 100.00
# EM Iter 92 | Loss: 45.2883 | Train Error: 0.5812 | Val Error : 0.8313 | Test Error: 0.7155 | Dyn var 2.92 | Obs var 100.00
# EM Iter 93 | Loss: 44.9107 | Train Error: 0.5676 | Val Error : 0.8246 | Test Error: 0.7047 | Dyn var 2.92 | Obs var 100.00
# EM Iter 94 | Loss: 45.0303 | Train Error: 0.5538 | Val Error : 0.8177 | Test Error: 0.6935 | Dyn var 2.92 | Obs var 100.00
# EM Iter 95 | Loss: 44.6504 | Train Error: 0.5397 | Val Error : 0.8105 | Test Error: 0.6814 | Dyn var 2.92 | Obs var 100.00
# EM Iter 96 | Loss: 44.7678 | Train Error: 0.5257 | Val Error : 0.8031 | Test Error: 0.6687 | Dyn var 2.92 | Obs var 100.00
# EM Iter 97 | Loss: 44.3858 | Train Error: 0.5115 | Val Error : 0.7954 | Test Error: 0.6552 | Dyn var 2.92 | Obs var 100.00
# EM Iter 98 | Loss: 44.5009 | Train Error: 0.4974 | Val Error : 0.7875 | Test Error: 0.6410 | Dyn var 2.92 | Obs var 100.00
# EM Iter 99 | Loss: 44.1168 | Train Error: 0.4835 | Val Error : 0.7792 | Test Error: 0.6259 | Dyn var 2.92 | Obs var 100.00
# EM Iter 100 | Loss: 44.2298 | Train Error: 0.4705 | Val Error : 0.7707 | Test Error: 0.6100 | Dyn var 2.92 | Obs var 100.00
# EM Iter 101 | Loss: 43.8435 | Train Error: 0.4590 | Val Error : 0.7618 | Test Error: 0.5931 | Dyn var 2.92 | Obs var 100.00
# EM Iter 102 | Loss: 43.9544 | Train Error: 0.4494 | Val Error : 0.7527 | Test Error: 0.5754 | Dyn var 2.92 | Obs var 100.00
# EM Iter 103 | Loss: 43.5660 | Train Error: 0.4419 | Val Error : 0.7432 | Test Error: 0.5564 | Dyn var 2.92 | Obs var 100.00
# EM Iter 104 | Loss: 43.6748 | Train Error: 0.4367 | Val Error : 0.7334 | Test Error: 0.5366 | Dyn var 2.92 | Obs var 100.00
# EM Iter 105 | Loss: 43.2844 | Train Error: 0.4333 | Val Error : 0.7232 | Test Error: 0.5154 | Dyn var 2.92 | Obs var 100.00
# EM Iter 106 | Loss: 43.3912 | Train Error: 0.4315 | Val Error : 0.7127 | Test Error: 0.4934 | Dyn var 2.92 | Obs var 100.00
# EM Iter 107 | Loss: 42.9987 | Train Error: 0.4310 | Val Error : 0.7017 | Test Error: 0.4697 | Dyn var 2.92 | Obs var 100.00
# EM Iter 108 | Loss: 43.1034 | Train Error: 0.4325 | Val Error : 0.6905 | Test Error: 0.4452 | Dyn var 2.92 | Obs var 100.00
# EM Iter 109 | Loss: 42.7089 | Train Error: 0.4359 | Val Error : 0.6786 | Test Error: 0.4189 | Dyn var 2.92 | Obs var 100.00
# EM Iter 110 | Loss: 42.8117 | Train Error: 0.4415 | Val Error : 0.6664 | Test Error: 0.3916 | Dyn var 2.92 | Obs var 100.00
# EM Iter 111 | Loss: 42.4152 | Train Error: 0.4492 | Val Error : 0.6535 | Test Error: 0.3625 | Dyn var 2.92 | Obs var 100.00
# EM Iter 112 | Loss: 42.5160 | Train Error: 0.4589 | Val Error : 0.6403 | Test Error: 0.3322 | Dyn var 2.92 | Obs var 100.00
# EM Iter 113 | Loss: 42.1175 | Train Error: 0.4713 | Val Error : 0.6262 | Test Error: 0.2999 | Dyn var 2.92 | Obs var 100.00
# EM Iter 114 | Loss: 42.2164 | Train Error: 0.4856 | Val Error : 0.6116 | Test Error: 0.2664 | Dyn var 2.92 | Obs var 100.00
# EM Iter 115 | Loss: 41.8160 | Train Error: 0.5027 | Val Error : 0.5959 | Test Error: 0.2307 | Dyn var 2.92 | Obs var 100.00
# EM Iter 116 | Loss: 41.9130 | Train Error: 0.5229 | Val Error : 0.5796 | Test Error: 0.1937 | Dyn var 2.92 | Obs var 100.00
# EM Iter 117 | Loss: 41.5107 | Train Error: 0.5465 | Val Error : 0.5619 | Test Error: 0.1590 | Dyn var 2.92 | Obs var 100.00
# EM Iter 118 | Loss: 41.6057 | Train Error: 0.5730 | Val Error : 0.5433 | Test Error: 0.1318 | Dyn var 2.92 | Obs var 100.00
# EM Iter 119 | Loss: 41.2015 | Train Error: 0.6039 | Val Error : 0.5229 | Test Error: 0.1111 | Dyn var 2.92 | Obs var 100.00
# EM Iter 120 | Loss: 41.2947 | Train Error: 0.6378 | Val Error : 0.5010 | Test Error: 0.1101 | Dyn var 2.92 | Obs var 100.00
# EM Iter 121 | Loss: 40.8887 | Train Error: 0.6764 | Val Error : 0.4768 | Test Error: 0.1305 | Dyn var 2.92 | Obs var 100.00
# EM Iter 122 | Loss: 40.9800 | Train Error: 0.7179 | Val Error : 0.4506 | Test Error: 0.1543 | Dyn var 2.92 | Obs var 100.00
# EM Iter 123 | Loss: 40.5721 | Train Error: 0.7636 | Val Error : 0.4360 | Test Error: 0.1849 | Dyn var 2.92 | Obs var 100.00
# EM Iter 124 | Loss: 40.6616 | Train Error: 0.8121 | Val Error : 0.4220 | Test Error: 0.2228 | Dyn var 2.92 | Obs var 100.00
# EM Iter 125 | Loss: 40.2519 | Train Error: 0.8660 | Val Error : 0.4044 | Test Error: 0.2656 | Dyn var 2.92 | Obs var 100.00
# EM Iter 126 | Loss: 40.3396 | Train Error: 0.9233 | Val Error : 0.3831 | Test Error: 0.3105 | Dyn var 2.92 | Obs var 100.00
# EM Iter 127 | Loss: 39.9282 | Train Error: 0.9860 | Val Error : 0.3567 | Test Error: 0.3599 | Dyn var 2.92 | Obs var 100.00
# EM Iter 128 | Loss: 40.0140 | Train Error: 1.0520 | Val Error : 0.3250 | Test Error: 0.4184 | Dyn var 2.92 | Obs var 100.00
# EM Iter 129 | Loss: 39.6008 | Train Error: 1.1243 | Val Error : 0.2860 | Test Error: 0.4861 | Dyn var 2.92 | Obs var 100.00
# EM Iter 130 | Loss: 39.6849 | Train Error: 1.2014 | Val Error : 0.2399 | Test Error: 0.5553 | Dyn var 2.92 | Obs var 100.00
# EM Iter 131 | Loss: 39.2699 | Train Error: 1.2850 | Val Error : 0.1856 | Test Error: 0.6288 | Dyn var 2.92 | Obs var 100.00
# EM Iter 132 | Loss: 39.3523 | Train Error: 1.3728 | Val Error : 0.1378 | Test Error: 0.7039 | Dyn var 2.92 | Obs var 100.00
# EM Iter 133 | Loss: 38.9356 | Train Error: 1.4687 | Val Error : 0.1916 | Test Error: 0.7836 | Dyn var 2.92 | Obs var 100.00
# EM Iter 134 | Loss: 39.0162 | Train Error: 1.5690 | Val Error : 0.3088 | Test Error: 0.8648 | Dyn var 2.92 | Obs var 100.00
# EM Iter 135 | Loss: 38.5978 | Train Error: 1.6779 | Val Error : 0.4452 | Test Error: 0.9510 | Dyn var 2.92 | Obs var 100.00
# EM Iter 136 | Loss: 38.6767 | Train Error: 1.7914 | Val Error : 0.5979 | Test Error: 1.0388 | Dyn var 2.92 | Obs var 100.00
# EM Iter 137 | Loss: 38.2566 | Train Error: 1.9137 | Val Error : 0.7754 | Test Error: 1.1319 | Dyn var 2.92 | Obs var 100.00
# EM Iter 138 | Loss: 38.3339 | Train Error: 2.0406 | Val Error : 0.9730 | Test Error: 1.2265 | Dyn var 2.92 | Obs var 100.00
# EM Iter 139 | Loss: 37.9121 | Train Error: 2.1783 | Val Error : 1.2019 | Test Error: 1.3269 | Dyn var 2.92 | Obs var 100.00
# EM Iter 140 | Loss: 37.9876 | Train Error: 2.3209 | Val Error : 1.4555 | Test Error: 1.4288 | Dyn var 2.92 | Obs var 100.00
# EM Iter 141 | Loss: 37.5642 | Train Error: 2.4737 | Val Error : 1.7476 | Test Error: 1.5368 | Dyn var 2.92 | Obs var 100.00
# EM Iter 142 | Loss: 37.6381 | Train Error: 2.6311 | Val Error : 2.0696 | Test Error: 1.6463 | Dyn var 2.92 | Obs var 100.00
# EM Iter 143 | Loss: 37.2130 | Train Error: 2.7994 | Val Error : 2.4388 | Test Error: 1.7624 | Dyn var 2.92 | Obs var 100.00
# EM Iter 144 | Loss: 37.2852 | Train Error: 2.9721 | Val Error : 2.8431 | Test Error: 1.8799 | Dyn var 2.92 | Obs var 100.00
# EM Iter 145 | Loss: 36.8585 | Train Error: 3.1566 | Val Error : 3.3043 | Test Error: 2.0045 | Dyn var 2.92 | Obs var 100.00
# EM Iter 146 | Loss: 36.9292 | Train Error: 3.3459 | Val Error : 3.8064 | Test Error: 2.1305 | Dyn var 2.92 | Obs var 100.00
# EM Iter 147 | Loss: 36.5008 | Train Error: 3.5489 | Val Error : 4.3761 | Test Error: 2.2640 | Dyn var 2.92 | Obs var 100.00
# EM Iter 148 | Loss: 36.5699 | Train Error: 3.7571 | Val Error : 4.9928 | Test Error: 2.3988 | Dyn var 2.92 | Obs var 100.00
# EM Iter 149 | Loss: 36.1399 | Train Error: 3.9799 | Val Error : 5.6889 | Test Error: 2.5417 | Dyn var 2.92 | Obs var 100.00
# EM Iter 150 | Loss: 36.2074 | Train Error: 4.2077 | Val Error : 6.4379 | Test Error: 2.6858 | Dyn var 2.92 | Obs var 100.00
# EM Iter 151 | Loss: 35.7759 | Train Error: 4.4509 | Val Error : 7.2793 | Test Error: 2.8386 | Dyn var 2.92 | Obs var 100.00
# EM Iter 152 | Loss: 35.8417 | Train Error: 4.6993 | Val Error : 8.1797 | Test Error: 2.9925 | Dyn var 2.92 | Obs var 100.00
# EM Iter 153 | Loss: 35.4087 | Train Error: 4.9644 | Val Error : 9.1864 | Test Error: 3.1558 | Dyn var 2.92 | Obs var 100.00
# EM Iter 154 | Loss: 35.4730 | Train Error: 5.2349 | Val Error : 10.2580 | Test Error: 3.3199 | Dyn var 2.92 | Obs var 100.00
# EM Iter 155 | Loss: 35.0384 | Train Error: 5.5234 | Val Error : 11.4507 | Test Error: 3.4941 | Dyn var 2.92 | Obs var 100.00

# %% [markdown]
# # Plot Prediction error vs forward step & Volatility trajectory

# %%
for k in range(len(error_for_all_theta_dim)):

    sns.set()
    fig = plt.figure(figsize=(15, 4))
    fig.suptitle("Theta = {}".format(k+8))
    
    mean_iteration = int((best_train_itr_for_all_theta_dim[k] + best_itr_for_all_theta_dim[k])/2)
    
    iteratons = range(mean_iteration, mean_iteration+1)
    
    # forward steps
    a = fig.add_subplot(121)
    
    
    xlabel = list(range(len(k_step_test_error)+1))
    plt.xticks(xlabel)
    a.set_ylim(0.0, 0.5)
    a.set_title('Prediction Error vs Forward Steps, theta_dim = {}'.format(k+8), color='C0')
    for i in iteratons:
        show = error_for_all_theta_dim[k][i]
        a.plot([i+1 for i in range(len(k_step_test_error))], show, marker='^', markersize= 5, linewidth=1)
    a.legend(["em itr={}".format(i) for i in iteratons])
    
    b = fig.add_subplot(122)
    b.xaxis_date()
    # volatility trajectory
    b.set_title('Volatility Trajectory vs theta dimension, theta_dim = {}'.format(k+8), color='C0')
    for i in iteratons:
        volatility_mean = np.average(ms_s_for_all_theta_dim[k][i], axis=1)
        b.plot(all_days, volatility_mean[1:], linewidth=1)
    b.legend(["em itr={}".format(i) for i in iteratons])
    plt.xticks(rotation=60)
    fig.show()

# %% [markdown]
# # Test Implied Volatility

# %%
base_date = list(valid_data.keys())[-1]
base_date_vol = np.average(valid_data[list(valid_data.keys())[-1]][0]["impl_volatility"].values) / bday_p_year

test_days = list(test_data.keys())
test_error_traj_imp_vol = []
for k in range(1, min(forward_k+1, num_test_day+1)):
    k_step_test_error_imp_vol = []
    for idx in range(k-1, num_test_day):
        pred_date = test_days[idx]
        pred_date_p = test_data[pred_date][3]
        pred_date_r = test_data[pred_date][1] / bday_p_year
        pred_date_K = test_data[pred_date][0]["strike_price"].values
        today = [d.date() for d in test_data[pred_date][0]["date"]]
        expireday = [d.date() for d in test_data[pred_date][0]["exdate"]]
        pred_date_T = np.busday_count(today, expireday)
        pred_date_y = test_data[pred_date][0]["spotclose"].values

        pred_price_imp_vol = BSf(base_date_vol, 
                                 p_t=pred_date_p, 
                                 r_t=pred_date_r, 
                                 K_t=pred_date_K, 
                                 T_t=pred_date_T)
        pred_error_imp_vol = np.average(np.abs(pred_price_imp_vol-pred_date_y) / pred_date_y)
        k_step_test_error_imp_vol.append(pred_error_imp_vol)

        base_date = test_days[idx-k+1]
        base_date_vol = np.average(valid_data[list(valid_data.keys())[-1]][0]["impl_volatility"].values) / bday_p_year

    test_error_traj_imp_vol.append(np.average(k_step_test_error_imp_vol))

fig = plt.figure(figsize=(8,4))
fig.suptitle("Implied Volatility Prediction k steps forward")
plt.xticks(xlabel)
plt.plot([_+1 for _ in range(forward_k)], test_error_traj_imp_vol, marker ='^', markersize=5, linewidth=1)
fig.show()

# %%
train_data[np.datetime64('2019-01-02T00:00:00.000000000')]
# Out:
# [              date     exdate  strike_price  best_bid  best_offer  volume  \
#  7824298 2019-01-02 2019-06-21        3050.0      3.40         3.7   30005
#  7824308 2019-01-02 2019-06-21        3300.0      0.75         1.0   30005
#  7823256 2019-01-02 2019-01-18        2570.0     14.50        15.3   22363
#  7823260 2019-01-02 2019-01-18        2590.0      9.20         9.8   19735
#  7825956 2019-01-02 2019-01-11        2525.0     23.40        24.0   19555
#
#           impl_volatility  spotclose
#  7824298         0.149985      3.550
#  7824308         0.163895      0.875
#  7823256         0.180783     14.900
#  7823260         0.174487      9.500
#  7825956         0.192232     23.700  ,
#  0.0279388,
#  array([ 8.64007027e-05, -1.53957145e-02, -1.57721063e-02, -2.05882284e-02,
#         -2.71122542e-02,  4.95937426e-02,  8.56268080e-03, -1.24158255e-03,
#          8.49248436e-03,  1.26849667e-03]),
#  2510.030029]

# %%
best_itr_for_all_theta_dim
# Out:
# [76, 67]
