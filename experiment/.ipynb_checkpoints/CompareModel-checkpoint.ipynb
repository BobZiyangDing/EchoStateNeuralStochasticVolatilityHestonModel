# %%
# Most Basic
import sys
from arch import arch_model

import matplotlib.pyplot as plt
import matplotlib as mpl
import seaborn as sns
import pandas as pd
import numpy as np
import math
import scipy.stats as ss
import copy
import warnings
import datetime as dt
from os import path
from datetime import datetime
from scipy.stats import norm
from DataMaker_New import dataCleaner_new
warnings.simplefilter('error')


columns = ["date","exdate","strike_price","best_bid","best_offer","volume","impl_volatility"]
start = dt.datetime(2018, 1, 1)
end = dt.datetime(2019, 12, 31)
train_valid_split = 0.936
valid_test_split = 0.94
u_dim = 10
topK = 5
cleaner = dataCleaner_new(columns, u_dim, topK, start, end, train_valid_split, valid_test_split)
return_dict, price_dict = cleaner.make_return_price()
risk_dict = cleaner.make_risk()
train_data, valid_data, test_data = cleaner.make_final_data(price_dict, return_dict, risk_dict)
num_train_day, num_train_obs = cleaner.get_train_num()
num_valid_day, num_valid_obs = cleaner.get_valid_num()
num_test_day, num_test_obs = cleaner.get_test_num()

train_data[np.datetime64('2019-01-02T00:00:00.000000000')]
# Out:
# Attached 351 days of train data
# Attached 1755 train option observations
# Attached 1 days of validation data
# Attached 5 validation option observations
# Attached 23 days of test data
# Attached 115 test option observations
# [              date     exdate  strike_price  best_bid  best_offer  volume  \
#  7824298 2019-01-02 2019-06-21        3050.0      3.40         3.7   30005
#  7824308 2019-01-02 2019-06-21        3300.0      0.75         1.0   30005
#  7823256 2019-01-02 2019-01-18        2570.0     14.50        15.3   22363
#  7823260 2019-01-02 2019-01-18        2590.0      9.20         9.8   19735
#  7825956 2019-01-02 2019-01-11        2525.0     23.40        24.0   19555
#
#           impl_volatility  spotclose
#  7824298         0.149985      3.550
#  7824308         0.163895      0.875
#  7823256         0.180783     14.900
#  7823260         0.174487      9.500
#  7825956         0.192232     23.700  ,
#  0.0279388,
#  array([ 8.64007027e-05, -1.53957145e-02, -1.57721063e-02, -2.05882284e-02,
#         -2.71122542e-02,  4.95937426e-02,  8.56268080e-03, -1.24158255e-03,
#          8.49248436e-03,  1.26849667e-03]),
#  2510.030029]

# %%
# Define transition Dynamics
# Positional requirement, no real effect, will be replaced by ESN and BS defined further down
def fx(x, dt):
    return x*dt
def hx(x):
    return x

def sigmoid(x):
    return np.divide(1, 1+np.exp(-x))


def ESNf(theta_now, dt, **fx_args):
    """
    :params theta_now theta_t
    
    **fx_args
    :params G reservoir transition matrix
    :params G_in input translation matrix
    :params b reservoir bias vector
    :params u_quad_now u_t^2
    """
    G = fx_args["G"]
    G_in = fx_args["G_in"]
    b = fx_args["b"]
    u_quad_now = fx_args["u_quad_now"]
    theta_next = sigmoid(np.matmul(G, theta_now) + np.matmul(G_in, u_quad_now) + b)
    return theta_next
    

def BSf(theta_t, **hx_args):
    """
    :params theta_t current state vector
    
    **hx_args
    :params p_t current asset price
    :params r_t current asset price
    :params K_t strike price, 1d vector
    :params T_t maturity time, 1d vector
    """
    p_t = hx_args["p_t"]
    r_t = hx_args["r_t"]
    K_t = hx_args["K_t"]
    T_t = hx_args["T_t"]
    
    volatility_std = np.average(theta_t)
    volatility_var = np.power(volatility_std, 2)
    
    dividor = np.sqrt(volatility_var * T_t)
    d_pls = (np.log(p_t/K_t) + np.multiply(r_t+volatility_var/2, T_t)) / dividor
    d_mns = (np.log(p_t/K_t) + np.multiply(r_t-volatility_var/2, T_t)) / dividor
    y_t = np.multiply(p_t, norm.cdf(d_pls)) - np.multiply(np.multiply(K_t, np.exp(-r_t*T_t)), norm.cdf(d_mns))
    return y_t

def is_pos_def(x):
    return np.all(np.linalg.eigvals(x) > 0)

# %% [markdown]
# # Test Implied Volatility

# %%
bday_p_year = 252
forward_k = 20
base_date = list(valid_data.keys())[-1]
base_date_vol = np.average(valid_data[list(valid_data.keys())[-1]][0]["impl_volatility"].values) / bday_p_year

test_days = list(test_data.keys())
test_error_traj_imp_vol = []
for k in range(1, min(forward_k+1, num_test_day+1)):
    k_step_test_error_imp_vol = []
    for idx in range(k-1, num_test_day):
        pred_date = test_days[idx]
        pred_date_p = test_data[pred_date][3]
        pred_date_r = test_data[pred_date][1] 
        pred_date_K = test_data[pred_date][0]["strike_price"].values
        today = [d.date() for d in test_data[pred_date][0]["date"]]
        expireday = [d.date() for d in test_data[pred_date][0]["exdate"]]
        pred_date_T = np.busday_count(today, expireday) / bday_p_year
        pred_date_y = test_data[pred_date][0]["spotclose"].values

        pred_price_imp_vol = BSf(base_date_vol, 
                                 p_t=pred_date_p, 
                                 r_t=pred_date_r, 
                                 K_t=pred_date_K, 
                                 T_t=pred_date_T)
        pred_error_imp_vol = np.average(np.abs(pred_price_imp_vol-pred_date_y) / pred_date_y)
        k_step_test_error_imp_vol.append(pred_error_imp_vol)

        base_date = test_days[idx-k+1]
        base_date_vol = np.average(valid_data[list(valid_data.keys())[-1]][0]["impl_volatility"].values) / bday_p_year

    test_error_traj_imp_vol.append(np.average(k_step_test_error_imp_vol))

sns.set()
fig = plt.figure(figsize=(8,4))
xlabel = list(range(len(k_step_test_error_imp_vol)+1))
fig.suptitle("Implied Volatility Prediction k steps forward")
plt.xticks(xlabel)
plt.plot([_+1 for _ in range(forward_k)], test_error_traj_imp_vol, marker ='^', markersize=5, linewidth=1)
fig.show()

# %% [markdown]
# # Test GARCH family

# %%
columns = ["date","exdate","strike_price","best_bid","best_offer","volume","impl_volatility"]
start = dt.datetime(2018, 1, 1)
end = dt.datetime(2019, 12, 31)
train_valid_split = 0.936
valid_test_split = 0.94
u_dim = 1
topK = 5
cleaner = dataCleaner_new(columns, u_dim, topK, start, end, train_valid_split, valid_test_split)
return_dict, price_dict = cleaner.make_return_price()
risk_dict = cleaner.make_risk()
train_data, valid_data, test_data = cleaner.make_final_data(price_dict, return_dict, risk_dict)
num_train_day, num_train_obs = cleaner.get_train_num()
num_valid_day, num_valid_obs = cleaner.get_valid_num()
num_test_day, num_test_obs = cleaner.get_test_num()

train_data[np.datetime64('2019-01-02T00:00:00.000000000')]
# Out:
# Attached 351 days of train data
# Attached 1755 train option observations
# Attached 1 days of validation data
# Attached 5 validation option observations
# Attached 23 days of test data
# Attached 115 test option observations
# [              date     exdate  strike_price  best_bid  best_offer  volume  \
#  7824298 2019-01-02 2019-06-21        3050.0      3.40         3.7   30005
#  7824308 2019-01-02 2019-06-21        3300.0      0.75         1.0   30005
#  7823256 2019-01-02 2019-01-18        2570.0     14.50        15.3   22363
#  7823260 2019-01-02 2019-01-18        2590.0      9.20         9.8   19735
#  7825956 2019-01-02 2019-01-11        2525.0     23.40        24.0   19555
#
#           impl_volatility  spotclose
#  7824298         0.149985      3.550
#  7824308         0.163895      0.875
#  7823256         0.180783     14.900
#  7823260         0.174487      9.500
#  7825956         0.192232     23.700  ,
#  0.0279388,
#  array([0.0012685]),
#  2510.030029]

# %%
returns = []
index = []
for day in list(train_data.keys()):
    returns.append(train_data[day][2][0])
    index.append(day)
for day in list(valid_data.keys()):
    returns.append(valid_data[day][2][0])
    index.append(day)
last_val_date = list(valid_data.keys())[-1]
base_idx = len(index)-1

for day in list(test_data.keys()):
    returns.append(test_data[day][2][0])
    index.append(day)
returns = np.array(returns)*100
index = np.array(index)
Garch_data = pd.DataFrame(returns, index=index, columns=["Returns"])


test_error_traj_garch = []
for k in range(1, min(forward_k+1, num_test_day+1)):
    k_step_test_error_garch = []
    for idx in range(base_idx+k, len(index)):
        am = arch_model(Garch_data[:base_idx+1], vol='Garch', p=5, q=5, dist='Normal')
        res = am.fit(update_freq=10)
        forecasts = res.forecast(horizon=k)
        pred_vol = math.sqrt(forecasts.mean.iloc[-1].tolist()[-1] / 10000)
        
        pred_date = index[idx]
        pred_date_p = test_data[pred_date][3]
        pred_date_r = test_data[pred_date][1] / bday_p_year
        pred_date_K = test_data[pred_date][0]["strike_price"].values
        today = [d.date() for d in test_data[pred_date][0]["date"]]
        expireday = [d.date() for d in test_data[pred_date][0]["exdate"]]
        pred_date_T = np.busday_count(today, expireday)
        pred_date_y = test_data[pred_date][0]["spotclose"].values
        
        pred_price_garch = BSf(pred_vol,
                               p_t=pred_date_p, 
                               r_t=pred_date_r, 
                               K_t=pred_date_K, 
                               T_t=pred_date_T)
        
        pred_error_garch = np.average(np.abs(pred_price_garch-pred_date_y) / pred_date_y)
        
        k_step_test_error_garch.append(pred_error_garch)
        base_idx += 1
        
    test_error_traj_garch.append( np.average(k_step_test_error_garch) )
        
sns.set()
fig = plt.figure(figsize=(8,4))
xlabel = list(range(len(k_step_test_error_garch)+1))
fig.suptitle("GARCH(5,5) Prediction k steps forward")
plt.xticks(xlabel)
plt.plot([_+1 for _ in range(forward_k)], test_error_traj_garch, marker ='^', markersize=5, linewidth=1)
fig.show()
# Out:
# Iteration:     10,   Func. Count:    153,   Neg. LLF: 447.6423567331483
# Iteration:     20,   Func. Count:    296,   Neg. LLF: 446.77828532885246
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 446.77828532867125
#             Iterations: 20
#             Function evaluations: 296
#             Gradient evaluations: 20
# Iteration:     10,   Func. Count:    153,   Neg. LLF: 448.8827659580677
# Iteration:     20,   Func. Count:    296,   Neg. LLF: 447.98313114409734
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 447.9831311438724
#             Iterations: 20
#             Function evaluations: 296
#             Gradient evaluations: 20
# Iteration:     10,   Func. Count:    153,   Neg. LLF: 449.68531332690117
# Iteration:     20,   Func. Count:    297,   Neg. LLF: 448.9281279373007
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 448.92812793745884
#             Iterations: 20
#             Function evaluations: 297
#             Gradient evaluations: 20
# Iteration:     10,   Func. Count:    152,   Neg. LLF: 452.58513492101105
# Iteration:     20,   Func. Count:    296,   Neg. LLF: 451.5675346416068
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 451.56753464169935
#             Iterations: 20
#             Function evaluations: 296
#             Gradient evaluations: 20
# Iteration:     10,   Func. Count:    153,   Neg. LLF: 453.5357244835728
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 452.6077482652986
#             Iterations: 19
#             Function evaluations: 282
#             Gradient evaluations: 19
# Iteration:     10,   Func. Count:    152,   Neg. LLF: 457.6359989752943
# Iteration:     20,   Func. Count:    297,   Neg. LLF: 456.4453079519243
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 456.4452925829187
#             Iterations: 21
#             Function evaluations: 311
#             Gradient evaluations: 21
# Iteration:     10,   Func. Count:    153,   Neg. LLF: 460.00520744028495
# Iteration:     20,   Func. Count:    296,   Neg. LLF: 457.6865811647499
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 457.6865811662926
#             Iterations: 20
#             Function evaluations: 296
#             Gradient evaluations: 20
# Iteration:     10,   Func. Count:    153,   Neg. LLF: 461.2867605202364
# Iteration:     20,   Func. Count:    297,   Neg. LLF: 458.8850507355541
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 458.88502136370016
#             Iterations: 22
#             Function evaluations: 325
#             Gradient evaluations: 22
# Iteration:     10,   Func. Count:    153,   Neg. LLF: 462.6453822098225
# Iteration:     20,   Func. Count:    296,   Neg. LLF: 460.2448507310144
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 460.24473872789997
#             Iterations: 22
#             Function evaluations: 324
#             Gradient evaluations: 22
# Iteration:     10,   Func. Count:    152,   Neg. LLF: 462.0845535479973
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 461.5617415165604
#             Iterations: 19
#             Function evaluations: 282
#             Gradient evaluations: 19
# Iteration:     10,   Func. Count:    154,   Neg. LLF: 464.5596791658021
# Iteration:     20,   Func. Count:    296,   Neg. LLF: 462.3211736480683
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 462.32116884151895
#             Iterations: 21
#             Function evaluations: 310
#             Gradient evaluations: 21
# Iteration:     10,   Func. Count:    153,   Neg. LLF: 465.4254696362156
# Iteration:     20,   Func. Count:    296,   Neg. LLF: 463.25403912087944
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 463.2540297639085
#             Iterations: 21
#             Function evaluations: 310
#             Gradient evaluations: 21
# Iteration:     10,   Func. Count:    153,   Neg. LLF: 466.22340214015225
# Iteration:     20,   Func. Count:    295,   Neg. LLF: 464.03383875188507
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 464.0338329160571
#             Iterations: 21
#             Function evaluations: 310
#             Gradient evaluations: 21
# Iteration:     10,   Func. Count:    153,   Neg. LLF: 466.8388422167662
# Iteration:     20,   Func. Count:    295,   Neg. LLF: 464.64901461259024
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 464.64901397285485
#             Iterations: 20
#             Function evaluations: 296
#             Gradient evaluations: 20
# Iteration:     10,   Func. Count:    153,   Neg. LLF: 467.2796142517937
# Iteration:     20,   Func. Count:    296,   Neg. LLF: 465.1022029078125
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 465.1022029078191
#             Iterations: 20
#             Function evaluations: 296
#             Gradient evaluations: 20
# Iteration:     10,   Func. Count:    153,   Neg. LLF: 468.75917669276134
# Iteration:     20,   Func. Count:    296,   Neg. LLF: 466.6268962414939
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 466.62689624145173
#             Iterations: 20
#             Function evaluations: 296
#             Gradient evaluations: 20
# Iteration:     10,   Func. Count:    153,   Neg. LLF: 469.26015833457694
# Iteration:     20,   Func. Count:    297,   Neg. LLF: 467.11257755927335
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 467.11257637441474
#             Iterations: 21
#             Function evaluations: 311
#             Gradient evaluations: 21
# Iteration:     10,   Func. Count:    153,   Neg. LLF: 470.6403646731819
# Iteration:     20,   Func. Count:    296,   Neg. LLF: 468.548855722198
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 468.54885572225686
#             Iterations: 20
#             Function evaluations: 296
#             Gradient evaluations: 20
# Iteration:     10,   Func. Count:    153,   Neg. LLF: 471.20350520298155
# Iteration:     20,   Func. Count:    297,   Neg. LLF: 469.0990688163983
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 469.09906716286565
#             Iterations: 21
#             Function evaluations: 311
#             Gradient evaluations: 21
# Iteration:     10,   Func. Count:    153,   Neg. LLF: 471.868447910499
# Iteration:     20,   Func. Count:    297,   Neg. LLF: 469.7613047177882
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 469.761303590461
#             Iterations: 21
#             Function evaluations: 311
#             Gradient evaluations: 21
# Iteration:     10,   Func. Count:    152,   Neg. LLF: 472.31516837613987
# Iteration:     20,   Func. Count:    296,   Neg. LLF: 471.83057177942294
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 471.8305717794207
#             Iterations: 20
#             Function evaluations: 296
#             Gradient evaluations: 20
# Iteration:     10,   Func. Count:    152,   Neg. LLF: 473.69967589170165
# Iteration:     20,   Func. Count:    296,   Neg. LLF: 472.5839663369299
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 472.58396530977916
#             Iterations: 21
#             Function evaluations: 310
#             Gradient evaluations: 21
# Iteration:     10,   Func. Count:    152,   Neg. LLF: 473.57608171629136
# Iteration:     20,   Func. Count:    296,   Neg. LLF: 473.08700945694716
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 473.08700945693295
#             Iterations: 20
#             Function evaluations: 296
#             Gradient evaluations: 20
# RuntimeWarningTraceback (most recent call last)
# <ipython-input-35-36a1262f8d1f> in <module>
#      47         base_idx += 1
#      48
# ---> 49     test_error_traj_garch.append(np.average(k_step_test_error_garch))
#      50
#      51 sns.set()
#
# <__array_function__ internals> in average(*args, **kwargs)
#
# /opt/conda/lib/python3.7/site-packages/numpy/lib/function_base.py in average(a, axis, weights, returned)
#     391
#     392     if weights is None:
# --> 393         avg = a.mean(axis)
#     394         scl = avg.dtype.type(a.size/avg.size)
#     395     else:
#
# /opt/conda/lib/python3.7/site-packages/numpy/core/_methods.py in _mean(a, axis, dtype, out, keepdims)
#     139     # Make this warning show up first
#     140     if rcount == 0:
# --> 141         warnings.warn("Mean of empty slice.", RuntimeWarning, stacklevel=2)
#     142
#     143     # Cast bool, unsigned int, and int to float64 by default
#
# RuntimeWarning: Mean of empty slice.

# %%
forecasts = res.forecast(horizon=5)

pred_vol = math.sqrt(forecasts.mean.iloc[-1].tolist()[-1] / 10000)
# Out:
# 0.0032903662159130464

# %%
forecasts = res.forecast(horizon=5)
print(forecasts.residual_variance.iloc[-3:])
# Out:
#                 h.1       h.2       h.3       h.4       h.5
# -0.123393       NaN       NaN       NaN       NaN       NaN
#  0.382318       NaN       NaN       NaN       NaN       NaN
#  0.575745  0.606588  0.392874  0.460303  0.465911  0.590083
